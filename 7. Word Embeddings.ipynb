# %%
import nltk
# nltk.download('averaged_perceptron_tagger_eng')
# nltk.download('punt_tab')

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import re

# from textblob import TextBlob
from pathlib import Path
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import contractions
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk import pos_tag

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet
# Initialize stemmer/lemmatizer (run once)
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# # Step 1: Cleaning Functions

# %%
def take_out_mentions_to_the_president(text):
    """Remove introductory phrases addressing the president or other dignitaries from text.
    Args:
        text (str): The input text to process    
    Returns:
        str: The text with introductory address phrases removed, or original text if none found
    """
    
    # Split into sentences (simple regex)
    # The regex looks for sentence-ending punctuation followed by whitespace
    sentences = re.split(r'(?<=[.!?])\s+', text.strip())
    
    # Get first 4 sentences as search area - addresses are typically at the beginning
    search_area = ' '.join(sentences[:2]).lower()
    
    # Phrases to search for (lowercase)
    # We look for various forms of presidential/dignitary addresses
    # Store the index where each phrase is found (-1 if not found)
    possible_starts = [
        search_area.lower().find("mr. president"),  # Formal address with period
        search_area.lower().find("mr president"),   # Formal address without period
        search_area.lower().find("ladies and gentlemen"),  # Common formal address
        search_area.lower().find("your excellency"),  # Covers "your excellence" and "your excellency"
        search_area.lower().find("your excellence"),  # Covers "your excellence" and "your excellency"
        search_area.lower().find("your majesties"),  # 
        search_area.lower().find("your majesties"),  # 
        search_area.lower().find("president of the general assembly"),
        search_area.lower().find("excellencies"),     # Plural form of address
        search_area.lower().find("esteemed president"),  # Honorific address
        search_area.lower().find("distinguished delegates"),  # Assembly address
        search_area.lower().find("allah"),  # Address to members of an assembly
    ]
    
    # Filter out phrases that weren't found (-1) and keep only valid indices
    starts = [start for start in possible_starts if start != -1]
    
    # Get the latest occurrence of any address phrase
    start = max(starts) if len(starts) > 0 else -1
    
    if start == -1:
        # No address phrases found - log this and return full text
        # print(f"Could not find probable start in the text of {url}")
        start = 0
    
    # Return text starting from after the address phrase
    return text[start:]

# %%
def simple_clean(text):
    """Cleans text by removing common formatting artifacts from PDF conversions and UN document patterns.
    
    Args:
        text (str): Input text to be cleaned
        
    Returns:
        str: Cleaned text with unwanted patterns removed
    """
    
    # Convert to lowercase for consistent processing 
    # text = text.lower()
  
    # 1: Remove UN document reference numbers (e.g. "20/26 15-29876")
    text = re.sub(r'\b\d{1,4}\s*/\s*\d{1,4}\s+\d{2,4}-\d{4,8}\b', ' ', text)
    
    # 2: Remove UN meeting record references (e.g. "A/70/PV.24")
    text = re.sub(r'\b[a-z]\s*/\s*\d+\s*/pv\s*\.\s*\d+\b', ' ', text, flags=re.IGNORECASE)
    
    # 3: Remove dates in DD/MM/YYYY format (e.g. "31/12/2023")
    text = re.sub(r'\d{2}\/\d{2}\/\d{4}', '', text) 
  
    # 4: Remove form feed characters (often from PDF conversion)
    text = re.sub(r'\x0c', '', text) 
  
    # 5: Remove parenthetical document references (e.g. "(A/70/123)" or "(A/70/123, annex)")
    text = re.sub(r'\(\s*[a-z]\s*/\s*\d+\s*/\s*\d+\s*(?:,\s*annex)?\s*\)', '', text, flags=re.IGNORECASE)
    
    # 6: Remove standalone line numbers/page numbers (e.g. "42" on its own line)
    text = re.sub(r'^\s*\d+\s*$\n?', '', text, flags=re.MULTILINE)
    
    # 7: Normalize newlines - replace all with single spaces
    text = re.sub(r'\n', ' ', text, flags=re.MULTILINE)

    # 8: Remove numbered list prefixes (e.g. "1.    Some text")
    text = re.sub(r'\d+\.\t', '', text)

    # 9: Remove Unicode BOM (Byte Order Mark) character if present
    text = text.replace('\ufeff', '')
    
    # 10: Normalize whitespace - collapse multiple spaces into one and trim
    text = re.sub(r'\s+', ' ', text).strip()

    # 11. Remove standalone hyphens
    text = re.sub(r'\s*-(?!\w)(?<!\w)-*\s*', ' ', text)

    # 12: Remove punctuations
    #text = text.replace('—', '').replace(',', '').replace(':', '').replace('’', '').replace('“', '').replace("”", '').replace(";", '').replace("''", '')
    
    # 12: Remove words/numbers between parenthesis
    text = re.sub(r'\([^)]*\)', '', text)

    #13: Remove markdown-style bold/italic/blockquote symbols (all below are subpoints rather that main ones)
    text = re.sub(r'\*\*+', '', text)       # removes **, **** etc.
    text = re.sub(r'>+', '', text)          # removes >, >>, etc.
    text = re.sub(r'-{2,}', '', text)       # removes --, --- etc.
    text = re.sub(r'[=*_~#`]+', '', text)   # removes *, _, =, #, ~, ` etc.
    
    return text

# %%
def clean_speeches(text, use_simple_clean=True, disregard_mentions_to_president=True, Remove_Stopwords = False, expand=False, Remove_Punctuations = False):
    """Load a text file and apply cleaning operations. 
    Args:
        text: Original text
        use_simple_clean (bool): Whether to apply basic text cleaning
        disregard_mentions_to_president (bool): Whether to remove mentions to the president
        Returns:
        str: Cleaned text from the file"""
    
    if expand: 
        text = contractions.fix(text) 

    # Apply basic text cleaning if the flag is set
    if use_simple_clean:
        text = simple_clean(text)  # Assumes simple_clean is a custom function defined elsewhere

    # Remove mentions to the president if the flag is set
    if disregard_mentions_to_president:
        text = take_out_mentions_to_the_president(text)  # Also assumes this function is defined elsewhere
    
    # Remove Stopwrods
    if Remove_Stopwords:
        text = remove_stopwords(text)

    # Remove Punctuations
    if Remove_Punctuations:
        text = remove_punctuations(text)
        
    # Replace only spaces/tabs induced from the stopwords
    text = re.sub(r'[ \t]+', ' ', text)

    # Return the cleaned (or original) text
    return text

# %% [markdown]
# # Step 2: Load the speeches

# %%
base_path_alvaro = Path(r"C:\Users\Alvaro Millan Ruiz\OneDrive\Escritorio\BDS\Block_5\NLP\Project")
base_path_gilda = "/Users/szonjapike/Desktop/BDS/Block_5/NLP/TXT/"

base_path = base_path_gilda # change according to user

# %%
path_dataset_gilda = "/Users/szonjapike/Desktop/BDS/Block_5/NLP/Project/"
base_path = path_dataset_gilda

# %%
final_df = pd.read_csv(base_path + "Final_df.csv")
final_df = final_df.drop(columns=["cleaned_speeches_no_postagging_expanded",
                                   "cleaned_speeches_no_postagging_no_expanded",
                                     "cleaned_speeches_postagging_no_expanded",
                                       "cleaned_speeches_postagging_expanded"])
final_df
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      NZL
# 1          45  1990      EGY
# 2          45  1990      CPV
# 3          45  1990      UGA
# 4          45  1990      NLD
# ...       ...   ...      ...
# 6434       79  2024      CIV
# 6435       79  2024      HND
# 6436       79  2024      MKD
# 6437       79  2024      KOR
# 6438       79  2024      SGP
#
#                                                  Speech  number_sentences  \
# 0     ﻿\nI should like to congratulate you, Sir, on ...               145
# 1     ﻿First of all, I would like to extend may dele...                76
# 2     ﻿I should like to begin by offering Mr. de Mar...                71
# 3     ﻿In 1967, I had the privilege of addressing th...               132
# 4     ﻿\nMay I, first of all, extend to Mr. de Marco...               167
# ...                                                 ...               ...
# 6434  Mr President of the 79th Session of the United...                41
# 6435  Madam President of this General Assembly,  \nM...                54
# 6436  Distinguished President of the United Nations ...               101
# 6437  Mr. President,\nMr. Secretary-General,\nDistin...                31
# 6438  Mdm President, Your Excellencies \n  \n  \n1 I...               100
#
#       number_tokens  Income Level
# 0              3512             4
# 1              2532             1
# 2              2432             2
# 3              3508             1
# 4              4134             4
# ...             ...           ...
# 6434           1206             2
# 6435           1367             2
# 6436           2804             3
# 6437            821             4
# 6438           2208             4
#
# [6439 rows x 7 columns]

# %%
# nltk.download('wordnet')
tqdm.pandas()  # Enable pandas integration

final_df['speeches_for_keyword_search'] = final_df['Speech'].progress_apply(
    lambda x: clean_speeches(
        x, 
        expand=True,
        use_simple_clean=True, 
        disregard_mentions_to_president=True, 
        Remove_Stopwords=False,        # No removal of stopwords
        Remove_Punctuations= False
    )
)

final_df
# Out:
#   0%|          | 4/6439 [00:00<03:59, 26.90it/s]
# 100%|██████████| 6439/6439 [00:59<00:00, 108.25it/s]
#       Session  Year ISO-Code  \
# 0          45  1990      NZL
# 1          45  1990      EGY
# 2          45  1990      CPV
# 3          45  1990      UGA
# 4          45  1990      NLD
# ...       ...   ...      ...
# 6434       79  2024      CIV
# 6435       79  2024      HND
# 6436       79  2024      MKD
# 6437       79  2024      KOR
# 6438       79  2024      SGP
#
#                                                  Speech  number_sentences  \
# 0     ﻿\nI should like to congratulate you, Sir, on ...               145
# 1     ﻿First of all, I would like to extend may dele...                76
# 2     ﻿I should like to begin by offering Mr. de Mar...                71
# 3     ﻿In 1967, I had the privilege of addressing th...               132
# 4     ﻿\nMay I, first of all, extend to Mr. de Marco...               167
# ...                                                 ...               ...
# 6434  Mr President of the 79th Session of the United...                41
# 6435  Madam President of this General Assembly,  \nM...                54
# 6436  Distinguished President of the United Nations ...               101
# 6437  Mr. President,\nMr. Secretary-General,\nDistin...                31
# 6438  Mdm President, Your Excellencies \n  \n  \n1 I...               100
#
#       number_tokens  Income Level  \
# 0              3512             4
# 1              2532             1
# 2              2432             2
# 3              3508             1
# 4              4134             4
# ...             ...           ...
# 6434           1206             2
# 6435           1367             2
# 6436           2804             3
# 6437            821             4
# 6438           2208             4
#
#                             speeches_for_keyword_search
# 0     I should like to congratulate you, Sir, on you...
# 1     First of all, I would like to extend may deleg...
# 2     I should like to begin by offering Mr. de Marc...
# 3     In 1967, I had the privilege of addressing thi...
# 4     May I, first of all, extend to Mr. de Marco my...
# ...                                                 ...
# 6434  Ladies and Gentlemen, Heads of State and Gover...
# 6435  Madam President of this General Assembly, Mr. ...
# 6436  Ladies and Gentlemen, Being invited to address...
# 6437  Mr. President, Mr. Secretary-General, Distingu...
# 6438  Excellencies 1 I bring you greetings from a ti...
#
# [6439 rows x 8 columns]

# %% [markdown]
# # Step 3: Look for the keywords

# %%
# Climate keyword according to the literature
climate_keywords = ["climate change", "global warming", "cap and trade", "unfccc", "paris accord", "emissions trading scheme", "global average temperature",
                    "kyoto protocol", "climate resilience", "carbon dioxide", "climate politics", "framework convention on climate change", "ball roadmap", 
                    "greenhouse gas", "ghg", "greenhouse effect", "ipcc", "climate mitigation", "climate action", "emissions", "temperature", "extreme weather", 
                    "global environmental change", "climate variability", "greenhouse", "low carbon", "ghge", "renewable energy", "carbon emission",
                    "co2", "climate pollutant", "climate pollutants", "carbon tax", "carbon footprint", "carbon neutrality", "net-zero", "net zero", "climate crisis",
                    "climate crisis", "climate summit", "climate catastrophe", "climate justice", "climate emergency", 
                    ]

len(climate_keywords)
# Out:
# 43

# %%
# This bigger dictionary can be used later for the the ClimateBERT
climate_keywords_dict = {
    # Core Climate Science
    "climate_science": [
        "climate change", "global warming", "global average temperature",
        "climate variability", "global environmental change", "greenhouse effect",
        "temperature", "extreme weather", "climate resilience"
    ],
    
    # Carbon & CO2
    "carbon": [
        "carbon dioxide", "co2", "low carbon", "carbon emission",
        "carbon tax", "carbon footprint", "carbon neutrality",
        "net-zero", "net zero"
    ],
    
    # Greenhouse Gases
    "greenhouse_gases": [
        "greenhouse gas", "ghg", "ghge", "greenhouse", "climate pollutant",
        "climate pollutants"
    ],
    
    # Climate Policy & Agreements
    "climate_policy": [
        "paris accord", "kyoto protocol", "unfccc",
        "framework convention on climate change", "climate politics",
        "cap and trade", "emissions trading scheme", "carbon tax",
        "climate mitigation", "climate action"
    ],
    
    # Institutions & Reports
    "institutions": [
        "ipcc", "ball roadmap"
    ],
    
    # Energy & Emissions
    "energy_emissions": [
        "emissions", "renewable energy", "carbon emission"
    ]
}

# %%
def extract_keyword_info(text, keywords):
    """
    Extracts climate-related keyword information from a text string.

    Parameters:
        text (str): The speech or text in which to search for keywords.
        keywords (list of str): A list of climate-related keywords or phrases to match against the text.
    """
    matches = []
    for kw in keywords:
        pattern = r'\b' + re.escape(kw) + r's?\b'  # Now accounts for plural forms
        if re.search(pattern, text, flags=re.IGNORECASE):
            matches.append(kw)
    contains_keyword = len(matches) > 0
    return pd.Series([matches, contains_keyword])

# %%
final_df[['matched_climate_keywords', 'contains_climate_keyword']] = final_df['speeches_for_keyword_search'].apply(
    lambda text: extract_keyword_info(text, climate_keywords)
)

final_df
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      NZL
# 1          45  1990      EGY
# 2          45  1990      CPV
# 3          45  1990      UGA
# 4          45  1990      NLD
# ...       ...   ...      ...
# 6434       79  2024      CIV
# 6435       79  2024      HND
# 6436       79  2024      MKD
# 6437       79  2024      KOR
# 6438       79  2024      SGP
#
#                                                  Speech  number_sentences  \
# 0     ﻿\nI should like to congratulate you, Sir, on ...               145
# 1     ﻿First of all, I would like to extend may dele...                76
# 2     ﻿I should like to begin by offering Mr. de Mar...                71
# 3     ﻿In 1967, I had the privilege of addressing th...               132
# 4     ﻿\nMay I, first of all, extend to Mr. de Marco...               167
# ...                                                 ...               ...
# 6434  Mr President of the 79th Session of the United...                41
# 6435  Madam President of this General Assembly,  \nM...                54
# 6436  Distinguished President of the United Nations ...               101
# 6437  Mr. President,\nMr. Secretary-General,\nDistin...                31
# 6438  Mdm President, Your Excellencies \n  \n  \n1 I...               100
#
#       number_tokens  Income Level  \
# 0              3512             4
# 1              2532             1
# 2              2432             2
# 3              3508             1
# 4              4134             4
# ...             ...           ...
# 6434           1206             2
# 6435           1367             2
# 6436           2804             3
# 6437            821             4
# 6438           2208             4
#
#                             speeches_for_keyword_search  \
# 0     I should like to congratulate you, Sir, on you...
# 1     First of all, I would like to extend may deleg...
# 2     I should like to begin by offering Mr. de Marc...
# 3     In 1967, I had the privilege of addressing thi...
# 4     May I, first of all, extend to Mr. de Marco my...
# ...                                                 ...
# 6434  Ladies and Gentlemen, Heads of State and Gover...
# 6435  Madam President of this General Assembly, Mr. ...
# 6436  Ladies and Gentlemen, Being invited to address...
# 6437  Mr. President, Mr. Secretary-General, Distingu...
# 6438  Excellencies 1 I bring you greetings from a ti...
#
#                                matched_climate_keywords  \
# 0     [climate change, greenhouse gas, emissions, gr...
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 6434   [climate change, global warming, climate action]
# 6435                                                 []
# 6436  [climate change, greenhouse gas, climate actio...
# 6437                                                 []
# 6438              [climate change, emissions, net-zero]
#
#       contains_climate_keyword
# 0                         True
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 6434                      True
# 6435                     False
# 6436                      True
# 6437                     False
# 6438                      True
#
# [6439 rows x 10 columns]

# %%
# Define climate-related keywords (add variants as needed)
# keywords = ['CO2', 'carbon dioxide', 'emissions', 'greenhouse gas', 'GHG', 'climate change']

climate_keywords = ["climate change", "global warming", "cap and trade", "unfccc", "paris accord", "emissions trading scheme", "global average temperature",
                    "kyoto protocol", "climate resilience", "carbon dioxide", "climate politics", "framework convention on climate change", "ball roadmap", 
                    "greenhouse gas", "ghg", "greenhouse effect", "ipcc", "climate mitigation", "climate action", "emissions", "temperature", "extreme weather", 
                    "global environmental change", "climate variability", "greenhouse", "low carbon", "ghge", "renewable energy", "carbon emission",
                    "co2", "climate pollutant", "climate pollutants", "carbon tax", "carbon footprint", "carbon neutrality", "net-zero", "net zero"
                    ]

# Create a regex pattern to match any keyword
pattern = re.compile('|'.join(map(re.escape, climate_keywords)), flags=re.IGNORECASE)

# Filter rows where speeches contain any keyword
climate_speeches = final_df[final_df['speeches_for_keyword_search'].str.contains(pattern, na=False)]
climate_speeches
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      NZL
# 12         45  1990      ITA
# 17         45  1990      FJI
# 19         45  1990      PNG
# 23         45  1990      FIN
# ...       ...   ...      ...
# 6431       79  2024      CHE
# 6432       79  2024      CUB
# 6434       79  2024      CIV
# 6436       79  2024      MKD
# 6438       79  2024      SGP
#
#                                                  Speech  number_sentences  \
# 0     ﻿\nI should like to congratulate you, Sir, on ...               145
# 12    ﻿Sir, on taking the floor on behalf of the Eur...               151
# 17    ﻿\nMr. President it gives me great pleasure to...               101
# 19    ﻿On behalf of the Government and people\nof Pa...               113
# 23    ﻿\nI take great pleasure in seeing you, Sir, a...                92
# ...                                                 ...               ...
# 6431  Mr President\nSecretary-General\nExcellencies\...                66
# 6432  **Mr President,**  \n**Mr Secretary-General,**...                76
# 6434  Mr President of the 79th Session of the United...                41
# 6436  Distinguished President of the United Nations ...               101
# 6438  Mdm President, Your Excellencies \n  \n  \n1 I...               100
#
#       number_tokens  Income Level  \
# 0              3512             4
# 12             4568             4
# 17             2666             2
# 19             2923             2
# 23             2080             4
# ...             ...           ...
# 6431           1314             4
# 6432           2433             3
# 6434           1206             2
# 6436           2804             3
# 6438           2208             4
#
#                             speeches_for_keyword_search  \
# 0     I should like to congratulate you, Sir, on you...
# 12    Sir, on taking the floor on behalf of the Euro...
# 17    President of the General Assembly at its forty...
# 19    On behalf of the Government and people of Papu...
# 23    I take great pleasure in seeing you, Sir, a di...
# ...                                                 ...
# 6431  Ladies and gentlemen On the morning of 3 March...
# 6432  Mr President, Mr Secretary-General, Let me beg...
# 6434  Ladies and Gentlemen, Heads of State and Gover...
# 6436  Ladies and Gentlemen, Being invited to address...
# 6438  Excellencies 1 I bring you greetings from a ti...
#
#                                matched_climate_keywords  \
# 0     [climate change, greenhouse gas, emissions, gr...
# 12                                                   []
# 17                                     [global warming]
# 19                      [greenhouse effect, greenhouse]
# 23                          [carbon dioxide, emissions]
# ...                                                 ...
# 6431                                   [climate change]
# 6432  [climate change, global average temperature, t...
# 6434   [climate change, global warming, climate action]
# 6436  [climate change, greenhouse gas, climate actio...
# 6438              [climate change, emissions, net-zero]
#
#       contains_climate_keyword
# 0                         True
# 12                       False
# 17                        True
# 19                        True
# 23                        True
# ...                        ...
# 6431                      True
# 6432                      True
# 6434                      True
# 6436                      True
# 6438                      True
#
# [3194 rows x 10 columns]

# %%
climate_speeches = pd.read_csv(base_path + "climate_speeches.csv")

# %%
from nltk.tokenize import sent_tokenize
# Function to extract sentences containing climate-related keywords
def extract_climate_sentences(text):
    if not isinstance(text, str):
        return []
    sentences = sent_tokenize(text)
    return [s for s in sentences if any(kw in s.lower() for kw in climate_keywords)]

climate_speeches['climate_sentences'] = climate_speeches['speeches_for_keyword_search'].apply(extract_climate_sentences)

# %%
# Drop the speeches that don't talk about climate change
climate_speeches = climate_speeches[climate_speeches['contains_climate_keyword']]

# %%
from nltk.tokenize import sent_tokenize


def extract_climate_sentences(text):
    if not isinstance(text, str):
        return []
    sentences = sent_tokenize(text)
    return [s for s in sentences if any(kw in s.lower() for kw in climate_keywords)]

climate_speeches['climate_sentences'] = climate_speeches['speeches_for_keyword_search'].apply(extract_climate_sentences)
climate_speeches
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      NZL
# 2          45  1990      FJI
# 3          45  1990      PNG
# 4          45  1990      FIN
# 5          45  1990      DEU
# ...       ...   ...      ...
# 3189       79  2024      CHE
# 3190       79  2024      CUB
# 3191       79  2024      CIV
# 3192       79  2024      MKD
# 3193       79  2024      SGP
#
#                                                  Speech  number_sentences  \
# 0     ﻿\nI should like to congratulate you, Sir, on ...               145
# 2     ﻿\nMr. President it gives me great pleasure to...               101
# 3     ﻿On behalf of the Government and people\nof Pa...               113
# 4     ﻿\nI take great pleasure in seeing you, Sir, a...                92
# 5     ﻿I wish first of all to offer you, Mr. Preside...               292
# ...                                                 ...               ...
# 3189  Mr President\nSecretary-General\nExcellencies\...                66
# 3190  **Mr President,**  \n**Mr Secretary-General,**...                76
# 3191  Mr President of the 79th Session of the United...                41
# 3192  Distinguished President of the United Nations ...               101
# 3193  Mdm President, Your Excellencies \n  \n  \n1 I...               100
#
#       number_tokens  Income Level  \
# 0              3512             4
# 2              2666             2
# 3              2923             2
# 4              2080             4
# 5              6149             4
# ...             ...           ...
# 3189           1314             4
# 3190           2433             3
# 3191           1206             2
# 3192           2804             3
# 3193           2208             4
#
#                             speeches_for_keyword_search  \
# 0     I should like to congratulate you, Sir, on you...
# 2     President of the General Assembly at its forty...
# 3     On behalf of the Government and people of Papu...
# 4     I take great pleasure in seeing you, Sir, a di...
# 5     Mr. President, my warm congratulations on your...
# ...                                                 ...
# 3189  Ladies and gentlemen On the morning of 3 March...
# 3190  Mr President, Mr Secretary-General, Let me beg...
# 3191  Ladies and Gentlemen, Heads of State and Gover...
# 3192  Ladies and Gentlemen, Being invited to address...
# 3193  Excellencies 1 I bring you greetings from a ti...
#
#                                matched_climate_keywords  \
# 0     ['climate change', 'greenhouse gas', 'emission...
# 2                                    ['global warming']
# 3                   ['greenhouse effect', 'greenhouse']
# 4                       ['carbon dioxide', 'emissions']
# 5     ['carbon dioxide', 'greenhouse effect', 'emiss...
# ...                                                 ...
# 3189                                 ['climate change']
# 3190  ['climate change', 'global average temperature...
# 3191  ['climate change', 'global warming', 'climate ...
# 3192  ['climate change', 'greenhouse gas', 'climate ...
# 3193        ['climate change', 'emissions', 'net-zero']
#
#       contains_climate_keyword  \
# 0                         True
# 2                         True
# 3                         True
# 4                         True
# 5                         True
# ...                        ...
# 3189                      True
# 3190                      True
# 3191                      True
# 3192                      True
# 3193                      True
#
#                                       climate_sentences
# 0     [But many of those are small islands, atoll co...
# 2     [The effects of global warming, especially on ...
# 3     [We are greatly concerned that, in spite of om...
# 4     [I am thinking, for example, of policies to re...
# 5     [Another key problem is the changing of the wo...
# ...                                                 ...
# 3189  [Climate change and loss of biodiversity are h...
# 3190  [Climate change is advancing inexorably., In J...
# 3191  [Mr President, The progress achieved by our co...
# 3192  [With the alarming level of greenhouse gas emi...
# 3193  [On almost every issue confronting the world –...
#
# [3186 rows x 11 columns]

# %%
climate_speeches[(climate_speeches['Income Level'] == 1) & (climate_speeches['Year'] == 2019)]
# Out:
#       Session  Year ISO-Code  \
# 2213       74  2019      RWA
# 2216       74  2019      ETH
# 2221       74  2019      BDI
# 2224       74  2019      MLI
# 2226       74  2019      NER
# 2266  President of the General Assembly at its seven...
# 2271  President of the General Assembly at its seven...
# 2278  I am honoured, on this occasion, to represent ...
# 2287  It is a pleasure for me at the outset to exten...
# 2294  The current General Assembly meeting is occurr...
# 2320  On behalf of His Excellency President Adama Ba...
# 2332  At the outset, on behalf of myself and my dele...
# 2336  I wish to congratulate Mr. Tijjani Muhammad-Ba...
# 2338  President of the General Assembly at its seven...
# 2341  President of the General Assembly at its seven...
# 2346  President of the General Assembly at its seven...
# 2351  I am honoured to address the General Assembly ...
# 2364  It is a great honour and privilege to address ...
# 2374  At the outset, I wish to convey the warmest co...
# 2378  Mr. President, on your election to lead the As...
# 2379  It is my distinct honour and privilege to take...
#
#                                matched_climate_keywords  \
# 2213  ['climate change', 'global warming', 'climate ...
# 2216               ['climate change', 'climate action']
# 2221  ['climate change', 'climate action', 'climate ...
# 2224               ['climate change', 'climate action']
# 2226  ['climate change', 'climate action', 'emission...
# 2228               ['climate change', 'climate action']
# 2240  ['climate change', 'framework convention on cl...
# 2247  ['climate change', 'climate action', 'renewabl...
# 2249  ['climate change', 'emissions', 'temperature',...
# 2257  ['climate change', 'framework convention on cl...
# 2261                                 ['climate change']
# 2266               ['climate change', 'climate action']
# 2271                                 ['climate action']
# 2278  ['climate change', 'emissions', 'temperature',...
# 2287  ['climate change', 'global warming', 'framewor...
# 2294                                 ['climate change']
# 2320  ['climate change', 'climate action', 'extreme ...
# 2332  ['climate change', 'greenhouse gas', 'climate ...
# 2336  ['climate change', 'climate action', 'extreme ...
# 2338  ['climate change', 'climate action', 'emission...
# 2341                    ['climate change', 'emissions']
# 2346                                 ['climate change']
# 2351               ['climate change', 'climate action']
# 2364  ['climate change', 'climate action', 'temperat...
# 2374                                 ['climate action']
# 2378                                 ['climate action']
# 2379  ['climate change', 'global warming', 'climate ...
#
#       contains_climate_keyword  \
# 2213                      True
# 2216                      True
# 2221                      True
# 2224                      True
# 2226                      True
# 2228                      True
# 2240                      True
# 2247                      True
# 2249                      True
# 2257                      True
# 2261                      True
# 2266                      True
# 2271                      True
# 2278                      True
# 2287                      True
# 2294                      True
# 2320                      True
# 2332                      True
# 2336                      True
# 2338                      True
# 2341                      True
# 2346                      True
# 2351                      True
# 2364                      True
# 2374                      True
# 2378                      True
# 2379                      True
#
#                                       climate_sentences
# 2213  [Never before have we had such well-defined ro...
# 2216  [Climate change is real and poses a real threa...
# 2221  [The great qualities and skills that we all re...
# 2224  [This is particularly true with regard to the ...
# 2226  [The theme of this year’s session, “Galvanizin...
# 2228  [The theme he has selected for this session — ...
# 2240  [I congratulate you, Mr. President, on assumin...
# 2247  [The theme of the current session, “Galvanizin...
# 2249  [However, we are also dealing with an array of...
# 2257  [The seventy-fourth session is being held at a...
# 2261  [Indeed, the threats of climate change, terror...
# 2266  [This year’s seventy-fourth session is being h...
# 2271  [The theme of the general debate for this sess...
# 2278  [Of course, we are committed to marshalling ou...
# 2287  [We live in a world that is replete with of ch...
# 2294  [Eritrea’s soil and water conservation strateg...
# 2320  [The theme that the President has chosen for o...
# 2332  [The theme of this session of the General Asse...
# 2336  [I also commend the Secretary-General, Mr. Ant...
# 2338  [Evidently, the scale and acuteness of these n...
# 2341  [Setting our world on a sustainable course req...
# 2346  [We have declared war on poverty, education in...
# 2351  [Trade protectionism and climate change are ha...
# 2364  [It is indeed my sincere belief that the Gener...
# 2374  [I am pleased to note that this session’s gene...
# 2378  [We support the theme of the current session, ...
# 2379  [The seventy-fourth session takes place at a t...

# %% [markdown]
# # Climate BERT

# %%
! pip install transformers sentence-transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting sentence-transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (3.17.0)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Using cached huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_10_12_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.2.0)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub<1.0,>=0.30.0->transformers)
#   Using cached hf_xet-1.1.3-cp37-abi3-macosx_10_12_x86_64.whl.metadata (879 bytes)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/deepl/lib/python3.12/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 979.5 kB/s eta 0:00:0000:0100:01
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Downloading safetensors-0.5.3-cp38-abi3-macosx_10_12_x86_64.whl (436 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.0 MB/s eta 0:00:00a 0:00:01
# Downloading hf_xet-1.1.3-cp37-abi3-macosx_10_12_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 973.7 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: safetensors, hf-xet, huggingface-hub, tokenizers, transformers, sentence-transformers
# Successfully installed hf-xet-1.1.3 huggingface-hub-0.33.0 safetensors-0.5.3 sentence-transformers-4.1.0 tokenizers-0.21.1 transformers-4.52.4

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import torch

# Load ClimateBERT
tokenizer = AutoTokenizer.from_pretrained("Climatebert/distilroberta-base-climate-f")
model = AutoModel.from_pretrained("Climatebert/distilroberta-base-climate-f")

# Define concept vocabularies
concepts = {
    "climate": ["climate change", "climate action", "the climate"],
    "emissions": ["emissions", "dangerous emissions", "carbon emissions"]
}

# Function to get embedding of a sentence
def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# Function to get average concept embedding from sentence list
def compute_concept_embedding(sentences, concept_terms):
    filtered = [s for s in sentences if any(term in s.lower() for term in concept_terms)]
    if not filtered:
        return None
    embeddings = [get_sentence_embedding(s) for s in filtered]
    return np.mean(embeddings, axis=0)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at Climatebert/distilroberta-base-climate-f and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # Trying Embeddings on a small subset

# %%
# Picking up two countries of the same income level
countries = ['GMB','ESP']  # Example from Income Level 1
years = [2015, 2019]         # Short range for simplicity

subset_embeddings = climate_speeches[
    (climate_speeches['ISO-Code'].isin(countries)) &
    (climate_speeches['Year'].isin(years)) &
    (climate_speeches['contains_climate_keyword'])
].copy()

# %%
subset_embeddings.iloc[0]['climate_sentences']
# Out:
# ['To begin with, protecting our environment must emphatically remain a major priority for this global body because registered climate changes over the course of history have significantly impacted negatively on our planet Earth and demand our immediate and permanent attention.',
#  '“This body must act with greater commitment and resolve to establish sustainable conservation programmes, with production patterns aimed at effectively combating climate change, restoring our ecosystems, promoting forest management and reversing desertification and land degradation.']

# %%
subset_embeddings.iloc[1]['climate_sentences']
# Out:
# ['I am thinking of the challenge of climate change.']

# %%
# Parse climate sentences
import ast
subset_embeddings['climate_sentences'] = subset_embeddings['climate_sentences'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

tokenizer = AutoTokenizer.from_pretrained("climatebert/distilroberta-base-climate-f")
model = AutoModel.from_pretrained("climatebert/distilroberta-base-climate-f")

def get_sentence_embedding(sentence):
    inputs = tokenizer(sentence, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

def get_document_embedding(sentences):
    if not isinstance(sentences, list) or len(sentences) == 0:
        return None
    embeddings = [get_sentence_embedding(s) for s in sentences]
    return np.mean(embeddings, axis=0)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at climatebert/distilroberta-base-climate-f and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Apply document level embedding
subset_embeddings['climate_embedding'] = subset_embeddings['climate_sentences'].apply(get_document_embedding)

# %%
# Aggregate to Country-Year Level
agg = subset_embeddings.dropna(subset=['climate_embedding']).groupby(['ISO-Code', 'Year'])['climate_embedding'].apply(
    lambda vecs: np.mean(np.stack(vecs), axis=0)
).reset_index()

# %%
agg.iloc[0]['climate_embedding']
# Out:
# array([ 6.28137961e-02, -1.26688816e-02,  7.72315189e-02, -2.70027295e-02,
#         5.73057711e-01, -1.10701799e-01,  3.09718046e-02,  6.61706254e-02,
#         1.35978445e-01, -4.94874306e-02, -6.62455186e-02,  6.69420511e-02,
#        -1.85810849e-02, -6.94348589e-02,  7.77413324e-02,  2.88998932e-01,
#        -1.66073497e-02,  6.12636916e-02,  1.00362957e-01, -1.55157745e-01,
#        -3.70285213e-02,  2.85723228e-02,  5.11427037e-02, -1.08260699e-02,
#        -3.84135805e-02,  6.49955496e-02,  1.29769864e-02,  3.76029871e-02,
#         1.74974967e-02,  9.30849090e-03, -1.35733604e-01, -1.05362304e-01,
#         7.95035735e-02,  4.28649150e-02, -3.65385860e-02,  7.50335827e-02,
#         6.43023774e-02, -1.50109544e-01,  1.98140979e-01,  1.18922018e-01,
#         1.97497327e-02, -2.35543981e-01,  5.79413362e-02,  1.04218625e-01,
#        -6.28283992e-02,  7.23872408e-02, -1.63482100e-01, -7.74684474e-02,
#         8.08516145e-02, -5.01379669e-02, -1.25766128e-01,  1.41181901e-01,
#        -3.02212294e-02, -1.36760697e-02, -3.13318893e-02, -4.30537201e-02,
#         4.02977131e-02,  2.93128699e-01,  1.08398348e-01, -1.36012537e-02,
#        -2.31796759e-03, -1.49978563e-01, -3.60401645e-02,  6.91572055e-02,
#         4.56531942e-02,  5.94594367e-02,  1.50684798e-02,  1.30855208e-02,
#         3.61630716e-03,  1.98500827e-01,  3.53349112e-02, -1.11495890e-01,
#         7.28266016e-02,  2.24561080e-01,  3.45721543e-02,  2.86506295e-01,
#        -6.78283125e-02, -3.69764900e+00, -8.98231342e-02,  8.28642305e-03,
#         5.29036224e-02, -1.59106568e-01,  7.28444993e-01, -1.74526155e-01,
#         1.75540432e-01, -4.89172749e-02,  3.01520973e-02, -7.23978356e-02,
#        -9.18994751e-03, -1.39373159e-02,  1.58755541e-01, -3.26844980e-03,
#         3.41403633e-02,  7.79287517e-02,  1.65125847e-01,  8.18867907e-02,
#        -3.60068493e-02,  9.64300871e-01,  9.99873877e-02, -7.49734566e-02,
#         1.18588321e-01, -6.58797740e-04, -9.51630548e-02,  1.89696983e-01,
#         1.40631869e-01, -6.31911606e-02, -8.20349827e-02, -1.32248729e-01,
#        -1.19344676e-02, -9.81644914e-02, -2.51366887e-02, -1.17986880e-01,
#         2.79795956e-02,  5.01299612e-02,  4.46813889e-02, -4.81787175e-02,
#         1.74571052e-01,  1.75599054e-01,  4.98598963e-02, -2.53331196e-02,
#         3.76169570e-02,  4.36088182e-02,  6.72853738e-02,  3.97257060e-02,
#         1.58951178e-01,  6.29566088e-02, -2.02808365e-01, -4.65401262e-02,
#         1.35238752e-01,  5.59701137e-02,  4.81731705e-02,  4.06585913e-03,
#        -6.19684458e-02,  3.53817386e-03, -4.87709492e-02, -4.06628773e-02,
#        -8.14176574e-02,  5.75516932e-02, -1.18167132e-01,  2.50643305e-03,
#         7.20974281e-02, -5.35039790e-02,  8.52713920e-03, -1.12677507e-01,
#        -3.40989418e-02,  8.47522318e-02,  6.16331294e-04,  9.02301148e-02,
#        -1.50667354e-02, -2.12018609e-01,  1.10496789e-01, -7.39283860e-06,
#         1.08913668e-01,  2.09935512e-02,  1.23590901e-02,  4.64700582e-03,
#        -9.44889709e-02, -2.31281757e-01,  7.54700042e-03, -6.65676415e-01,
#        -1.55641809e-01, -8.64523575e-02,  1.56206816e-01,  2.23884702e-01,
#         8.69404972e-02, -6.08356157e-03,  7.46235773e-02,  2.11486723e-02,
#        -4.52980362e-02, -4.56732810e-02, -1.14892215e-01, -3.84726040e-02,
#        -4.31264304e-02,  1.97262332e-01, -8.81813094e-02,  3.27307545e-02,
#        -2.72187412e-01,  1.25868118e-03,  1.00804090e-01, -2.13300213e-01,
#         2.68958360e-01,  3.50248776e-02, -5.16296178e-02, -2.27206051e-02,
#         1.27925083e-01, -6.23815060e-02, -1.77897289e-01,  3.72284092e-02,
#        -7.21695572e-02, -6.46498054e-02, -1.49823472e-01,  9.26158950e-02,
#         2.53878862e-01,  1.00565456e-04, -5.79675473e-02, -3.05150747e-02],
#       dtype=float32)

# %%
# Compare country embeddings using cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

# Make matrix of embeddings
embedding_matrix = np.stack(agg['climate_embedding'].values)

# Compute cosine similarity between country-year entries
similarity_matrix = cosine_similarity(embedding_matrix)

# Attach labels
labels = agg['ISO-Code'] + "_" + agg['Year'].astype(str)
sim_df = pd.DataFrame(similarity_matrix, index=labels, columns=labels)

# %%
print(sim_df.round(2))
# Out:
#           ESP_2015  ESP_2019  GMB_2015  GMB_2019
# ESP_2015      1.00      0.97      0.95      0.97
# ESP_2019      0.97      1.00      0.99      1.00
# GMB_2015      0.95      0.99      1.00      0.99
# GMB_2019      0.97      1.00      0.99      1.00

# %% [markdown]
# ## Example of usage of embeddings

# %%
sample_sentences = [
    "We must act urgently to address climate change and protect future generations.",
    "Carbon emissions have reached dangerous levels.",
    "Climate action must be fair and equitable.",
    "We pledge to reduce emissions by 40% by 2030."
]

# Compute concept embeddings
climate_emb = compute_concept_embedding(sample_sentences, concepts["climate"])
emissions_emb = compute_concept_embedding(sample_sentences, concepts["emissions"])

# Compare the two with cosine similarity
similarity = cosine_similarity([climate_emb], [emissions_emb])[0][0]
print(f"Cosine similarity between 'climate' and 'emissions': {similarity:.4f}")
# Out:
# Cosine similarity between 'climate' and 'emissions': 0.9772
