# %%
import nltk
# nltk.download('averaged_perceptron_tagger_eng')
# nltk.download('punt_tab')

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# from textblob import TextBlob
from pathlib import Path
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import contractions
from nltk import pos_tag
from nltk.corpus import stopwords
import matplotlib.ticker as ticker
import re

# %%
import ast
import pandas as pd

def clean_list_column(df, column_name):
    """
    Converts stringified lists in a column to real lists and lowercases each string element.
    
    Parameters:
        df (pd.DataFrame): The DataFrame containing the column.
        column_name (str): The name of the column to clean.
    
    Returns:
        pd.DataFrame: A copy of the DataFrame with the cleaned column.
    """
    # df = df.copy()
    
    # Convert stringified lists to real lists
    df[column_name] = df[column_name].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
    )

    
    return df

# %%
def ensure_list(x):
    if isinstance(x, list):
        return x
    else:
        raise ValueError(f"Expected list, got {type(x)}")

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# %% [markdown]
# # Step 1: Load the speeches

# %%
# Climate keyword according to the literature
climate_keywords = ["climate change", "global warming", "global warm","cap and trade", "paris accord", "emissions trading", "global average temperature", 
                      "kyoto protocol", "climate resilience", "carbon dioxide", "climate politics", "framework convention on climate change", "ball roadmap",
                      "greenhouse gas", "greenhouse effect", "climate mitigation", "climate action", "emissions", "temperature", "extreme weather", 
                      "global environmental change", "global environment", "global environmental" ,"climate variability", "low carbon", "renewable energy", 
                      "carbon emission", "climate pollutant", "climate pollutants", "carbon tax", "carbon footprint", "carbon neutrality", "net-zero", 
                      "net zero", "climate crisis", "climate summit", "climate catastrophe", "climate justice", "climate emergency", "climate funding",
                      "climate fund", "climate financing", "climate finance","climate peace", "climate agreement", "climate security", "climate ambition", 
                      "climate issue", "climate impact", "climate conference", "climate event", "climate challenge", "climate trust", "climate negotiation", 
                      "climate catastrophe", "climate risk", "climate goal", "climate change-related", "climate regime", "climate resilient", "climate policy", 
                      "carbon market", "carbon sink", "green climate", "green economy", "emission reduction", "emissions reduction", "carbon neutral", 
                      "carbon sink", "ozone layer", "unfccc", "emissions trading scheme", "ghg", "ghge", "co2", "ipcc"]


climate_keywords_dict = {
    # 1. Climate Science & Impacts
    "science_impacts": [
        "climate change", "global warm", "global warming", "global average temperature",
        "climate variability", "extreme weather", "climate impact",
        "greenhouse effect", "temperature", "climate catastrophe",
        "climate risk", "ozone layer", "global environmental change",
        "global environmental", "global environment", 
        "climate change-related", "climate risk"
    ],

    # 2. Policy & Agreements
    "policy_agreements": [
        "paris accord", "kyoto protocol", "unfccc", "climate policy",
        "framework convention on climate change", "climate agreement",
        "climate regime", "climate negotiation", "climate ambition",
        "climate security", "ball roadmap", "ipcc"
    ],

    # 3. Carbon & Emissions
    "carbon_emissions": [
        "carbon dioxide", "co2", "carbon emission", "carbon tax",
        "carbon footprint", "carbon neutrality", "carbon neutral",
        "carbon market", "carbon sink", "low carbon", "emissions",
        "emission reduction", "emissions reduction", "ghg", "ghge",
        "climate pollutant", "climate pollutants", "carbon neutral",
        "greenhouse gas"
    ],

    # 4. Climate Action & Solutions
    "action_solutions": [
        "climate action", "climate mitigation", "renewable energy",
        "climate resilience", "climate resilient", "green economy",
        "climate funding", "climate fund", "climate financing", "climate finance",
        "net-zero", "net zero", "green climate", "cap and trade",
        "emissions trading scheme", "emissions trading"
    ],

    # 5. Sociopolitical Climate Issues
    "sociopolitical": [
        "climate justice", "climate emergency", "climate crisis",
        "climate summit", "climate politics", "climate peace",
        "climate challenge", "climate goal", "climate issue",
        "climate event", "climate conference", "climate trust"
    ]
}

# %%
base_path_alvaro = Path(r"C:\Users\Alvaro Millan Ruiz\OneDrive\Escritorio\BDS\Block_5\NLP\Project")
base_path_gilda = "/Users/szonjapike/Desktop/BDS/Block_5/NLP/TXT/"

base_path = base_path_alvaro # change according to user

# %%
final_df = pd.read_csv(base_path / "df_sentiment_analysis_extended.csv")
final_df = final_df.drop(columns=["matched_climate_keywords", "contains_climate_keyword", "cat_policy_agreements", "cat_carbon_emissions", "cat_action_solutions", "cat_sociopolitical", "climate_sentences", "cat_science_impacts"])
final_df
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      ATG
# 1          45  1990      AUS
# 2          45  1990      AUT
# 3          45  1990      BFA
# 4          45  1990      BGD
# ...       ...   ...      ...
# 3369       79  2024      WSM
# 3370       79  2024      YEM
# 3371       79  2024      ZAF
# 3372       79  2024      ZMB
# 3373       79  2024      ZWE
#
#                                                  Speech  number_sentences  \
# 0     ﻿Please accept my country's congratulations, S...               115
# 1     ﻿It is with great pleasure. Sir, that I congra...               162
# 2     ﻿\n\nI am pleased, Sir, to congratulate you on...               162
# 3     ﻿\nMr. President, events in Eastern and Centra...                91
# 4     ﻿\nMr. President, warm felicitations are due y...               180
# ...                                                 ...               ...
# 3369  Excellencies,  \nI extend my congratulations t...                68
# ...

# %%
df = clean_list_column(final_df, 'climate_sentences_extended')
df = clean_list_column(df, 'cat_extended_policy_agreements')
df = clean_list_column(df, 'cat_extended_science_impacts')
df = clean_list_column(df, 'cat_extended_carbon_emissions')
df = clean_list_column(df, 'cat_extended_action_solutions')
df
# Out:
#       Session  Year ISO-Code  \
# 0          45  1990      ATG
# 1          45  1990      AUS
# 2          45  1990      AUT
# 3          45  1990      BFA
# 4          45  1990      BGD
# ...       ...   ...      ...
# 3369       79  2024      WSM
# 3370       79  2024      YEM
# 3371       79  2024      ZAF
# 3372       79  2024      ZMB
# 3373       79  2024      ZWE
#
#                                                  Speech  number_sentences  \
# 0     ﻿Please accept my country's congratulations, S...               115
# 1     ﻿It is with great pleasure. Sir, that I congra...               162
# 2     ﻿\n\nI am pleased, Sir, to congratulate you on...               162
# 3     ﻿\nMr. President, events in Eastern and Centra...                91
# 4     ﻿\nMr. President, warm felicitations are due y...               180
# ...                                                 ...               ...
# 3369  Excellencies,  \nI extend my congratulations t...                68
# ...

# %% [markdown]
# # 4. Transformers

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import torch

# Load ClimateBERT
tokenizer = AutoTokenizer.from_pretrained("Climatebert/distilroberta-base-climate-f")
model = AutoModel.from_pretrained("Climatebert/distilroberta-base-climate-f")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at Climatebert/distilroberta-base-climate-f and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Get document embedding

# %%
# Sentence-level embedding
# def get_sentence_embedding(text):
#     inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
#     with torch.no_grad():
#         outputs = model(**inputs)
#     return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# # potential issue — if you don’t mask out the padding tokens, their embeddings (which are mostly zeros or neutral vectors) will dilute the real signal.
# You're averaging all token embeddings, including padding — unless you use the attention mask to filter them out.
def get_sentence_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=511)
    with torch.no_grad():
        outputs = model(**inputs)

    token_embeddings = outputs.last_hidden_state.squeeze(0)
    attention_mask = inputs['attention_mask'].squeeze(0)
    valid_embeddings = token_embeddings[attention_mask.bool()]
    return valid_embeddings.mean(dim=0).numpy()


def chunk_text(text, max_tokens=511):
    tokens = tokenizer.tokenize(text)
    chunks = [" ".join(tokens[i:i+max_tokens]) for i in range(0, len(tokens), max_tokens)]
    return [tokenizer.convert_tokens_to_string(tokenizer.tokenize(chunk)) for chunk in chunks]

def chunk_text(text, max_tokens=511):
    tokens = tokenizer.encode(text, add_special_tokens=False)  # list of token IDs (ints)
    chunks = [tokens[i:i+max_tokens] for i in range(0, len(tokens), max_tokens)]
    return [tokenizer.decode(chunk) for chunk in chunks]  # decode each list of token IDs back into a string


def get_long_text_embedding(text):
    chunks = chunk_text(text)
    embeddings = [get_sentence_embedding(chunk) for chunk in chunks]
    return np.mean(embeddings, axis=0) if embeddings else None

# Get average embedding for a list of sentences
def get_document_embedding(sentences):
    if not sentences:
        return None
    embeddings = [get_long_text_embedding(sent) for sent in sentences if sent.strip()]
    return np.mean(embeddings, axis=0) if embeddings else None

# %%
text = "Unpredictability in climate change-driven weather patterns is affecting food security."

token_ids = tokenizer.encode(text, add_special_tokens=False)
# e.g., [4895, 1999, 9711, 2689, 1011, 4011, 4638, 8092, 2833, 2003, 5833, 2833, 1012]

chunk_ids = token_ids[:8]
chunk = tokenizer.decode(chunk_ids)
# 'Unpredictability in climate change-driven weather'
print(f"Chunk: {chunk}")
# Out:
# Chunk: Unpredictability in climate change-

# %%
tokens = tokenizer.tokenize(text)
# ['un', '##predict', '##ability', 'in', 'climate', 'change', '-', 'driven', 'weather', 'patterns', 'is', 'affecting', 'food', 'security', '.']

joined = " ".join(tokens[:8])  # take first 8 tokens and join with space
# 'un ##predict ##ability in climate change - driven'

chunk = tokenizer.convert_tokens_to_string(tokenizer.tokenize(joined))
# 'unpredictability in climate change-driven'
print(f"Chunk: {chunk}")
# Out:
# Chunk: Un p redict ability Ġin Ġclimate Ġchange -

# %% [markdown]
# ## Get Keyword embedding

# %%
# Keyword embedding: average across all matches of that keyword in text
def get_keyword_embedding_from_sentences(sentences, keyword):
    # matches = [s for s in sentences if keyword in s.lower()]
    keyword_lower = keyword.lower().strip()
    seen = set()
    matches = []
    for paragraph in sentences:
        # Split paragraph into sentences based on punctuation
        split_sents = re.split(r'(?<=[.!?])\s+', paragraph)
        for sent in split_sents:
            if keyword_lower in sent.lower():
                if sent not in seen:
                    matches.append(sent)
                    seen.add(sent) 

    if not matches:
        return None
    embeddings = [get_long_text_embedding(s) for s in matches if s.strip()]
    return np.mean(embeddings, axis=0) if embeddings else None

# %% [markdown]
# # Income 1

# %%
df_1 = df[df['Income Level'] == 1]
df_1
# Out:
#       Session  Year ISO-Code  \
# 3          45  1990      BFA
# 4          45  1990      BGD
# 6          45  1990      CHN
# 8          45  1990      COD
# 20         45  1990      IND
# ...       ...   ...      ...
# 3350       79  2024      SYR
# 3351       79  2024      TCD
# 3352       79  2024      TGO
# 3363       79  2024      UGA
# 3370       79  2024      YEM
#
#                                                  Speech  number_sentences  \
# 3     ﻿\nMr. President, events in Eastern and Centra...                91
# 4     ﻿\nMr. President, warm felicitations are due y...               180
# 6     ﻿I should like to begin by warmly congratulati...               115
# 8     ﻿Mr. President, the forty-fifth session of the...                88
# 20    ﻿\nIt is with a deep sense of history that I a...               183
# ...                                                 ...               ...
# 3350  Your Excellency Philémon Yang, President of th...                78
# ...

# %%
doc_embeddings_by_year = []

# Wrap the groupby iterator with tqdm
for year, group in tqdm(df_1.groupby('Year'), desc="Processing years"):
    # Combine all climate sentences in the year across countries
    all_sentences = sum(group['climate_sentences_extended'].dropna().tolist(), [])
    
    emb = get_document_embedding(all_sentences)
    if emb is not None:
        doc_embeddings_by_year.append({
            'year': year,
            'embedding': emb
        })

pd.DataFrame(doc_embeddings_by_year).to_csv(base_path / "climate_sentences_embeddings_income_1.csv", index=False)
df_1_results = pd.DataFrame(doc_embeddings_by_year)
df_1_results
# Out:
# Processing years: 100%|██████████| 35/35 [02:26<00:00,  4.18s/it]
#     year                                          embedding
# 0   1990  [0.0484467, 0.06284331, 0.15418789, -0.1442476...
# 1   1991  [0.03896288, 0.06156079, 0.15986873, -0.169748...
# 2   1992  [0.06464172, 0.07060031, 0.15155809, -0.132438...
# 3   1993  [0.059180908, 0.061809994, 0.16026683, -0.1438...
# 4   1994  [0.046268575, 0.07281602, 0.1534081, -0.152766...
# 5   1995  [0.079599425, 0.052727044, 0.15894027, -0.1554...
# 6   1996  [0.078254886, 0.059046693, 0.14916505, -0.1703...
# 7   1997  [0.053070124, 0.040869173, 0.13706599, -0.1683...
# 8   1998  [0.038284067, 0.056499187, 0.14104912, -0.1030...
# 9   1999  [0.048365623, 0.072539225, 0.1654418, -0.09824...
# 10  2000  [0.039534964, 0.0695464, 0.12843657, -0.136196...
# 11  2001  [0.06531921, 0.04157539, 0.15670793, -0.110270...
# 12  2002  [0.039612316, 0.046635825, 0.13899621, -0.1516...
# 13  2003  [0.030649515, 0.046617277, 0.13450703, -0.1414...
# ...

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

years = df_1_results['year']
embeddings = np.stack(df_1_results['embedding'])

tsne = TSNE(n_components=2, random_state=42)
proj = tsne.fit_transform(embeddings)

plt.figure(figsize=(10,6))
scatter = plt.scatter(proj[:, 0], proj[:, 1], c=years, cmap='viridis')
plt.colorbar(scatter, label='Year')
plt.title("Climate Discourse Embeddings Over Time (Document-Level)")
plt.xlabel("TSNE-1")
plt.ylabel("TSNE-2")
plt.show()

# %%
keyword_embeddings_by_year = []

kws = ["climate change", "ozone layer", "greenhouse effect"]

for year, group in tqdm(df_1.groupby('Year'), desc="Processing years"):
    all_sentences = sum(group['climate_sentences_extended'].dropna().tolist(), [])

    for kw in kws:
        emb = get_keyword_embedding_from_sentences(all_sentences, kw)
        if emb is not None:
            keyword_embeddings_by_year.append({
                'year': year,
                'keyword': kw,
                'embedding': emb
            })
# Out:
# Processing years: 100%|██████████| 35/35 [01:06<00:00,  1.89s/it]

# %%
df_kw = pd.DataFrame(keyword_embeddings_by_year)
# get the average embedding for each keyword across all years
df_kw_avg = df_kw.groupby('keyword').agg({'embedding': lambda x: np.mean(np.stack(x), axis=0)}).reset_index()

perplexity = min(5, len(df_kw_avg) - 1)  # safe default

embs = np.stack(df_kw_avg['embedding'].values)
tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity)
proj = tsne.fit_transform(embs)

plt.figure(figsize=(10, 6))
plt.scatter(proj[:, 0], proj[:, 1], s=100, color='darkorange')

# Add labels
for i, kw in enumerate(df_kw_avg['keyword']):
    plt.text(proj[i, 0] + 0.5, proj[i, 1], kw, fontsize=9)

plt.title("t-SNE of Average Keyword Embeddings (Climate Discourse)", fontsize=14)
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

df_kw = pd.DataFrame(keyword_embeddings_by_year)
kw = "climate change"
df_kw_one = df_kw[df_kw['keyword'] == kw]

tsne = TSNE(n_components=2, random_state=42)
embs = np.stack(df_kw_one['embedding'].values)
proj = tsne.fit_transform(embs)

plt.figure(figsize=(10,6))
plt.scatter(proj[:, 0], proj[:, 1], c=df_kw_one['year'], cmap='plasma')
plt.colorbar(label='Year')
plt.title(f"Semantic Drift of '{kw}' Over Time")
plt.xlabel("TSNE-1")
plt.ylabel("TSNE-2")
for i, y in enumerate(df_kw_one['year']):
    plt.text(proj[i,0], proj[i,1], str(y), fontsize=8)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE
from adjustText import adjust_text  # pip install adjustText

combined_embeddings = []
labels = []
types = []  # "year" or "keyword"

# Add document embeddings
for item in doc_embeddings_by_year:
    combined_embeddings.append(item['embedding'])
    labels.append(str(item['year']))
    types.append("year")

for index, row in df_kw_avg.iterrows():
    combined_embeddings.append(row['embedding'])
    labels.append(row['keyword'])
    types.append("keyword")

# Recommended perplexity ranges based on your description:
if len(combined_embeddings) < 100:
    optimal_perplexity = min(5, len(combined_embeddings)//3)  # ~3-5
else:
    optimal_perplexity = 30  # Default for larger datasets

# Normalize and project
embeddings = np.stack(combined_embeddings)

tsne = TSNE(n_components=2, 
           perplexity=10,  # Using your working value
           early_exaggeration=12,  # Helps separate clusters
           learning_rate=1,  # Better for small perplexity
           random_state=42)

proj = tsne.fit_transform(embeddings)

# Prepare plot
plt.figure(figsize=(12, 8))
colors = {'year': 'tab:blue', 'keyword': 'tab:orange'}
markers = {'year': 'o', 'keyword': 's'}

# Plot by type
for t in set(types):
    mask = [typ == t for typ in types]
    plt.scatter(proj[mask, 0], proj[mask, 1], 
                color=colors[t], 
                marker=markers[t], 
                s=100, 
                label=t, 
                alpha=0.7)

# Add labels with anti-overlap
texts = []
for i, (x, y) in enumerate(proj):
    texts.append(plt.text(x+0.5, y, labels[i], fontsize=8))

plt.title("t-SNE: Climate Discourse (Years + Keywords)", fontsize=14)
plt.legend(title="Embedding Type")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Keyword embedding: average across all matches of that keyword in text
def get_keyword_embedding_from_sentences_tryout(sentences, keyword, year):
    # matches = [s for s in sentences if keyword in s.lower()]
    keyword_lower = keyword.lower().strip()
    seen = set()
    matches = []
    for paragraph in sentences:
        # Split paragraph into sentences based on punctuation
        split_sents = re.split(r'(?<=[.!?])\s+', paragraph)
        for sent in split_sents:
            if keyword_lower in sent.lower():
                if sent not in seen:
                    matches.append(sent)
                    seen.add(sent) 

    if not matches:
        return None
    # embeddings = [get_long_text_embedding(s) for s in matches if s.strip()]
    print(f"Keyword: {keyword}, Matches found: {len(matches)}, Year: {year}")
    return matches

# %%
keyword_embeddings_by_year = []

kws = ["climate change", "ozone layer", "greenhouse effect"]

for year, group in tqdm(df_1.groupby('Year'), desc="Processing years"):
    all_sentences = sum(group['climate_sentences_extended'].dropna().tolist(), [])

    for kw in kws:
        matches = get_keyword_embedding_from_sentences_tryout(all_sentences, kw, year)
        print(matches)
        break

    break
# Out:
# Processing years:   0%|          | 0/35 [00:00<?, ?it/s]
# Keyword: climate change, Matches found: 5, Year: 1990
# ...

# %%
sentences = ['The Conference must produce results that will assist countries, particularly in the developing world, to meet their obligations. We hope the proposed conventions on climate change and on the protection of biodiversity will soon be ready for signature. A mainstay of the consolidation of global peace, development and security is the effort to strengthen the rule of international law.', 'Looking forward into the 1990s, we see a world which is faced with challenges and risks but is also full of opportunities and hopes. No matter how the international climate changes, the historical tide of peace and development is irresistible. The future of the world is bright.', "With a view to finding some grounds for understanding in dealing with the environment and development, we should mention a graver threat to our planet, the risk of the emission of carbon dioxide into the atmosphere causing a greenhouse effect. An increase in the planet's average temperature will lead to a change in rainfall levels and a deterioration in crop conditions in the major temperate and grain-producing areas. In this respect, my country joined in the Hague Declaration on the depletion of the ozone layer and on atmospheric pollution and climate change.", "An increase in the planet's average temperature will lead to a change in rainfall levels and a deterioration in crop conditions in the major temperate and grain-producing areas. In this respect, my country joined in the Hague Declaration on the depletion of the ozone layer and on atmospheric pollution and climate change. It supports the development of a framework convention in order to preserve our planet and the future of mankind.", 'At the meeting of the Commonwealth Heads of Government held in Kuala Lumpur in October 1989, the Maldives proposed that the Commonwealth make every possible effort to expedite the drafting of the framework convention on environment on which the World Meteorological Organization and the United Nations Environment Programme have been collaborating for some time. The initial report of the Intergovernmental Panel on Climate Change will be considered at the second World Climate Conference to be held in Geneva from 29 October to 7 November this year, and it is hoped that the final convention will be adopted at the United Nations Conference on Environment and Development in 1992. A Small States Conference on Sea-Level Rise was hosted by the Maldives last year, and the Male Declaration on Global Warming and Sea-Level Rise, which was adopted at the Conference, underscored the urgency of the problem and identified many areas of possible international co-operation in this field.', 'The initial report of the Intergovernmental Panel on Climate Change will be considered at the second World Climate Conference to be held in Geneva from 29 October to 7 November this year, and it is hoped that the final convention will be adopted at the United Nations Conference on Environment and Development in 1992. A Small States Conference on Sea-Level Rise was hosted by the Maldives last year, and the Male Declaration on Global Warming and Sea-Level Rise, which was adopted at the Conference, underscored the urgency of the problem and identified many areas of possible international co-operation in this field. As called for in the Male Declaration, an action group has been established to co-ordinate a joint approach on the issues of climate change, global warming and sea-level rise, and to pursue and follow up on global and regional response strategies.', 'A Small States Conference on Sea-Level Rise was hosted by the Maldives last year, and the Male Declaration on Global Warming and Sea-Level Rise, which was adopted at the Conference, underscored the urgency of the problem and identified many areas of possible international co-operation in this field. As called for in the Male Declaration, an action group has been established to co-ordinate a joint approach on the issues of climate change, global warming and sea-level rise, and to pursue and follow up on global and regional response strategies. The group comprising representatives from the Mediterranean, the Caribbean, the South Pacific and the Indian Ocean regions is scheduled to meet in Male early next year.']
keyword = "climate change"
keyword_lower = keyword.lower().strip()
seen = set()
unique_matched_sentences = []
for paragraph in sentences:
    # Split paragraph into sentences based on punctuation
    split_sents = re.split(r'(?<=[.!?])\s+', paragraph)
    for sent in split_sents:
        if keyword_lower in sent.lower():
            if sent not in seen:
                unique_matched_sentences.append(sent)
                seen.add(sent)  



for sent in unique_matched_sentences:
    print(f"Original Sentence: {sent}")
# Out:
# Original Sentence: We hope the proposed conventions on climate change and on the protection of biodiversity will soon be ready for signature.
# Original Sentence: No matter how the international climate changes, the historical tide of peace and development is irresistible.
# Original Sentence: In this respect, my country joined in the Hague Declaration on the depletion of the ozone layer and on atmospheric pollution and climate change.
# Original Sentence: The initial report of the Intergovernmental Panel on Climate Change will be considered at the second World Climate Conference to be held in Geneva from 29 October to 7 November this year, and it is hoped that the final convention will be adopted at the United Nations Conference on Environment and Development in 1992.
# ...

# %%
keywords = ["climate change", "klk"]

for keyword in keywords:
    keyword_lower = keyword.lower().strip()
    seen = set()
    matched_sentences = []
    matched_phrases = []

    for paragraph in sentences:
        split_sents = re.split(r'(?<=[.!?])\s+', paragraph)
        for sent in split_sents:
            sent_lower = sent.lower()
            if keyword_lower in sent_lower:
                if sent not in seen:
                    matched_sentences.append(sent)
                    seen.add(sent)
                    phrases = re.findall(rf'\b{re.escape(keyword_lower)}\b', sent_lower)
                    matched_phrases.extend(phrases)

    print(f"\n== Results for '{keyword}' ==")
    for i, sent in enumerate(matched_sentences):
        print(f"Matched Sentence {i+1}: {sent}")

    print("Extracted Bigram Matches:")
    print(matched_phrases)
# Out:
# == Results for 'climate change' ==
# Matched Sentence 1: We hope the proposed conventions on climate change and on the protection of biodiversity will soon be ready for signature.
# Matched Sentence 2: No matter how the international climate changes, the historical tide of peace and development is irresistible.
# Matched Sentence 3: In this respect, my country joined in the Hague Declaration on the depletion of the ozone layer and on atmospheric pollution and climate change.
# Matched Sentence 4: The initial report of the Intergovernmental Panel on Climate Change will be considered at the second World Climate Conference to be held in Geneva from 29 October to 7 November this year, and it is hoped that the final convention will be adopted at the United Nations Conference on Environment and Development in 1992.
# ...
