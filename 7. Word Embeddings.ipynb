# %%
# pip install "numpy>=2.0.0,<3.0.0"

# %%
# no hace falta runearlo por ahora
# !pip install scikit-learn

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords  # You need to import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alvar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import ast
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import re
from gensim.utils import simple_preprocess
from pathlib import Path
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import contractions
from nltk import pos_tag
from nltk.corpus import stopwords
import matplotlib.ticker as ticker
from gensim.models import Word2Vec
from collections import defaultdict
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from adjustText import adjust_text

# %%
def clean_and_lowercase_list_column(df, column_name):
    """
    Converts stringified lists in a column to real lists and lowercases each string element.
    
    Parameters:
        df (pd.DataFrame): The DataFrame containing the column.
        column_name (str): The name of the column to clean.
    
    Returns:
        pd.DataFrame: A copy of the DataFrame with the cleaned column.
    """
    # df = df.copy()
    
    # Convert stringified lists to real lists
    df[column_name] = df[column_name].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
    )
    
    # Lowercase each string in the list
    df[column_name] = df[column_name].apply(
        lambda lst: [s.lower() for s in lst] if isinstance(lst, list) else lst
    )
    
    return df

# %%
def extract_keyword_info(text, keyword):
    """
    Extracts climate-related keyword information from a text string.

    Parameters:
        text (str): The speech or text in which to search for keywords.
        keywords (list of str): A list of climate-related keywords or phrases to match against the text.
    """
    matches = []
    pattern = r'\b' + re.escape(keyword) + r's?\b' # Match also plural forms
    if re.search(pattern, text, flags=re.IGNORECASE):
        matches.append(keyword)
    contains_keyword = len(matches) > 0
    return pd.Series([matches, contains_keyword])

# %%
bigrams = ["climate change", "global warming", "global warm","cap and trade", "paris accord", "emissions trading", "global average temperature", 
            "kyoto protocol", "changing climate" ,"climate resilience","climate decay", "carbon dioxide", "carbon-dioxide","climate politics", 
            "framework on convention climate change", "bali roadmap", "bali action plan", 
            "greenhouse gas", "greenhouse-gas","greenhouse effect", "climate mitigation", "climate action", "emissions", "temperature", "extreme weather", 
            "global environmental change", "global environment", "global environmental" ,"climate variability", "low carbon", "renewable energy", 
            "carbon emission", "climate pollutant", "climate pollutants", "carbon tax", "carbon footprint", "carbon neutrality", 
            "net zero","net-zero","climate crisis", "climate summit", "climate catastrophe", "climate justice", "climate emergency", "climate funding",
            "climate fund", "climate financing", "climate finance","climate peace", "climate agreement", "climate security", "climate ambition", 
            "climate issue", "climate impact", "climate conference", "climate event", "climate challenge", "climate trust", "climate negotiation", 
            "climate catastrophe", "climate risk", "climate goal", "climate change-related", "climate regime", "climate resilient", "climate policy", 
            "carbon market", "carbon sink", "green climate", "green economy", "emission reduction", "emissions reduction", "carbon neutral", 
            "ozone layer", "emissions trading scheme", "co2 emission", "united nation"]

bigrams_1 = sorted(bigrams, key=lambda x: -len(x.split()))

def replace_bigrams(text, bigrams):
    for phrase in bigrams:
        # Normalize the phrase: convert dashes to spaces
        normalized_phrase = phrase.replace("-", " ")
        # Build regex pattern from normalized phrase
        pattern = r'\b' + re.escape(normalized_phrase) +  r's?\b'
        # Replace spaces (now consistent) with underscores
        underscored = normalized_phrase.replace(" ", "_")
        text = re.sub(pattern, underscored, text)
    return text

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
def extract_climate_sentences_with_context(speech, keywords):
    """
    Extracts sentences containing climate keywords along with one sentence before and after each.
    Returns a list of context windows (strings of 1–3 sentences).
    """
    doc = list(nlp(speech).sents)  # Convert to list to access by index
    context_windows = []

    for i, sent in enumerate(doc):
        sent_text = sent.text.strip()

        if any(kw.lower() in sent_text.lower() for kw in keywords):
            # Grab the previous, current, and next sentence if available
            prev_sent = doc[i-1].text.strip() if i > 0 else ''
            next_sent = doc[i+1].text.strip() if i < len(doc) - 1 else ''
            
            context = ' '.join([s for s in [prev_sent, sent_text, next_sent] if s])
            context_windows.append(context)

    return context_windows

# %%
def preprocess_text(entry_1, entry_2, entry_3):
    # Choose text source based on count_climate_change
    text = entry_2 if entry_3 == 1 else entry_1
    
    custom_stopwords = {'mr', 'there', 'that', 'this', 'they', 'them', 'those', 'themselves'} | set(stop_words)

    tokens = text.split()
    
    return [token for token in tokens
        if (token.lower() not in custom_stopwords)  # Case-insensitive check
        and (len(token) > 3)]
def preprocess_df(df, column_1='speeches_for_word2vec', column_2='climate_sentences_extended', column_3='count_climate_change'):
    tqdm.pandas()
    
    # Apply preprocessing and store results in 'tokens' column
    df['tokens'] = df.progress_apply(
        lambda row: preprocess_text(row[column_1], row[column_2], row[column_3]),
        axis=1
    )
    
    return df

# %%
text = 'the conference must produce results that will assist countries particularly in the developing world to meet their obligations we hope the proposed conventions on climate_change_1990 and on the protection of biodiversity will soon be ready for signature a mainstay of the consolidation of global peace development and security is the effort to strengthen the rule of international law'

tokens = text.split()
custom_stopwords = {'mr', 'there', 'that', 'this', 'they', 'them', 'those', 'themselves'} | set(stop_words)
klk = [token for token in tokens
        if (token.lower() not in custom_stopwords)  # Case-insensitive check
        and (len(token) > 3)] 

print(klk)
# Out:
# ['conference', 'must', 'produce', 'results', 'assist', 'countries', 'particularly', 'developing', 'world', 'meet', 'obligations', 'hope', 'proposed', 'conventions', 'climate_change_1990', 'protection', 'biodiversity', 'soon', 'ready', 'signature', 'mainstay', 'consolidation', 'global', 'peace', 'development', 'security', 'effort', 'strengthen', 'rule', 'international']

# %% [markdown]
# # 1. Data

# %%
base_path_alvaro = Path(r"C:\Users\alvar\OneDrive\Escritorio\BDS\Block_5\NLP\Project")

base_path = base_path_alvaro # change according to user

# %%
# Step 1. Call the data
final_df = pd.read_csv(base_path / "Final_df_extended.csv")

# Step 2. Select only the climate related speeches
df_sentiment = final_df[final_df['contains_climate_keyword'] != False]

# Step 3. Keep only the most important columns
df_climate_change = df_sentiment.drop(['Session', 'Speech', 'number_sentences', 'number_tokens', 'cleaned_speeches_postagging_expanded', 'contains_climate_keyword', 'climate_sentences', 'contains_climate_keyword', 'matched_climate_keywords', 'climate_sentences_extended'], axis = 1)

# %%
tqdm.pandas()
# Step 1: Replace bigrams
df_climate_change["speeches_for_keyword_search"] = df_climate_change["speeches_for_keyword_search"].progress_apply(
    lambda x: replace_bigrams(x, bigrams)
)

# Step 2. Select only those speeches that mention CLIMATE_CHANGE
df_climate_change[['matched_climate_keywords', 'contains_climate_keyword']] = df_climate_change['speeches_for_keyword_search'].progress_apply(
    lambda text: extract_keyword_info(text, 'climate_change')
)

# Step 3. Only select those instances with climate = True
df_climate_change_smp = df_climate_change[df_climate_change['contains_climate_keyword'] == True]

# Step 4. Extend the climate sentences WATCH OUT WITH THE HEAD HERE LIL BOI
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp.progress_apply(
    lambda row: extract_climate_sentences_with_context(row['speeches_for_keyword_search'], row['matched_climate_keywords']),
    axis=1
)

df_climate_change_smp = df_climate_change_smp.rename(columns={"speeches_for_keyword_search": "speeches_for_word2vec"}).drop(['matched_climate_keywords', 'contains_climate_keyword'], axis = 1)

# Step 5: Remove 'mr. president' (case-insensitive, with or without period)
df_climate_change_smp["speeches_for_word2vec"] = df_climate_change_smp["speeches_for_word2vec"].str.replace(
    r'\bmr\.?\s+president\b', '', flags=re.IGNORECASE, regex=True
)

# Step 6: Remove punctuation from word2vec
df_climate_change_smp['speeches_for_word2vec'] = df_climate_change_smp['speeches_for_word2vec'].str.replace(
    r'[^\w\s]', '', regex=True
)

# Step 7: Turn climate_sentences_extended into a STR and not a list
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp['climate_sentences_extended'].apply(
    lambda sentences: ' '.join(sentences) if isinstance(sentences, list) else sentences
)

# Step 8: Remove punctuation from climate_sentences_extended
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp['climate_sentences_extended'].str.replace(
    r'[^\w\s]', '', regex=True
)

# Step 9: 
df_climate_change_smp["speeches_for_word2vec"] = df_climate_change_smp.apply(
    lambda row: row["speeches_for_word2vec"].replace("climate_change", f"climate_change_{row['Year']}"),
    axis=1
)

# Step 10: 
df_climate_change_smp["climate_sentences_extended"] = df_climate_change_smp.apply(
    lambda row: row["climate_sentences_extended"].replace("climate_change", f"climate_change_{row['Year']}"),
    axis=1
)

# Step 11: count the instances of climate_change in the speech
df_climate_change_smp["count_climate_change"] = df_climate_change_smp["speeches_for_word2vec"].str.count("climate_change")

df_climate_change_smp
# Out:
# 100%|██████████| 3380/3380 [01:33<00:00, 36.19it/s]
# 100%|██████████| 3380/3380 [00:01<00:00, 2495.24it/s]
# 100%|██████████| 2946/2946 [27:31<00:00,  1.78it/s]
# C:\Users\alvar\AppData\Local\Temp\ipykernel_23244\855043073.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp.progress_apply(
#       Year ISO-Code  Income Level  \
# 4     1990      BGD             1
# 6     1990      CHN             1
# 8     1990      COD             1
# 14    1990      DNK             4
# 21    1990      ISL             4
# ...    ...      ...           ...
# 3375  2024      WSM             2
# 3376  2024      YEM             1
# 3377  2024      ZAF             3
# 3378  2024      ZMB             2
# 3379  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 4      warm felicitations are due you on your wellde...
# 6     i should like to begin by warmly congratulatin...
# 8      the fortyfifth session of the united_nation g...
# 14    i congratulate you sir on your election as pre...
# 21     to congratulate you on your election to our h...
# ...                                                 ...
# 3375  excellencies i extend my congratulations to hi...
# 3376  ladies and gentlemen it is a happy coincidence...
# 3377  president of the 79th session of the un genera...
# 3378  ladies and gentlemen i congratulate you your e...
# 3379  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change
# 4     the conference must produce results that will ...                     1
# 6     looking forward into the 1990s we see a world ...                     1
# 8     an increase in the planets average temperature...                     1
# 14    at the same time we must not lose sight of oth...                     4
# 21    international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 3375  please be assured of samoas support in the suc...                     7
# 3376  for this reason the republic of yemen renews i...                     1
# 3377  extreme_weather such as flooding fires and dro...                     2
# 3378  furthermore zambia recognises the efforts of h...                     2
# 3379  in this spirit of unity we must prioritize the...                     4
#
# [2946 rows x 6 columns]

# %%
#df_climate_change_smp.to_csv(base_path_alvaro / "Final_df_extended_new.csv", index=False, encoding='utf-8')
df_wo_tokens = pd.read_csv(base_path_alvaro / "Final_df_extended_new.csv")
df_wo_tokens
# Out:
#       Year ISO-Code  Income Level  \
# 0     1990      BGD             1
# 1     1990      CHN             1
# 2     1990      COD             1
# 3     1990      DNK             4
# 4     1990      ISL             4
# ...    ...      ...           ...
# 2941  2024      WSM             2
# 2942  2024      YEM             1
# 2943  2024      ZAF             3
# 2944  2024      ZMB             2
# 2945  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 0      warm felicitations are due you on your wellde...
# 1     i should like to begin by warmly congratulatin...
# 2      the fortyfifth session of the united_nation g...
# 3     i congratulate you sir on your election as pre...
# 4      to congratulate you on your election to our h...
# ...                                                 ...
# 2941  excellencies i extend my congratulations to hi...
# 2942  ladies and gentlemen it is a happy coincidence...
# 2943  president of the 79th session of the un genera...
# 2944  ladies and gentlemen i congratulate you your e...
# 2945  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change
# 0     the conference must produce results that will ...                     1
# 1     looking forward into the 1990s we see a world ...                     1
# 2     an increase in the planets average temperature...                     1
# 3     at the same time we must not lose sight of oth...                     4
# 4     international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 2941  please be assured of samoas support in the suc...                     7
# 2942  for this reason the republic of yemen renews i...                     1
# 2943  extreme_weather such as flooding fires and dro...                     2
# 2944  furthermore zambia recognises the efforts of h...                     2
# 2945  in this spirit of unity we must prioritize the...                     4
#
# [2946 rows x 6 columns]

# %%
df_w_tokens = preprocess_df(df_wo_tokens.copy())
df_w_tokens
# Out:
# 100%|██████████| 2946/2946 [00:00<00:00, 3374.08it/s]
#       Year ISO-Code  Income Level  \
# 0     1990      BGD             1
# 1     1990      CHN             1
# 2     1990      COD             1
# 3     1990      DNK             4
# 4     1990      ISL             4
# ...    ...      ...           ...
# 2941  2024      WSM             2
# 2942  2024      YEM             1
# 2943  2024      ZAF             3
# 2944  2024      ZMB             2
# 2945  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 0      warm felicitations are due you on your wellde...
# 1     i should like to begin by warmly congratulatin...
# 2      the fortyfifth session of the united_nation g...
# 3     i congratulate you sir on your election as pre...
# 4      to congratulate you on your election to our h...
# ...                                                 ...
# 2941  excellencies i extend my congratulations to hi...
# 2942  ladies and gentlemen it is a happy coincidence...
# 2943  president of the 79th session of the un genera...
# 2944  ladies and gentlemen i congratulate you your e...
# 2945  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change  \
# 0     the conference must produce results that will ...                     1
# 1     looking forward into the 1990s we see a world ...                     1
# 2     an increase in the planets average temperature...                     1
# 3     at the same time we must not lose sight of oth...                     4
# 4     international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 2941  please be assured of samoas support in the suc...                     7
# 2942  for this reason the republic of yemen renews i...                     1
# 2943  extreme_weather such as flooding fires and dro...                     2
# 2944  furthermore zambia recognises the efforts of h...                     2
# 2945  in this spirit of unity we must prioritize the...                     4
#
#                                                  tokens
# 0     [conference, must, produce, results, assist, c...
# 1     [looking, forward, 1990s, world, faced, challe...
# 2     [increase, planets, average, temperature, lead...
# 3     [congratulate, election, president, general, a...
# 4     [international, treaties, specific, fields, en...
# ...                                                 ...
# 2941  [excellencies, extend, congratulations, excell...
# 2942  [reason, republic, yemen, renews, call, intern...
# 2943  [president, 79th, session, general, assembly, ...
# 2944  [ladies, gentlemen, congratulate, excellency, ...
# 2945  [excellency, philemon, yang, president, 79th, ...
#
# [2946 rows x 7 columns]

# %%
all_models = {}

for i in range(1, 5):  # For each income level
    print(f'\n{"-"*40} Income Level {i} {"-"*40}')
    
    df_income = df_w_tokens[df_w_tokens['Income Level'] == i]

    # Group by year to get list of sentences per year
    grouped_by_year = df_income.groupby('Year')['tokens'].apply(list)

    # Optional: for inspection
    grouped_by_year_df = grouped_by_year.reset_index(name='tokens')

    # Dictionary to store yearly models
    models_by_year = {}
    
    for year, sentences in grouped_by_year.items():
        # Extract climate sentences for this specific year
        flat_sentences = [s for s in sentences if len(s) > 0]
        
        if not flat_sentences:
            print(f"Skipping year {year} - no climate sentences")
            continue
            
        print(f"\nTraining climate_change_{year} model (Income {i})")
        print(f"Documents: {len(flat_sentences)}")
        
        model = Word2Vec(
            sentences=flat_sentences,
            vector_size=150,
            window=10,
            min_count=1,  # Increased from 1 for better quality
            sample=1e-5,
            workers=4,
            sg=1,
            seed=42,
            epochs=10
        )
        
        # Store with year-specific key
        models_by_year[year] = model
        
        # Yearly diagnostics
        print(f"Vocab size: {len(model.wv)}")
        climate_key = f"climate_change_{year}"
        try:
            print(f"Top associations for '{climate_key}':")
            print(model.wv.most_similar(positive=[climate_key], topn=5))
        except KeyError:
            print(f"'{climate_key}' not in vocabulary")
    
    all_models[i] = models_by_year
# Out:
# ---------------------------------------- Income Level 1 ----------------------------------------
#
# Training climate_change_1990 model (Income 1)
# Documents: 4
# Vocab size: 880
# Top associations for 'climate_change_1990':
# [('newest', 0.2844316065311432), ('hazards', 0.24801857769489288), ('partners', 0.24469779431819916), ('mercenaries', 0.2338961511850357), ('dismantled', 0.22689150273799896)]
#
# Training climate_change_1991 model (Income 1)
# Documents: 2
# Vocab size: 118
# Top associations for 'climate_change_1991':
# [('recognized', 0.22766292095184326), ('forward', 0.19723685085773468), ('proposals', 0.17473183572292328), ('role', 0.1730346530675888), ('peoples', 0.17094294726848602)]
#
# Training climate_change_1992 model (Income 1)
# Documents: 11
# Vocab size: 273
# Top associations for 'climate_change_1992':
# [('nations', 0.26159554719924927), ('ignoring', 0.225995272397995), ('early', 0.2069367915391922), ('biodiversity', 0.18253886699676514), ('follow', 0.164656400680542)]
#
# Training climate_change_1993 model (Income 1)
# Documents: 3
# Vocab size: 91
# Top associations for 'climate_change_1993':
# [('role', 0.19603592157363892), ('country', 0.15405626595020294), ('readiness', 0.1529860943555832), ('production', 0.1444990187883377), ('ozone_layer', 0.14043189585208893)]
#
# Training climate_change_1994 model (Income 1)
# Documents: 5
# Vocab size: 830
# Top associations for 'climate_change_1994':
# [('impossible', 0.24368348717689514), ('certainly', 0.240714892745018), ('time', 0.23973865807056427), ('multilateralism', 0.23755094408988953), ('management', 0.22320084273815155)]
#
# Training climate_change_1995 model (Income 1)
# Documents: 3
# Vocab size: 97
# Top associations for 'climate_change_1995':
# [('june', 0.23772215843200684), ('awareness', 0.23646733164787292), ('serious', 0.16915570199489594), ('global', 0.1664217710494995), ('october', 0.16230802237987518)]
#
# Training climate_change_1996 model (Income 1)
# Documents: 2
# Vocab size: 68
# Top associations for 'climate_change_1996':
# [('watersharing', 0.23642006516456604), ('code', 0.19990822672843933), ('stresses', 0.15354865789413452), ('united_nation', 0.1525779664516449), ('particular', 0.1456107199192047)]
#
# Training climate_change_1997 model (Income 1)
# Documents: 3
# Vocab size: 136
# Top associations for 'climate_change_1997':
# [('effective', 0.1960323005914688), ('mkapa', 0.1665777862071991), ('touched', 0.15404470264911652), ('welcomed', 0.15297529101371765), ('spirit', 0.14450562000274658)]
#
# Training climate_change_1998 model (Income 1)
# Documents: 5
# Vocab size: 830
# Top associations for 'climate_change_1998':
# [('fish', 0.2579498589038849), ('china', 0.24864934384822845), ('rejoiced', 0.23545527458190918), ('undertaken', 0.2283366322517395), ('negotiate', 0.2201424092054367)]
#
# Training climate_change_1999 model (Income 1)
# Documents: 2
# Vocab size: 708
# Top associations for 'climate_change_1999':
# [('promoting', 0.22988635301589966), ('400000', 0.22597363591194153), ('activities', 0.21885576844215393), ('administrative', 0.2047020047903061), ('mass', 0.20089970529079437)]
#
# Training climate_change_2000 model (Income 1)
# Documents: 4
# Vocab size: 177
# Top associations for 'climate_change_2000':
# [('decisions', 0.26155248284339905), ('opportunities', 0.22605504095554352), ('biodiversity', 0.18269437551498413), ('emerging', 0.15415330231189728), ('year', 0.15252315998077393)]
#
# Training climate_change_2001 model (Income 1)
# Documents: 5
# Vocab size: 1201
# Top associations for 'climate_change_2001':
# [('force', 0.25247523188591003), ('capacity', 0.23622265458106995), ('developed', 0.2332426756620407), ('exceed', 0.21809761226177216), ('flexibility', 0.21562623977661133)]
#
# Training climate_change_2002 model (Income 1)
# Documents: 6
# Vocab size: 1388
# Top associations for 'climate_change_2002':
# [('density', 0.2790679633617401), ('humble', 0.2397623509168625), ('conflicts', 0.2255171835422516), ('democracy', 0.22263897955417633), ('prosperity', 0.21441560983657837)]
#
# Training climate_change_2003 model (Income 1)
# Documents: 4
# Vocab size: 1482
# Top associations for 'climate_change_2003':
# [('obligations', 0.25135600566864014), ('step', 0.2505010664463043), ('means', 0.24658817052841187), ('story', 0.23833997547626495), ('degradation', 0.23386865854263306)]
#
# Training climate_change_2004 model (Income 1)
# Documents: 2
# Vocab size: 657
# Top associations for 'climate_change_2004':
# [('without', 0.2583778202533722), ('resolution', 0.2076142281293869), ('hunger', 0.20757991075515747), ('expansion', 0.20201954245567322), ('beneficiary', 0.19842950999736786)]
#
# Training climate_change_2005 model (Income 1)
# Documents: 5
# Vocab size: 1216
# Top associations for 'climate_change_2005':
# [('livelihood', 0.2270212322473526), ('measures', 0.2154897153377533), ('colleague', 0.21295735239982605), ('parliament', 0.20936301350593567), ('expenses', 0.2039915770292282)]
#
# Training climate_change_2006 model (Income 1)
# Documents: 4
# Vocab size: 1247
# Top associations for 'climate_change_2006':
# [('fiscal', 0.29397204518318176), ('prevention', 0.24791380763053894), ('drawn', 0.23847191035747528), ('liberalization', 0.21861732006072998), ('assure', 0.21847572922706604)]
#
# Training climate_change_2007 model (Income 1)
# Documents: 39
# Vocab size: 5196
# Top associations for 'climate_change_2007':
# [('must', 0.9990703463554382), ('world', 0.9990395307540894), ('assembly', 0.9990289211273193), ('united_nation', 0.9990185499191284), ('president', 0.9990078806877136)]
#
# Training climate_change_2008 model (Income 1)
# Documents: 31
# Vocab size: 3803
# Top associations for 'climate_change_2008':
# [('development', 0.9925147294998169), ('food', 0.9915743470191956), ('security', 0.9909408688545227), ('agriculture', 0.9905582070350647), ('africa', 0.9901309609413147)]
#
# Training climate_change_2009 model (Income 1)
# Documents: 36
# Vocab size: 5075
# Top associations for 'climate_change_2009':
# [('therefore', 0.9991958737373352), ('council', 0.9991434812545776), ('people', 0.9991403818130493), ('united_nation', 0.9991312026977539), ('support', 0.9991145730018616)]
#
# Training climate_change_2010 model (Income 1)
# Documents: 25
# Vocab size: 4124
# Top associations for 'climate_change_2010':
# [('international', 0.9947184324264526), ('global', 0.9945794939994812), ('united_nation', 0.9943652749061584), ('union', 0.9941102862358093), ('security', 0.994109570980072)]
#
# Training climate_change_2011 model (Income 1)
# Documents: 23
# Vocab size: 3348
# Top associations for 'climate_change_2011':
# [('international', 0.882984459400177), ('countries', 0.8758038282394409), ('also', 0.8756041526794434), ('africa', 0.8725376129150391), ('world', 0.8704730272293091)]
#
# Training climate_change_2012 model (Income 1)
# Documents: 14
# Vocab size: 2780
# Top associations for 'climate_change_2012':
# [('need', 0.38264793157577515), ('country', 0.37975767254829407), ('international', 0.3797515630722046), ('global', 0.37517914175987244), ('organized', 0.3683660328388214)]
#
# Training climate_change_2013 model (Income 1)
# Documents: 10
# Vocab size: 2399
# Top associations for 'climate_change_2013':
# [('republic', 0.3317483961582184), ('founding', 0.28067708015441895), ('women', 0.2753463685512543), ('centre', 0.26933765411376953), ('decade', 0.2496969848871231)]
#
# Training climate_change_2014 model (Income 1)
# Documents: 19
# Vocab size: 3187
# Top associations for 'climate_change_2014':
# [('peace', 0.48472341895103455), ('global', 0.48404207825660706), ('development', 0.4821200966835022), ('result', 0.48084089159965515), ('united_nation', 0.4760506749153137)]
#
# Training climate_change_2015 model (Income 1)
# Documents: 20
# Vocab size: 3615
# Top associations for 'climate_change_2015':
# [('development', 0.8025764226913452), ('also', 0.7836297154426575), ('united_nation', 0.7817747592926025), ('people', 0.7789316773414612), ('made', 0.7781838178634644)]
#
# Training climate_change_2016 model (Income 1)
# Documents: 27
# Vocab size: 4091
# Top associations for 'climate_change_2016':
# [('support', 0.9945253133773804), ('world', 0.9941777586936951), ('countries', 0.9941381216049194), ('united_nation', 0.9940488934516907), ('development', 0.9939643740653992)]
#
# Training climate_change_2017 model (Income 1)
# Documents: 28
# Vocab size: 4263
# Top associations for 'climate_change_2017':
# [('development', 0.9965121150016785), ('countries', 0.9964519739151001), ('efforts', 0.9963615536689758), ('country', 0.9963144659996033), ('measures', 0.9963095784187317)]
#
# Training climate_change_2018 model (Income 1)
# Documents: 20
# Vocab size: 4083
# Top associations for 'climate_change_2018':
# [('security', 0.9941573143005371), ('national', 0.9938014149665833), ('challenges', 0.9936721324920654), ('peace', 0.9933857321739197), ('international', 0.9933481216430664)]
#
# Training climate_change_2019 model (Income 1)
# Documents: 24
# Vocab size: 4348
# Top associations for 'climate_change_2019':
# [('peace', 0.9983023405075073), ('development', 0.9980432987213135), ('security', 0.9980237483978271), ('education', 0.9979997873306274), ('society', 0.9979247450828552)]
#
# Training climate_change_2020 model (Income 1)
# Documents: 18
# Vocab size: 2900
# Top associations for 'climate_change_2020':
# [('covid19', 0.7825082540512085), ('efforts', 0.7669028043746948), ('world', 0.7620989680290222), ('peace', 0.7404415011405945), ('africa', 0.7384664416313171)]
#
# Training climate_change_2021 model (Income 1)
# Documents: 21
# Vocab size: 4666
# Top associations for 'climate_change_2021':
# [('people', 0.9969833493232727), ('support', 0.996720552444458), ('united_nation', 0.9965972304344177), ('covid19', 0.9963558912277222), ('security', 0.9962807297706604)]
#
# Training climate_change_2022 model (Income 1)
# Documents: 24
# Vocab size: 4501
# Top associations for 'climate_change_2022':
# [('development', 0.9960538744926453), ('international', 0.9953237771987915), ('people', 0.9952044486999512), ('support', 0.9949217438697815), ('countries', 0.9948605298995972)]
#
# Training climate_change_2023 model (Income 1)
# Documents: 19
# Vocab size: 4028
# Top associations for 'climate_change_2023':
# [('countries', 0.933350145816803), ('african', 0.9310826063156128), ('government', 0.9279410243034363), ('world', 0.9262784123420715), ('also', 0.9254192113876343)]
#
# Training climate_change_2024 model (Income 1)
# Documents: 21
# Vocab size: 3960
# Top associations for 'climate_change_2024':
# [('security', 0.9275633692741394), ('development', 0.9228456020355225), ('countries', 0.9226480722427368), ('conflicts', 0.9220229983329773), ('support', 0.9216970801353455)]
#
# ---------------------------------------- Income Level 2 ----------------------------------------
#
# Training climate_change_1991 model (Income 2)
# Documents: 6
# Vocab size: 1519
# Top associations for 'climate_change_1991':
# [('reminder', 0.3089452385902405), ('forum', 0.28017809987068176), ('encouraged', 0.2796515226364136), ('commitment', 0.2554416060447693), ('stockpile', 0.24521717429161072)]
#
# Training climate_change_1992 model (Income 2)
# Documents: 7
# Vocab size: 1728
# Top associations for 'climate_change_1992':
# [('declaration', 0.27613767981529236), ('around', 0.27493155002593994), ('framework', 0.2457468956708908), ('cold', 0.22567568719387054), ('1990', 0.2255348116159439)]
#
# Training climate_change_1993 model (Income 2)
# Documents: 7
# Vocab size: 2056
# Top associations for 'climate_change_1993':
# [('denying', 0.2691112458705902), ('specks', 0.2444596290588379), ('fourth', 0.23519255220890045), ('facing', 0.23488818109035492), ('taken', 0.2345174103975296)]
#
# Training climate_change_1994 model (Income 2)
# Documents: 4
# Vocab size: 1673
# Top associations for 'climate_change_1994':
# [('possible', 0.28142037987709045), ('world', 0.2643492817878723), ('vocabulary', 0.25973233580589294), ('commemorate', 0.2581911087036133), ('intergovernmental', 0.2379949390888214)]
#
# Training climate_change_1995 model (Income 2)
# Documents: 7
# Vocab size: 2552
# Top associations for 'climate_change_1995':
# [('global', 0.4033552408218384), ('provides', 0.34994378685951233), ('action', 0.3126143217086792), ('forum', 0.31078246235847473), ('guinea', 0.30959001183509827)]
#
# Training climate_change_1996 model (Income 2)
# Documents: 7
# Vocab size: 2386
# Top associations for 'climate_change_1996':
# [('development', 0.34970012307167053), ('council', 0.33301499485969543), ('honoured', 0.3196825683116913), ('unique', 0.3183119297027588), ('vital', 0.3164995610713959)]
#
# Training climate_change_1997 model (Income 2)
# Documents: 11
# Vocab size: 2295
# Top associations for 'climate_change_1997':
# [('settings', 0.29743459820747375), ('live', 0.28560832142829895), ('turn', 0.2545114755630493), ('bottom', 0.25121739506721497), ('kwajalein', 0.25034597516059875)]
#
# Training climate_change_1998 model (Income 2)
# Documents: 9
# Vocab size: 2474
# Top associations for 'climate_change_1998':
# [('like', 0.3456752300262451), ('appear', 0.34520313143730164), ('refer', 0.34017717838287354), ('kyoto_protocol', 0.3338565528392792), ('stronger', 0.3328709006309509)]
#
# Training climate_change_1999 model (Income 2)
# Documents: 5
# Vocab size: 1437
# Top associations for 'climate_change_1999':
# [('outcome', 0.26709598302841187), ('point', 0.25312796235084534), ('review', 0.24480663239955902), ('killer', 0.23452511429786682), ('failed', 0.2284659743309021)]
#
# Training climate_change_2000 model (Income 2)
# Documents: 9
# Vocab size: 1600
# Top associations for 'climate_change_2000':
# [('positive', 0.3006320893764496), ('office', 0.27492082118988037), ('speeches', 0.24658071994781494), ('unaffected', 0.24309971928596497), ('independent', 0.2357938289642334)]
#
# Training climate_change_2001 model (Income 2)
# Documents: 8
# Vocab size: 1880
# Top associations for 'climate_change_2001':
# [('holkeri', 0.31316375732421875), ('impossible', 0.3091374933719635), ('pressing', 0.30042824149131775), ('foreign', 0.2966429591178894), ('regardless', 0.27655428647994995)]
#
# Training climate_change_2002 model (Income 2)
# Documents: 9
# Vocab size: 975
# Top associations for 'climate_change_2002':
# [('every', 0.2604447305202484), ('position', 0.24186792969703674), ('natural', 0.24122463166713715), ('halving', 0.23041197657585144), ('redoubling', 0.22651317715644836)]
#
# Training climate_change_2003 model (Income 2)
# Documents: 4
# Vocab size: 1089
# Top associations for 'climate_change_2003':
# [('ongoing', 0.25456178188323975), ('successful', 0.22312599420547485), ('landmark', 0.2214922159910202), ('expanded', 0.2178286612033844), ('time', 0.20850546658039093)]
#
# Training climate_change_2004 model (Income 2)
# Documents: 6
# Vocab size: 1372
# Top associations for 'climate_change_2004':
# [('moratorium', 0.25630074739456177), ('allocation', 0.24527014791965485), ('including', 0.2416182905435562), ('steer', 0.24025027453899384), ('ones', 0.23711000382900238)]
#
# Training climate_change_2005 model (Income 2)
# Documents: 6
# Vocab size: 1534
# Top associations for 'climate_change_2005':
# [('general', 0.30495142936706543), ('commodity', 0.2561837136745453), ('pacific', 0.24561059474945068), ('share', 0.23831486701965332), ('charted', 0.213717982172966)]
#
# Training climate_change_2006 model (Income 2)
# Documents: 6
# Vocab size: 1510
# Top associations for 'climate_change_2006':
# [('frameworks', 0.3052532374858856), ('holy', 0.24909183382987976), ('always', 0.24902789294719696), ('marine', 0.2308979481458664), ('geographical', 0.21826796233654022)]
#
# Training climate_change_2007 model (Income 2)
# Documents: 41
# Vocab size: 5246
# Top associations for 'climate_change_2007':
# [('general', 0.9991453886032104), ('also', 0.9991220831871033), ('states', 0.9991113543510437), ('international', 0.9991099834442139), ('country', 0.9990739226341248)]
#
# Training climate_change_2008 model (Income 2)
# Documents: 40
# Vocab size: 5664
# Top associations for 'climate_change_2008':
# [('community', 0.9991470575332642), ('united_nation', 0.9991388916969299), ('states', 0.9991205334663391), ('international', 0.9991011023521423), ('must', 0.999091386795044)]
#
# Training climate_change_2009 model (Income 2)
# Documents: 46
# Vocab size: 6084
# Top associations for 'climate_change_2009':
# [('vulnerable', 0.9989275336265564), ('national', 0.9989116787910461), ('relevant', 0.9988996982574463), ('mitigation', 0.9988985061645508), ('sovereignty', 0.9988864064216614)]
#
# Training climate_change_2010 model (Income 2)
# Documents: 42
# Vocab size: 5488
# Top associations for 'climate_change_2010':
# [('international', 0.9991255402565002), ('assembly', 0.9990159273147583), ('also', 0.9989979267120361), ('global', 0.99897700548172), ('cent', 0.9989683032035828)]
#
# Training climate_change_2011 model (Income 2)
# Documents: 34
# Vocab size: 4780
# Top associations for 'climate_change_2011':
# [('development', 0.9982035160064697), ('world', 0.9979215860366821), ('united_nation', 0.9979137778282166), ('global', 0.9978160858154297), ('countries', 0.9977685213088989)]
#
# Training climate_change_2012 model (Income 2)
# Documents: 25
# Vocab size: 3977
# Top associations for 'climate_change_2012':
# [('peace', 0.9797939658164978), ('united_nation', 0.97885662317276), ('community', 0.978397011756897), ('people', 0.978326678276062), ('government', 0.9782447814941406)]
#
# Training climate_change_2013 model (Income 2)
# Documents: 25
# Vocab size: 3968
# Top associations for 'climate_change_2013':
# [('states', 0.9896557331085205), ('development', 0.9893734455108643), ('international', 0.9877541661262512), ('security', 0.9877429604530334), ('economic', 0.9862942099571228)]
#
# Training climate_change_2014 model (Income 2)
# Documents: 34
# Vocab size: 5201
# Top associations for 'climate_change_2014':
# [('peace', 0.9991360902786255), ('development', 0.9991063475608826), ('international', 0.9990950226783752), ('first', 0.9990671873092651), ('efforts', 0.9990517497062683)]
#
# Training climate_change_2015 model (Income 2)
# Documents: 39
# Vocab size: 5679
# Top associations for 'climate_change_2015':
# [('government', 0.999041736125946), ('necessary', 0.99898362159729), ('people', 0.9989661574363708), ('community', 0.9989010691642761), ('continues', 0.9988858103752136)]
#
# Training climate_change_2016 model (Income 2)
# Documents: 37
# Vocab size: 6163
# Top associations for 'climate_change_2016':
# [('said', 0.9989872574806213), ('hospitals', 0.9988630414009094), ('part', 0.9988604187965393), ('towards', 0.9988558292388916), ('cent', 0.9988505840301514)]
#
# Training climate_change_2017 model (Income 2)
# Documents: 40
# Vocab size: 5788
# Top associations for 'climate_change_2017':
# [('country', 0.9990695714950562), ('social', 0.9990519285202026), ('small', 0.999022901058197), ('become', 0.9990044236183167), ('organization', 0.9989952445030212)]
#
# Training climate_change_2018 model (Income 2)
# Documents: 32
# Vocab size: 5536
# Top associations for 'climate_change_2018':
# [('united_nation', 0.9992425441741943), ('economic', 0.9992101192474365), ('peace', 0.9991187453269958), ('cent', 0.9990864396095276), ('also', 0.9990728497505188)]
#
# Training climate_change_2019 model (Income 2)
# Documents: 45
# Vocab size: 6866
# Top associations for 'climate_change_2019':
# [('continue', 0.998767614364624), ('western', 0.9987333416938782), ('minister', 0.9987211227416992), ('office', 0.9987180829048157), ('rule', 0.9987155199050903)]
#
# Training climate_change_2020 model (Income 2)
# Documents: 33
# Vocab size: 5472
# Top associations for 'climate_change_2020':
# [('united_nation', 0.9985227584838867), ('sustainable', 0.9984850287437439), ('covid19', 0.9984235167503357), ('need', 0.9984170198440552), ('people', 0.998396098613739)]
#
# Training climate_change_2021 model (Income 2)
# Documents: 47
# Vocab size: 7130
# Top associations for 'climate_change_2021':
# [('successive', 0.9988303184509277), ('view', 0.9987631440162659), ('committees', 0.9987613558769226), ('force', 0.9987573027610779), ('ethical', 0.9987566471099854)]
#
# Training climate_change_2022 model (Income 2)
# Documents: 45
# Vocab size: 6833
# Top associations for 'climate_change_2022':
# [('international', 0.9987461566925049), ('nuclear', 0.998740017414093), ('peaceful', 0.9987242221832275), ('multilateral', 0.9987213015556335), ('meeting', 0.9987132549285889)]
#
# Training climate_change_2023 model (Income 2)
# Documents: 44
# Vocab size: 6412
# Top associations for 'climate_change_2023':
# [('agriculture', 0.9987260103225708), ('children', 0.9987192749977112), ('members', 0.9986966848373413), ('rights', 0.9986926317214966), ('duty', 0.9986776113510132)]
#
# Training climate_change_2024 model (Income 2)
# Documents: 40
# Vocab size: 6186
# Top associations for 'climate_change_2024':
# [('region', 0.9990634918212891), ('conditions', 0.9990511536598206), ('health', 0.9990466833114624), ('sectors', 0.9990313053131104), ('council', 0.9989961981773376)]
#
# ---------------------------------------- Income Level 3 ----------------------------------------
#
# Training climate_change_1990 model (Income 3)
# Documents: 2
# Vocab size: 102
# Top associations for 'climate_change_1990':
# [('expectations', 0.19871360063552856), ('international', 0.18278682231903076), ('confront', 0.1668207198381424), ('admission', 0.16225378215312958), ('envisaging', 0.15280678868293762)]
#
# Training climate_change_1991 model (Income 3)
# Documents: 3
# Vocab size: 1597
# Top associations for 'climate_change_1991':
# [('pluralism', 0.26454561948776245), ('balance', 0.25180965662002563), ('disregard', 0.24061176180839539), ('liberated', 0.23702576756477356), ('paris', 0.23163525760173798)]
#
# Training climate_change_1992 model (Income 3)
# Documents: 5
# Vocab size: 812
# Top associations for 'climate_change_1992':
# [('good', 0.2605287432670593), ('fields', 0.2409561425447464), ('holds', 0.22748129069805145), ('present', 0.2248329520225525), ('constant', 0.22349385917186737)]
#
# Training climate_change_1993 model (Income 3)
# Documents: 4
# Vocab size: 896
# Top associations for 'climate_change_1993':
# [('make', 0.28427526354789734), ('disputes', 0.2482302337884903), ('moment', 0.24320001900196075), ('many', 0.23210777342319489), ('priority', 0.22657410800457)]
#
# Training climate_change_1994 model (Income 3)
# Documents: 1
# Vocab size: 1034
# Top associations for 'climate_change_1994':
# [('efforts', 0.27908018231391907), ('desired', 0.24766218662261963), ('final', 0.22884169220924377), ('response', 0.22855763137340546), ('possibilities', 0.21402548253536224)]
#
# Training climate_change_1995 model (Income 3)
# Documents: 3
# Vocab size: 1503
# Top associations for 'climate_change_1995':
# [('manmade', 0.27551618218421936), ('broken', 0.24662303924560547), ('evidence', 0.24124296009540558), ('given', 0.23312275111675262), ('winds', 0.22723136842250824)]
#
# Training climate_change_1996 model (Income 3)
# Documents: 1
# Vocab size: 36
# Top associations for 'climate_change_1996':
# [('planet', 0.13956297934055328), ('close', 0.11715947836637497), ('common', 0.10802662372589111), ('must', 0.10450369119644165), ('efforts', 0.10250561684370041)]
#
# Training climate_change_1997 model (Income 3)
# Documents: 6
# Vocab size: 1009
# Top associations for 'climate_change_1997':
# [('poorer', 0.2798750400543213), ('drawn', 0.22426113486289978), ('different', 0.2116071730852127), ('join', 0.20709499716758728), ('unless', 0.20198728144168854)]
#
# Training climate_change_1998 model (Income 3)
# Documents: 6
# Vocab size: 183
# Top associations for 'climate_change_1998':
# [('aware', 0.2205878049135208), ('longterm', 0.2058769017457962), ('answers', 0.16897700726985931), ('economic', 0.14632739126682281), ('sovereignty', 0.14543943107128143)]
#
# Training climate_change_1999 model (Income 3)
# Documents: 3
# Vocab size: 562
# Top associations for 'climate_change_1999':
# [('fulfilling', 0.21989664435386658), ('came', 0.20561738312244415), ('problems', 0.2000444233417511), ('tables', 0.1991538554430008), ('1400', 0.19859713315963745)]
#
# Training climate_change_2000 model (Income 3)
# Documents: 3
# Vocab size: 474
# Top associations for 'climate_change_2000':
# [('water', 0.25807759165763855), ('member', 0.24599269032478333), ('including', 0.23673206567764282), ('play', 0.22287125885486603), ('month', 0.21090562641620636)]
#
# Training climate_change_2001 model (Income 3)
# Documents: 8
# Vocab size: 1279
# Top associations for 'climate_change_2001':
# [('thursday', 0.23332178592681885), ('bundestag', 0.22305430471897125), ('addressing', 0.22034086287021637), ('emergency', 0.2156970202922821), ('firmly', 0.20549148321151733)]
#
# Training climate_change_2002 model (Income 3)
# Documents: 3
# Vocab size: 1041
# Top associations for 'climate_change_2002':
# [('priorities', 0.2558099925518036), ('recognize', 0.2551916539669037), ('campaign', 0.24492603540420532), ('smaller', 0.22830171883106232), ('satisfaction', 0.22802619636058807)]
#
# Training climate_change_2003 model (Income 3)
# Documents: 8
# Vocab size: 1676
# Top associations for 'climate_change_2003':
# [('determinants', 0.2523994743824005), ('much', 0.2500830590724945), ('paid', 0.23535744845867157), ('gives', 0.23212797939777374), ('long', 0.23083211481571198)]
#
# Training climate_change_2004 model (Income 3)
# Documents: 7
# Vocab size: 1337
# Top associations for 'climate_change_2004':
# [('sovereign', 0.24291975796222687), ('rest', 0.24071134626865387), ('peace', 0.23029093444347382), ('attenuate', 0.22603967785835266), ('however', 0.216499462723732)]
#
# Training climate_change_2005 model (Income 3)
# Documents: 9
# Vocab size: 1373
# Top associations for 'climate_change_2005':
# [('additional', 0.299858421087265), ('relief', 0.26118534803390503), ('must', 0.2562018036842346), ('macroeconomic', 0.2473560869693756), ('effective', 0.24334031343460083)]
#
# Training climate_change_2006 model (Income 3)
# Documents: 8
# Vocab size: 1552
# Top associations for 'climate_change_2006':
# [('stock', 0.3017773926258087), ('guidance', 0.27301517128944397), ('trade', 0.25107765197753906), ('political', 0.24854901432991028), ('causes', 0.23478427529335022)]
#
# Training climate_change_2007 model (Income 3)
# Documents: 35
# Vocab size: 5474
# Top associations for 'climate_change_2007':
# [('development', 0.999231219291687), ('united_nation', 0.9990853071212769), ('country', 0.9990471601486206), ('therefore', 0.9990452527999878), ('africa', 0.9990435242652893)]
#
# Training climate_change_2008 model (Income 3)
# Documents: 35
# Vocab size: 5008
# Top associations for 'climate_change_2008':
# [('security', 0.9987607002258301), ('world', 0.998668909072876), ('human', 0.9986608624458313), ('united_nation', 0.9986582398414612), ('countries', 0.9986141324043274)]
#
# Training climate_change_2009 model (Income 3)
# Documents: 39
# Vocab size: 6674
# Top associations for 'climate_change_2009':
# [('states', 0.9991494417190552), ('past', 0.9991130232810974), ('neither', 0.9990675449371338), ('small', 0.9990630149841309), ('available', 0.9990270137786865)]
#
# Training climate_change_2010 model (Income 3)
# Documents: 42
# Vocab size: 6243
# Top associations for 'climate_change_2010':
# [('peoples', 0.9989763498306274), ('huge', 0.9989727139472961), ('fact', 0.9989571571350098), ('many', 0.9989471435546875), ('poor', 0.9989436864852905)]
#
# Training climate_change_2011 model (Income 3)
# Documents: 38
# Vocab size: 5240
# Top associations for 'climate_change_2011':
# [('must', 0.9993079900741577), ('countries', 0.9991723895072937), ('international', 0.9991219639778137), ('security', 0.9991064071655273), ('united_nation', 0.9990946650505066)]
#
# Training climate_change_2012 model (Income 3)
# Documents: 34
# Vocab size: 5178
# Top associations for 'climate_change_2012':
# [('world', 0.9980142712593079), ('global', 0.9979154467582703), ('united_nation', 0.99774569272995), ('international', 0.9977443814277649), ('countries', 0.9976458549499512)]
#
# Training climate_change_2013 model (Income 3)
# Documents: 34
# Vocab size: 4751
# Top associations for 'climate_change_2013':
# [('development', 0.9987862706184387), ('international', 0.9987567067146301), ('agenda', 0.9986014366149902), ('therefore', 0.9985983371734619), ('syria', 0.9985790848731995)]
#
# Training climate_change_2014 model (Income 3)
# Documents: 34
# Vocab size: 5584
# Top associations for 'climate_change_2014':
# [('economic', 0.9991705417633057), ('development', 0.9991346001625061), ('state', 0.999114990234375), ('international', 0.9990986585617065), ('people', 0.9990966320037842)]
#
# Training climate_change_2015 model (Income 3)
# Documents: 42
# Vocab size: 6557
# Top associations for 'climate_change_2015':
# [('government', 0.9990358352661133), ('island', 0.999005138874054), ('national', 0.9989983439445496), ('small', 0.9989799857139587), ('global', 0.9989686012268066)]
#
# Training climate_change_2016 model (Income 3)
# Documents: 43
# Vocab size: 6326
# Top associations for 'climate_change_2016':
# [('dialogue', 0.9989538192749023), ('vulnerable', 0.9989449977874756), ('believe', 0.9989401698112488), ('lives', 0.9989392757415771), ('regional', 0.9989378452301025)]
#
# Training climate_change_2017 model (Income 3)
# Documents: 40
# Vocab size: 6625
# Top associations for 'climate_change_2017':
# [('world', 0.9990124702453613), ('principles', 0.99899822473526), ('today', 0.9989293217658997), ('meeting', 0.9989200234413147), ('system', 0.9989026188850403)]
#
# Training climate_change_2018 model (Income 3)
# Documents: 40
# Vocab size: 5622
# Top associations for 'climate_change_2018':
# [('economic', 0.999317467212677), ('international', 0.9993032217025757), ('people', 0.9992052316665649), ('region', 0.9991966485977173), ('peoples', 0.9991944432258606)]
#
# Training climate_change_2019 model (Income 3)
# Documents: 45
# Vocab size: 6866
# Top associations for 'climate_change_2019':
# [('sector', 0.9991015791893005), ('state', 0.999081015586853), ('continue', 0.9990628361701965), ('security', 0.9990475177764893), ('time', 0.99903804063797)]
#
# Training climate_change_2020 model (Income 3)
# Documents: 40
# Vocab size: 4966
# Top associations for 'climate_change_2020':
# [('pandemic', 0.9973901510238647), ('support', 0.9971892237663269), ('economic', 0.9971482753753662), ('united_nation', 0.9970500469207764), ('human', 0.9970401525497437)]
#
# Training climate_change_2021 model (Income 3)
# Documents: 43
# Vocab size: 6695
# Top associations for 'climate_change_2021':
# [('economic', 0.9989568591117859), ('crimes', 0.9989311099052429), ('infrastructure', 0.9989068508148193), ('better', 0.998904824256897), ('back', 0.9988961815834045)]
#
# Training climate_change_2022 model (Income 3)
# Documents: 41
# Vocab size: 6478
# Top associations for 'climate_change_2022':
# [('conflict', 0.9989734292030334), ('exploitation', 0.9989344477653503), ('people', 0.9989343881607056), ('tourism', 0.9989342093467712), ('injustice', 0.9989333152770996)]
#
# Training climate_change_2023 model (Income 3)
# Documents: 43
# Vocab size: 6744
# Top associations for 'climate_change_2023':
# [('process', 0.9990127682685852), ('face', 0.9989922046661377), ('international', 0.9989485144615173), ('haiti', 0.9989385604858398), ('leaders', 0.9989345073699951)]
#
# Training climate_change_2024 model (Income 3)
# Documents: 38
# Vocab size: 6113
# Top associations for 'climate_change_2024':
# [('development', 0.9990613460540771), ('world', 0.9990128874778748), ('united_nation', 0.9990122318267822), ('international', 0.9990037679672241), ('security', 0.9989820122718811)]
#
# ---------------------------------------- Income Level 4 ----------------------------------------
#
# Training climate_change_1990 model (Income 4)
# Documents: 4
# Vocab size: 1298
# Top associations for 'climate_change_1990':
# [('valuable', 0.2694438397884369), ('yesterday', 0.2422468364238739), ('demonstrating', 0.2415170520544052), ('momentum', 0.2408820539712906), ('abilities', 0.22203129529953003)]
#
# Training climate_change_1991 model (Income 4)
# Documents: 9
# Vocab size: 1443
# Top associations for 'climate_change_1991':
# [('immeasurably', 0.27516502141952515), ('interdependent', 0.2615818679332733), ('meetings', 0.25164252519607544), ('signal', 0.23058034479618073), ('dispatch', 0.20802071690559387)]
#
# Training climate_change_1992 model (Income 4)
# Documents: 4
# Vocab size: 150
# Top associations for 'climate_change_1992':
# [('livelihoods', 0.19603590667247772), ('essential', 0.1665661334991455), ('minister', 0.1539495438337326), ('signatories', 0.1529860943555832), ('nationbuilders', 0.14453789591789246)]
#
# Training climate_change_1993 model (Income 4)
# Documents: 2
# Vocab size: 68
# Top associations for 'climate_change_1993':
# [('committed', 0.14536921679973602), ('secretariat', 0.13955113291740417), ('availability', 0.12733741104602814), ('affairs', 0.11426940560340881), ('international', 0.10127198696136475)]
#
# Training climate_change_1995 model (Income 4)
# Documents: 3
# Vocab size: 628
# Top associations for 'climate_change_1995':
# [('together', 0.22986984252929688), ('november', 0.22477327287197113), ('beijing', 0.22269116342067719), ('population', 0.2133045196533203), ('infrastructure', 0.20182804763317108)]
#
# Training climate_change_1996 model (Income 4)
# Documents: 7
# Vocab size: 198
# Top associations for 'climate_change_1996':
# [('practical', 0.22050760686397552), ('would', 0.20592407882213593), ('help', 0.1689450740814209), ('north', 0.14638301730155945), ('social', 0.14536921679973602)]
#
# Training climate_change_1997 model (Income 4)
# Documents: 8
# Vocab size: 639
# Top associations for 'climate_change_1997':
# [('protect', 0.29843008518218994), ('tons', 0.23177829384803772), ('country', 0.21881103515625), ('life', 0.21880246698856354), ('ability', 0.21765385568141937)]
#
# Training climate_change_1998 model (Income 4)
# Documents: 7
# Vocab size: 805
# Top associations for 'climate_change_1998':
# [('decreasing', 0.27625465393066406), ('asia', 0.24607330560684204), ('emissions', 0.2395956665277481), ('struggle', 0.22987864911556244), ('responses', 0.2283804714679718)]
#
# Training climate_change_1999 model (Income 4)
# Documents: 7
# Vocab size: 204
# Top associations for 'climate_change_1999':
# [('agenda', 0.22049567103385925), ('greenhouse', 0.20594044029712677), ('kyoto', 0.16893550753593445), ('peoples', 0.14635686576366425), ('markets', 0.14531974494457245)]
#
# Training climate_change_2000 model (Income 4)
# Documents: 5
# Vocab size: 630
# Top associations for 'climate_change_2000':
# [('impoverished', 0.260024756193161), ('mid2002', 0.24309620261192322), ('centre', 0.22371986508369446), ('ratify', 0.22331252694129944), ('seattle', 0.20499302446842194)]
#
# Training climate_change_2001 model (Income 4)
# Documents: 5
# Vocab size: 164
# Top associations for 'climate_change_2001':
# [('reassessment', 0.22583091259002686), ('world', 0.18278683722019196), ('postponed', 0.15415571630001068), ('next', 0.1525111198425293), ('overall', 0.14895407855510712)]
#
# Training climate_change_2002 model (Income 4)
# Documents: 2
# Vocab size: 71
# Top associations for 'climate_change_2002':
# [('including', 0.18279105424880981), ('call', 0.1363266259431839), ('water', 0.13457264006137848), ('small', 0.13382205367088318), ('bahamas', 0.1302417367696762)]
#
# Training climate_change_2003 model (Income 4)
# Documents: 2
# Vocab size: 57
# Top associations for 'climate_change_2003':
# [('states', 0.17005769908428192), ('affect', 0.1604202389717102), ('specifically', 0.12622545659542084), ('detailed', 0.11601787805557251), ('united', 0.09617381542921066)]
#
# Training climate_change_2004 model (Income 4)
# Documents: 9
# Vocab size: 1519
# Top associations for 'climate_change_2004':
# [('members', 0.28961363434791565), ('construction', 0.2642052173614502), ('united', 0.24328644573688507), ('determine', 0.2397202104330063), ('aside', 0.2358626127243042)]
#
# Training climate_change_2005 model (Income 4)
# Documents: 7
# Vocab size: 1892
# Top associations for 'climate_change_2005':
# [('foregoing', 0.31441691517829895), ('tribute', 0.24145357310771942), ('constructively', 0.23825900256633759), ('peace', 0.2378389835357666), ('responsibility', 0.23539520800113678)]
#
# Training climate_change_2006 model (Income 4)
# Documents: 11
# Vocab size: 1707
# Top associations for 'climate_change_2006':
# [('ahead', 0.3206591010093689), ('work', 0.26866307854652405), ('shanghai', 0.26261910796165466), ('programme', 0.23641230165958405), ('demonstrates', 0.23508787155151367)]
#
# Training climate_change_2007 model (Income 4)
# Documents: 43
# Vocab size: 5455
# Top associations for 'climate_change_2007':
# [('need', 0.998894989490509), ('hope', 0.9988419413566589), ('convention', 0.998833179473877), ('cooperation', 0.9987619519233704), ('progress', 0.9987496733665466)]
#
# Training climate_change_2008 model (Income 4)
# Documents: 40
# Vocab size: 5046
# Top associations for 'climate_change_2008':
# [('efforts', 0.9992347359657288), ('international', 0.9991979002952576), ('united_nation', 0.9991738796234131), ('must', 0.9991483092308044), ('african', 0.9991437196731567)]
#
# Training climate_change_2009 model (Income 4)
# Documents: 45
# Vocab size: 5977
# Top associations for 'climate_change_2009':
# [('power', 0.9988009929656982), ('effort', 0.9987995028495789), ('humanitarian', 0.9987906217575073), ('report', 0.9987883567810059), ('debt', 0.9987701773643494)]
#
# Training climate_change_2010 model (Income 4)
# Documents: 37
# Vocab size: 4741
# Top associations for 'climate_change_2010':
# [('turkish', 0.999224841594696), ('international', 0.9992154836654663), ('united_nation', 0.9991887211799622), ('national', 0.9991872906684875), ('council', 0.9991733431816101)]
#
# Training climate_change_2011 model (Income 4)
# Documents: 32
# Vocab size: 4003
# Top associations for 'climate_change_2011':
# [('peace', 0.9786505103111267), ('united_nation', 0.978570818901062), ('challenges', 0.9785280823707581), ('people', 0.9783995151519775), ('need', 0.9778286814689636)]
#
# Training climate_change_2012 model (Income 4)
# Documents: 25
# Vocab size: 3595
# Top associations for 'climate_change_2012':
# [('must', 0.7414478063583374), ('community', 0.7335871458053589), ('small', 0.7287558317184448), ('people', 0.7050790190696716), ('international', 0.7031548619270325)]
#
# Training climate_change_2013 model (Income 4)
# Documents: 26
# Vocab size: 4569
# Top associations for 'climate_change_2013':
# [('world', 0.9969711899757385), ('development', 0.9967957139015198), ('international', 0.9966549277305603), ('also', 0.9965953230857849), ('people', 0.9965564608573914)]
#
# Training climate_change_2014 model (Income 4)
# Documents: 43
# Vocab size: 5395
# Top associations for 'climate_change_2014':
# [('international', 0.9991549253463745), ('global', 0.9991401433944702), ('protection', 0.9991345405578613), ('peace', 0.9990878105163574), ('need', 0.9990788698196411)]
#
# Training climate_change_2015 model (Income 4)
# Documents: 42
# Vocab size: 5452
# Top associations for 'climate_change_2015':
# [('peaceful', 0.9989753365516663), ('international', 0.9989525675773621), ('agenda', 0.9989416003227234), ('right', 0.9989399313926697), ('small', 0.9989222288131714)]
#
# Training climate_change_2016 model (Income 4)
# Documents: 43
# Vocab size: 5572
# Top associations for 'climate_change_2016':
# [('peace', 0.9990633726119995), ('countries', 0.9990083575248718), ('would', 0.9989968538284302), ('security', 0.9989721775054932), ('must', 0.9989697933197021)]
#
# Training climate_change_2017 model (Income 4)
# Documents: 47
# Vocab size: 5993
# Top associations for 'climate_change_2017':
# [('effects', 0.9988634586334229), ('weapons', 0.998837947845459), ('natural', 0.9988038539886475), ('even', 0.9987723231315613), ('future', 0.9987647533416748)]
#
# Training climate_change_2018 model (Income 4)
# Documents: 47
# Vocab size: 6620
# Top associations for 'climate_change_2018':
# [('hurricane', 0.9988333582878113), ('relevant', 0.9987413883209229), ('democracy', 0.9987189769744873), ('rome', 0.9987148642539978), ('meet', 0.9987084865570068)]
#
# Training climate_change_2019 model (Income 4)
# Documents: 52
# Vocab size: 7526
# Top associations for 'climate_change_2019':
# [('costly', 0.9986803531646729), ('approximately', 0.9986191987991333), ('developing', 0.9986013770103455), ('organizations', 0.9985702633857727), ('online', 0.9985697865486145)]
#
# Training climate_change_2020 model (Income 4)
# Documents: 44
# Vocab size: 6108
# Top associations for 'climate_change_2020':
# [('work', 0.9990756511688232), ('also', 0.9990026354789734), ('people', 0.9989961385726929), ('time', 0.9989480972290039), ('developing', 0.9989296793937683)]
#
# Training climate_change_2021 model (Income 4)
# Documents: 54
# Vocab size: 7306
# Top associations for 'climate_change_2021':
# [('spoke', 0.9987761974334717), ('cancer', 0.9987330436706543), ('1980s', 0.9987235069274902), ('constitutional', 0.9987162351608276), ('grandparents', 0.9986937046051025)]
#
# Training climate_change_2022 model (Income 4)
# Documents: 56
# Vocab size: 7001
# Top associations for 'climate_change_2022':
# [('2050', 0.9986358284950256), ('truth', 0.9985734820365906), ('together', 0.998562753200531), ('moreover', 0.9985622763633728), ('bucha', 0.9985479712486267)]
#
# Training climate_change_2023 model (Income 4)
# Documents: 60
# Vocab size: 7046
# Top associations for 'climate_change_2023':
# [('construction', 0.9987554550170898), ('implementation', 0.998673677444458), ('born', 0.9986682534217834), ('starting', 0.9986631274223328), ('fight', 0.9986251592636108)]
#
# Training climate_change_2024 model (Income 4)
# Documents: 43
# Vocab size: 5900
# Top associations for 'climate_change_2024':
# [('cannot', 0.9990431070327759), ('international', 0.9990236759185791), ('past', 0.9989470839500427), ('children', 0.9989432096481323), ('national', 0.9989412426948547)]

# %%
""" top_similar_by_year = {}

for income_level, models_by_year in all_models.items():
    for year, model in models_by_year.items():
        token = f"climate_change_{year}"
        
        if token in model.wv:
            similar_words = model.wv.most_similar(token, topn=5)
            top_similar_by_year[(income_level, year)] = [word for word, _ in similar_words]
        else:
            print('something wrong')
            top_similar_by_year[(income_level, year)] = [None] * 5


top_words_df = pd.DataFrame.from_dict(top_similar_by_year, orient='index')
top_words_df.index = pd.MultiIndex.from_tuples(top_words_df.index, names=['Income_Level', 'Year'])
top_words_df.columns = [f"Rank_{i+1}" for i in range(top_words_df.shape[1])]

top_words_df = top_words_df.sort_index()
top_words_df """
# Out:
# ' top_similar_by_year = {}\n\nfor income_level, models_by_year in all_models.items():\n    for year, model in models_by_year.items():\n        token = f"climate_change_{year}"\n\n        if token in model.wv:\n            similar_words = model.wv.most_similar(token, topn=5)\n            top_similar_by_year[(income_level, year)] = [word for word, _ in similar_words]\n        else:\n            print(\'something wrong\')\n            top_similar_by_year[(income_level, year)] = [None] * 5\n\n\ntop_words_df = pd.DataFrame.from_dict(top_similar_by_year, orient=\'index\')\ntop_words_df.index = pd.MultiIndex.from_tuples(top_words_df.index, names=[\'Income_Level\', \'Year\'])\ntop_words_df.columns = [f"Rank_{i+1}" for i in range(top_words_df.shape[1])]\n\ntop_words_df = top_words_df.sort_index()\ntop_words_df '

# %%
plot_data = []

for income_level, models_by_year in all_models.items():
    print(income_level)
    for year, model in models_by_year.items():
        target_token = f"climate_change_{year}"
        
        if target_token not in model.wv:
            continue
        
        # Add climate_change_YEAR
        plot_data.append({
            'token': target_token,
            'vector': model.wv[target_token],
            'year': year,
            'source': 'climate_change',
            'income_level': income_level
        })
        
        # Add top N similar words
        similar = model.wv.most_similar(target_token, topn=2)
        for word, _ in similar:
            if word in model.wv:
                plot_data.append({
                    'token': word,
                    'vector': model.wv[word],
                    'year': year,
                    'source': 'neighbor',
                    'income_level': income_level
                })
#    break

    df_plot = pd.DataFrame(plot_data)
    

    # Stack vectors into 2D array for t-SNE
    X = np.vstack(df_plot['vector'].values)

    # Run t-SNE
    tsne = TSNE(n_components=2, perplexity=10, metric='cosine', random_state=42)
    X_2d = tsne.fit_transform(X)

    # Store the result back in the DataFrame
    df_plot['TSNE_1'] = X_2d[:, 0]
    df_plot['TSNE_2'] = X_2d[:, 1]

    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=df_plot,
        x='TSNE_1',
        y='TSNE_2',
        hue='year',
        style='source',
        palette='coolwarm',
        alpha=1
    )

    # Prepare all labels as objects
    texts = []

    # Climate change labels
    for _, row in df_plot[df_plot['source'] == 'climate_change'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=9, weight='bold')
        )

    # Neighbor labels (optional, maybe use fewer or smaller fontsize)
    for _, row in df_plot[df_plot['source'] == 'neighbor'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=7, alpha=0.7)
        )

    # Adjust to avoid overlaps
    adjust_text(texts, 
                arrowprops=dict(arrowstyle="-", color='gray', lw=0.5), 
                expand_points=(1.2, 1.2), 
                expand_text=(1.2, 1.2),
                force_text=0.25,
                force_points=0.25)

    plt.title("t-SNE: Semantic Drift of 'climate_change_YEAR' and Neighbors")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    break
# Out:
# 1

# %%
from sklearn.manifold import TSNE
import numpy as np

# Stack vectors into 2D array for t-SNE
X = np.vstack(df_plot['vector'].values)

# Run t-SNE
tsne = TSNE(n_components=2, perplexity=5, metric='cosine', random_state=42)
X_2d = tsne.fit_transform(X)

# Store the result back in the DataFrame
df_plot['TSNE_1'] = X_2d[:, 0]
df_plot['TSNE_2'] = X_2d[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df_plot,
    x='TSNE_1',
    y='TSNE_2',
    hue='year',
    style='source',
    palette='coolwarm',
    alpha=0.8
)

# Prepare all labels as objects
texts = []

# Climate change labels
for _, row in df_plot[df_plot['source'] == 'climate_change'].iterrows():
    texts.append(
        plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=9, weight='bold')
    )

# Neighbor labels (optional, maybe use fewer or smaller fontsize)
for _, row in df_plot[df_plot['source'] == 'neighbor'].iterrows():
    texts.append(
        plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=6, alpha=0.7)
    )

# Adjust to avoid overlaps
adjust_text(texts, 
            arrowprops=dict(arrowstyle="-", color='gray', lw=0.5), 
            expand_points=(1.2, 1.2), 
            expand_text=(1.2, 1.2),
            force_text=0.25,
            force_points=0.25)

plt.title("t-SNE: Semantic Drift of 'climate_change_YEAR' and Neighbors")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 12
#       9 X_2d = tsne.fit_transform(X)
#      11 # Store the result back in the DataFrame
# ---> 12 df_plot['TSNE_1'] = X_2d[:, 0]
#      13 df_plot['TSNE_2'] = X_2d[:, 1]
#      15 plt.figure(figsize=(12, 8))
#
# File c:\Users\alvar\OneDrive\Escritorio\clean_nlp_env\venv\Lib\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File c:\Users\alvar\OneDrive\Escritorio\clean_nlp_env\venv\Lib\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\alvar\OneDrive\Escritorio\clean_nlp_env\venv\Lib\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)   5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File c:\Users\alvar\OneDrive\Escritorio\clean_nlp_env\venv\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (102) does not match length of index (408)
