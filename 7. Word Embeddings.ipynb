# %%
# pip install "numpy>=2.0.0,<3.0.0"

# %%
# no hace falta runearlo por ahora
# !pip install scikit-learn

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords  # You need to import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alvar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import ast
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import re
from gensim.utils import simple_preprocess
from pathlib import Path
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import contractions
from nltk import pos_tag
from nltk.corpus import stopwords
import matplotlib.ticker as ticker
from gensim.models import Word2Vec
from collections import defaultdict
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from adjustText import adjust_text

# %%
def clean_and_lowercase_list_column(df, column_name):
    """
    Converts stringified lists in a column to real lists and lowercases each string element.
    
    Parameters:
        df (pd.DataFrame): The DataFrame containing the column.
        column_name (str): The name of the column to clean.
    
    Returns:
        pd.DataFrame: A copy of the DataFrame with the cleaned column.
    """
    # df = df.copy()
    
    # Convert stringified lists to real lists
    df[column_name] = df[column_name].apply(
        lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
    )
    
    # Lowercase each string in the list
    df[column_name] = df[column_name].apply(
        lambda lst: [s.lower() for s in lst] if isinstance(lst, list) else lst
    )
    
    return df

# %%
def extract_keyword_info(text, keyword):
    """
    Extracts climate-related keyword information from a text string.

    Parameters:
        text (str): The speech or text in which to search for keywords.
        keywords (list of str): A list of climate-related keywords or phrases to match against the text.
    """
    matches = []
    pattern = r'\b' + re.escape(keyword) + r's?\b' # Match also plural forms
    if re.search(pattern, text, flags=re.IGNORECASE):
        matches.append(keyword)
    contains_keyword = len(matches) > 0
    return pd.Series([matches, contains_keyword])

# %%
bigrams = ["climate change", "global warming", "global warm","cap and trade", "paris accord", "emissions trading", "global average temperature", 
            "kyoto protocol", "changing climate" ,"climate resilience","climate decay", "carbon dioxide", "carbon-dioxide","climate politics", 
            "framework on convention climate change", "bali roadmap", "bali action plan", 
            "greenhouse gas", "greenhouse-gas","greenhouse effect", "climate mitigation", "climate action", "emissions", "temperature", "extreme weather", 
            "global environmental change", "global environment", "global environmental" ,"climate variability", "low carbon", "renewable energy", 
            "carbon emission", "climate pollutant", "climate pollutants", "carbon tax", "carbon footprint", "carbon neutrality", 
            "net zero","net-zero","climate crisis", "climate summit", "climate catastrophe", "climate justice", "climate emergency", "climate funding",
            "climate fund", "climate financing", "climate finance","climate peace", "climate agreement", "climate security", "climate ambition", 
            "climate issue", "climate impact", "climate conference", "climate event", "climate challenge", "climate trust", "climate negotiation", 
            "climate catastrophe", "climate risk", "climate goal", "climate change-related", "climate regime", "climate resilient", "climate policy", 
            "carbon market", "carbon sink", "green climate", "green economy", "emission reduction", "emissions reduction", "carbon neutral", 
            "ozone layer", "emissions trading scheme", "co2 emission", "united nation"]

bigrams_1 = sorted(bigrams, key=lambda x: -len(x.split()))

def replace_bigrams(text, bigrams):
    for phrase in bigrams:
        # Normalize the phrase: convert dashes to spaces
        normalized_phrase = phrase.replace("-", " ")
        # Build regex pattern from normalized phrase
        pattern = r'\b' + re.escape(normalized_phrase) +  r's?\b'
        # Replace spaces (now consistent) with underscores
        underscored = normalized_phrase.replace(" ", "_")
        text = re.sub(pattern, underscored, text)
    return text

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
def extract_climate_sentences_with_context(speech, keywords):
    """
    Extracts sentences containing climate keywords along with one sentence before and after each.
    Returns a list of context windows (strings of 1–3 sentences).
    """
    doc = list(nlp(speech).sents)  # Convert to list to access by index
    context_windows = []

    for i, sent in enumerate(doc):
        sent_text = sent.text.strip()

        if any(kw.lower() in sent_text.lower() for kw in keywords):
            # Grab the previous, current, and next sentence if available
            prev_sent = doc[i-1].text.strip() if i > 0 else ''
            next_sent = doc[i+1].text.strip() if i < len(doc) - 1 else ''
            
            context = ' '.join([s for s in [prev_sent, sent_text, next_sent] if s])
            context_windows.append(context)

    return context_windows

# %%
def select_text(entry_1, entry_2, entry_3):
    text = entry_2 if entry_3 == 1 else entry_1
    return text

def get_text(df, entry_1, entry_2, entry_3):

    df['final_text'] = df.progress_apply(
        lambda row: select_text(row[entry_1], row[entry_2], row[entry_3]),
        axis=1
    )

    return df

def preprocess_text(entry_1):
    # Choose text source based on count_climate_change
    text = entry_1

    custom_stopwords = {'mr', 'there', 'that', 'this', 'they', 'them', 'those', 'themselves'} | set(stop_words)

    tokens = text.split()
    
    return [token for token in tokens
        if (token.lower() not in custom_stopwords)  # Case-insensitive check
        and (len(token) > 3)]

def preprocess_df(df, column_1):
    tqdm.pandas()
    
    # Apply preprocessing and store results in 'tokens' column
    df['tokens'] = df.progress_apply(
        lambda row: preprocess_text(row[column_1]),
        axis=1
    )
    
    return df

# %% [markdown]
# # 1. Data

# %%
base_path_alvaro = Path(r"C:\Users\alvar\OneDrive\Escritorio\BDS\Block_5\NLP\Project")

base_path = base_path_alvaro # change according to user

# %%
# Step 1. Call the data
final_df = pd.read_csv(base_path / "Final_df_extended.csv")

# Step 2. Select only the climate related speeches
df_sentiment = final_df[final_df['contains_climate_keyword'] != False]

# Step 3. Keep only the most important columns
df_climate_change = df_sentiment.drop(['Session', 'Speech', 'number_sentences', 'number_tokens', 'cleaned_speeches_postagging_expanded', 'contains_climate_keyword', 'climate_sentences', 'contains_climate_keyword', 'matched_climate_keywords', 'climate_sentences_extended'], axis = 1)

# %%
tqdm.pandas()
# Step 1: Replace bigrams
df_climate_change["speeches_for_keyword_search"] = df_climate_change["speeches_for_keyword_search"].progress_apply(
    lambda x: replace_bigrams(x, bigrams)
)

# Step 2. Select only those speeches that mention CLIMATE_CHANGE
df_climate_change[['matched_climate_keywords', 'contains_climate_keyword']] = df_climate_change['speeches_for_keyword_search'].progress_apply(
    lambda text: extract_keyword_info(text, 'climate_change')
)

# Step 3. Only select those instances with climate = True
df_climate_change_smp = df_climate_change[df_climate_change['contains_climate_keyword'] == True]

# Step 4. Extend the climate sentences WATCH OUT WITH THE HEAD HERE LIL BOI
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp.progress_apply(
    lambda row: extract_climate_sentences_with_context(row['speeches_for_keyword_search'], row['matched_climate_keywords']),
    axis=1
)

df_climate_change_smp = df_climate_change_smp.rename(columns={"speeches_for_keyword_search": "speeches_for_word2vec"}).drop(['matched_climate_keywords', 'contains_climate_keyword'], axis = 1)

# Step 5: Remove 'mr. president' (case-insensitive, with or without period)
df_climate_change_smp["speeches_for_word2vec"] = df_climate_change_smp["speeches_for_word2vec"].str.replace(
    r'\bmr\.?\s+president\b', '', flags=re.IGNORECASE, regex=True
)

# Step 6: Remove punctuation from word2vec
df_climate_change_smp['speeches_for_word2vec'] = df_climate_change_smp['speeches_for_word2vec'].str.replace(
    r'[^\w\s]', '', regex=True
)

# Step 7: Turn climate_sentences_extended into a STR and not a list
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp['climate_sentences_extended'].apply(
    lambda sentences: ' '.join(sentences) if isinstance(sentences, list) else sentences
)

# Step 8: Remove punctuation from climate_sentences_extended
df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp['climate_sentences_extended'].str.replace(
    r'[^\w\s]', '', regex=True
)

# Step 9: count the instances of climate_change in the speech
df_climate_change_smp["count_climate_change"] = df_climate_change_smp["speeches_for_word2vec"].str.count("climate_change")

df_climate_change_smp
# Out:
# 100%|██████████| 3380/3380 [01:44<00:00, 32.43it/s]
# 100%|██████████| 3380/3380 [00:01<00:00, 2473.46it/s]
# 100%|██████████| 2946/2946 [23:23<00:00,  2.10it/s]
# C:\Users\alvar\AppData\Local\Temp\ipykernel_12028\3199499718.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_climate_change_smp['climate_sentences_extended'] = df_climate_change_smp.progress_apply(
#       Year ISO-Code  Income Level  \
# 4     1990      BGD             1
# 6     1990      CHN             1
# 8     1990      COD             1
# 14    1990      DNK             4
# 21    1990      ISL             4
# ...    ...      ...           ...
# 3375  2024      WSM             2
# 3376  2024      YEM             1
# 3377  2024      ZAF             3
# 3378  2024      ZMB             2
# 3379  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 4      warm felicitations are due you on your wellde...
# 6     i should like to begin by warmly congratulatin...
# 8      the fortyfifth session of the united_nation g...
# 14    i congratulate you sir on your election as pre...
# 21     to congratulate you on your election to our h...
# ...                                                 ...
# 3375  excellencies i extend my congratulations to hi...
# 3376  ladies and gentlemen it is a happy coincidence...
# 3377  president of the 79th session of the un genera...
# 3378  ladies and gentlemen i congratulate you your e...
# 3379  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change
# 4     the conference must produce results that will ...                     1
# 6     looking forward into the 1990s we see a world ...                     1
# 8     an increase in the planets average temperature...                     1
# 14    at the same time we must not lose sight of oth...                     4
# 21    international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 3375  please be assured of samoas support in the suc...                     7
# 3376  for this reason the republic of yemen renews i...                     1
# 3377  extreme_weather such as flooding fires and dro...                     2
# 3378  furthermore zambia recognises the efforts of h...                     2
# 3379  in this spirit of unity we must prioritize the...                     4
#
# [2946 rows x 6 columns]

# %%
df = get_text(df_climate_change_smp.copy(), entry_1='speeches_for_word2vec', entry_2='climate_sentences_extended',entry_3='count_climate_change')
df
# Out:
# 100%|██████████| 2946/2946 [00:00<00:00, 95783.23it/s]
#       Year ISO-Code  Income Level  \
# 4     1990      BGD             1
# 6     1990      CHN             1
# 8     1990      COD             1
# 14    1990      DNK             4
# 21    1990      ISL             4
# ...    ...      ...           ...
# 3375  2024      WSM             2
# 3376  2024      YEM             1
# 3377  2024      ZAF             3
# 3378  2024      ZMB             2
# 3379  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 4      warm felicitations are due you on your wellde...
# 6     i should like to begin by warmly congratulatin...
# 8      the fortyfifth session of the united_nation g...
# 14    i congratulate you sir on your election as pre...
# 21     to congratulate you on your election to our h...
# ...                                                 ...
# 3375  excellencies i extend my congratulations to hi...
# 3376  ladies and gentlemen it is a happy coincidence...
# 3377  president of the 79th session of the un genera...
# 3378  ladies and gentlemen i congratulate you your e...
# 3379  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change  \
# 4     the conference must produce results that will ...                     1
# 6     looking forward into the 1990s we see a world ...                     1
# 8     an increase in the planets average temperature...                     1
# 14    at the same time we must not lose sight of oth...                     4
# 21    international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 3375  please be assured of samoas support in the suc...                     7
# 3376  for this reason the republic of yemen renews i...                     1
# 3377  extreme_weather such as flooding fires and dro...                     2
# 3378  furthermore zambia recognises the efforts of h...                     2
# 3379  in this spirit of unity we must prioritize the...                     4
#
#                                              final_text
# 4     the conference must produce results that will ...
# 6     looking forward into the 1990s we see a world ...
# 8     an increase in the planets average temperature...
# 14    i congratulate you sir on your election as pre...
# 21    international treaties in specific fields of t...
# ...                                                 ...
# 3375  excellencies i extend my congratulations to hi...
# 3376  for this reason the republic of yemen renews i...
# 3377  president of the 79th session of the un genera...
# 3378  ladies and gentlemen i congratulate you your e...
# 3379  your excellency mr philemon yang president of ...
#
# [2946 rows x 7 columns]

# %% [markdown]
# # START HERE

# %%
#df.to_csv(base_path_alvaro / "DF_word_embeddings.csv", index=False, encoding='utf-8')
df_wo_tokens = pd.read_csv(base_path_alvaro / "DF_word_embeddings.csv")

df_wo_tokens["final_text"] = df_wo_tokens.apply(
    lambda row: row["final_text"].replace("climate_change", f"climate_change_{row['Year']}"),
    axis=1
)

df_w_tokens = preprocess_df(df_wo_tokens.copy(), column_1='final_text')
df_w_tokens.iloc[0]['final_text']
# Out:
# 100%|██████████| 2946/2946 [00:00<00:00, 3406.62it/s]
# 'the conference must produce results that will assist countries particularly in the developing world to meet their obligations we hope the proposed conventions on climate_change_1990 and on the protection of biodiversity will soon be ready for signature a mainstay of the consolidation of global peace development and security is the effort to strengthen the rule of international law'

# %%
df_w_tokens
# Out:
#       Year ISO-Code  Income Level  \
# 0     1990      BGD             1
# 1     1990      CHN             1
# 2     1990      COD             1
# 3     1990      DNK             4
# 4     1990      ISL             4
# ...    ...      ...           ...
# 2941  2024      WSM             2
# 2942  2024      YEM             1
# 2943  2024      ZAF             3
# 2944  2024      ZMB             2
# 2945  2024      ZWE             2
#
#                                   speeches_for_word2vec  \
# 0      warm felicitations are due you on your wellde...
# 1     i should like to begin by warmly congratulatin...
# 2      the fortyfifth session of the united_nation g...
# 3     i congratulate you sir on your election as pre...
# 4      to congratulate you on your election to our h...
# ...                                                 ...
# 2941  excellencies i extend my congratulations to hi...
# 2942  ladies and gentlemen it is a happy coincidence...
# 2943  president of the 79th session of the un genera...
# 2944  ladies and gentlemen i congratulate you your e...
# 2945  your excellency mr philemon yang president of ...
#
#                              climate_sentences_extended  count_climate_change  \
# 0     the conference must produce results that will ...                     1
# 1     looking forward into the 1990s we see a world ...                     1
# 2     an increase in the planets average temperature...                     1
# 3     at the same time we must not lose sight of oth...                     4
# 4     international treaties in specific fields of t...                     1
# ...                                                 ...                   ...
# 2941  please be assured of samoas support in the suc...                     7
# 2942  for this reason the republic of yemen renews i...                     1
# 2943  extreme_weather such as flooding fires and dro...                     2
# 2944  furthermore zambia recognises the efforts of h...                     2
# 2945  in this spirit of unity we must prioritize the...                     4
#
#                                              final_text  \
# 0     the conference must produce results that will ...
# 1     looking forward into the 1990s we see a world ...
# 2     an increase in the planets average temperature...
# 3     i congratulate you sir on your election as pre...
# 4     international treaties in specific fields of t...
# ...                                                 ...
# 2941  excellencies i extend my congratulations to hi...
# 2942  for this reason the republic of yemen renews i...
# 2943  president of the 79th session of the un genera...
# 2944  ladies and gentlemen i congratulate you your e...
# 2945  your excellency mr philemon yang president of ...
#
#                                                  tokens
# 0     [conference, must, produce, results, assist, c...
# 1     [looking, forward, 1990s, world, faced, challe...
# 2     [increase, planets, average, temperature, lead...
# 3     [congratulate, election, president, general, a...
# 4     [international, treaties, specific, fields, en...
# ...                                                 ...
# 2941  [excellencies, extend, congratulations, excell...
# 2942  [reason, republic, yemen, renews, call, intern...
# 2943  [president, 79th, session, general, assembly, ...
# 2944  [ladies, gentlemen, congratulate, excellency, ...
# 2945  [excellency, philemon, yang, president, 79th, ...
#
# [2946 rows x 8 columns]

# %%
all_models = {}

for i in range(1, 5):  # For each income level
    print(f'\n{"-"*40} Income Level {i} {"-"*40}')
    
    df_income = df_w_tokens[df_w_tokens['Income Level'] == i]

    # Group by year to get list of sentences per year
    grouped_by_year = df_income.groupby('Year')['tokens'].apply(list)

    # Optional: for inspection
    grouped_by_year_df = grouped_by_year.reset_index(name='tokens')

    # Dictionary to store yearly models
    models_by_year = {}
    
    for year, sentences in grouped_by_year.items():
        # Extract climate sentences for this specific year
        flat_sentences = [s for s in sentences if len(s) > 0]
        
        if not flat_sentences:
            print(f"Skipping year {year} - no climate sentences")
            continue
            
        print(f"\nTraining climate_change_{year} model (Income {i})")
        print(f"Documents: {len(flat_sentences)}")
        
        model = Word2Vec(
            sentences=flat_sentences,
            vector_size=150,
            window=10,
            min_count=1,  # Increased from 1 for better quality
            sample=1e-5,
            workers=4,
            sg=1,
            seed=42,
            epochs=10
        )
        
        # Store with year-specific key
        models_by_year[year] = model
        
        # Yearly diagnostics
        print(f"Vocab size: {len(model.wv)}")
        climate_key = f"climate_change_{year}"
        try:
            print(f"Top associations for '{climate_key}':")
            print(model.wv.most_similar(positive=[climate_key], topn=10))
        except KeyError:
            print(f"'{climate_key}' not in vocabulary")
    
    all_models[i] = models_by_year
# Out:
# ---------------------------------------- Income Level 1 ----------------------------------------
#
# Training climate_change_1990 model (Income 1)
# Documents: 4
# Vocab size: 880
# Top associations for 'climate_change_1990':
# [('newest', 0.2844316065311432), ('hazards', 0.24801857769489288), ('partners', 0.24469779431819916), ('mercenaries', 0.2338961511850357), ('dismantled', 0.22689150273799896), ('revitalize', 0.22202037274837494), ('programmes', 0.21476812660694122), ('agencies', 0.1930307000875473), ('population', 0.18926019966602325), ('enjoys', 0.18887430429458618)]
#
# Training climate_change_1991 model (Income 1)
# Documents: 2
# Vocab size: 118
# Top associations for 'climate_change_1991':
# [('recognized', 0.22766292095184326), ('forward', 0.19723685085773468), ('proposals', 0.17473183572292328), ('role', 0.1730346530675888), ('peoples', 0.17094294726848602), ('pacific', 0.16290149092674255), ('specific', 0.15523900091648102), ('international', 0.14011754095554352), ('hope', 0.13538223505020142), ('untenable', 0.1296842098236084)]
#
# Training climate_change_1992 model (Income 1)
# Documents: 11
# Vocab size: 273
# Top associations for 'climate_change_1992':
# [('nations', 0.26159554719924927), ('ignoring', 0.225995272397995), ('early', 0.2069367915391922), ('biodiversity', 0.18253886699676514), ('follow', 0.164656400680542), ('mankind', 0.16218572854995728), ('obligations', 0.15415430068969727), ('zaire', 0.15245968103408813), ('make', 0.14911389350891113), ('rights', 0.1450067162513733)]
#
# Training climate_change_1993 model (Income 1)
# Documents: 3
# Vocab size: 91
# Top associations for 'climate_change_1993':
# [('role', 0.19603592157363892), ('country', 0.15405626595020294), ('readiness', 0.1529860943555832), ('production', 0.1444990187883377), ('ozone_layer', 0.14043189585208893), ('historic', 0.13663876056671143), ('made', 0.12406811118125916), ('biological', 0.12103796005249023), ('review', 0.11941985040903091), ('challenge', 0.1176697313785553)]
#
# Training climate_change_1994 model (Income 1)
# Documents: 5
# Vocab size: 830
# Top associations for 'climate_change_1994':
# [('impossible', 0.24368348717689514), ('certainly', 0.240714892745018), ('time', 0.23973865807056427), ('multilateralism', 0.23755094408988953), ('management', 0.22320084273815155), ('beginning', 0.22184640169143677), ('presence', 0.21420030295848846), ('another', 0.2133466601371765), ('challenge', 0.20320995151996613), ('virtual', 0.20233294367790222)]
#
# Training climate_change_1995 model (Income 1)
# Documents: 3
# Vocab size: 97
# Top associations for 'climate_change_1995':
# [('june', 0.23772215843200684), ('awareness', 0.23646733164787292), ('serious', 0.16915570199489594), ('global', 0.1664217710494995), ('october', 0.16230802237987518), ('shoulder', 0.15642303228378296), ('africa', 0.14685679972171783), ('responsibility', 0.1410072296857834), ('framework', 0.13738909363746643), ('conventions', 0.12599210441112518)]
#
# Training climate_change_1996 model (Income 1)
# Documents: 2
# Vocab size: 68
# Top associations for 'climate_change_1996':
# [('watersharing', 0.23642006516456604), ('code', 0.19990822672843933), ('stresses', 0.15354865789413452), ('united_nation', 0.1525779664516449), ('particular', 0.1456107199192047), ('official', 0.12370853126049042), ('conduct', 0.12205570191144943), ('committee', 0.10459326207637787), ('joint', 0.10386069864034653), ('sharing', 0.10261811316013336)]
#
# Training climate_change_1997 model (Income 1)
# Documents: 3
# Vocab size: 136
# Top associations for 'climate_change_1997':
# [('effective', 0.1960323005914688), ('mkapa', 0.1665777862071991), ('touched', 0.15404470264911652), ('welcomed', 0.15297529101371765), ('spirit', 0.14450562000274658), ('exploitation', 0.14231066405773163), ('biodiversity', 0.14040358364582062), ('holding', 0.13664554059505463), ('regrettable', 0.12460699677467346), ('president', 0.12406791001558304)]
#
# Training climate_change_1998 model (Income 1)
# Documents: 5
# Vocab size: 830
# Top associations for 'climate_change_1998':
# [('fish', 0.2579498589038849), ('china', 0.24864934384822845), ('rejoiced', 0.23545527458190918), ('undertaken', 0.2283366322517395), ('negotiate', 0.2201424092054367), ('peace', 0.21858014166355133), ('greenhouse', 0.20757746696472168), ('economy', 0.2070513665676117), ('debtforgiving', 0.20512624084949493), ('council', 0.19416694343090057)]
#
# Training climate_change_1999 model (Income 1)
# Documents: 2
# Vocab size: 708
# Top associations for 'climate_change_1999':
# [('promoting', 0.22988635301589966), ('400000', 0.22597363591194153), ('activities', 0.21885576844215393), ('administrative', 0.2047020047903061), ('mass', 0.20089970529079437), ('advancement', 0.20030561089515686), ('caledonia', 0.20020261406898499), ('firmly', 0.19507279992103577), ('twentyfirst', 0.19404491782188416), ('projects', 0.18376576900482178)]
#
# Training climate_change_2000 model (Income 1)
# Documents: 4
# Vocab size: 177
# Top associations for 'climate_change_2000':
# [('decisions', 0.26155248284339905), ('opportunities', 0.22605504095554352), ('biodiversity', 0.18269437551498413), ('emerging', 0.15415330231189728), ('year', 0.15252315998077393), ('access', 0.1488933116197586), ('careful', 0.14496193826198578), ('remains', 0.13736818730831146), ('polluted', 0.13635772466659546), ('republic', 0.13454648852348328)]
#
# Training climate_change_2001 model (Income 1)
# Documents: 5
# Vocab size: 1201
# Top associations for 'climate_change_2001':
# [('force', 0.25247523188591003), ('capacity', 0.23622265458106995), ('developed', 0.2332426756620407), ('exceed', 0.21809761226177216), ('flexibility', 0.21562623977661133), ('evident', 0.21192041039466858), ('contracts', 0.21061761677265167), ('testban', 0.20144090056419373), ('nations', 0.19946104288101196), ('amendments', 0.19858093559741974)]
#
# Training climate_change_2002 model (Income 1)
# Documents: 6
# Vocab size: 1388
# Top associations for 'climate_change_2002':
# [('density', 0.2790679633617401), ('humble', 0.2397623509168625), ('conflicts', 0.2255171835422516), ('democracy', 0.22263897955417633), ('prosperity', 0.21441560983657837), ('proved', 0.20404411852359772), ('survive', 0.20205307006835938), ('real', 0.19373276829719543), ('indonesia', 0.1932680755853653), ('territories', 0.19314034283161163)]
#
# Training climate_change_2003 model (Income 1)
# Documents: 4
# Vocab size: 1482
# Top associations for 'climate_change_2003':
# [('obligations', 0.25135600566864014), ('step', 0.2505010664463043), ('means', 0.24658817052841187), ('story', 0.23833997547626495), ('degradation', 0.23386865854263306), ('wound', 0.22643567621707916), ('concerning', 0.22591164708137512), ('reforms', 0.21886427700519562), ('ideals', 0.2181341052055359), ('kavan', 0.21607768535614014)]
#
# Training climate_change_2004 model (Income 1)
# Documents: 2
# Vocab size: 657
# Top associations for 'climate_change_2004':
# [('without', 0.2583778202533722), ('resolution', 0.2076142281293869), ('hunger', 0.20757991075515747), ('expansion', 0.20201954245567322), ('beneficiary', 0.19842950999736786), ('provides', 0.1781412661075592), ('privileges', 0.1762223243713379), ('reporting', 0.17552150785923004), ('personnel', 0.174115389585495), ('discussions', 0.17040285468101501)]
#
# Training climate_change_2005 model (Income 1)
# Documents: 5
# Vocab size: 1216
# Top associations for 'climate_change_2005':
# [('livelihood', 0.2270212322473526), ('measures', 0.2154897153377533), ('colleague', 0.21295735239982605), ('parliament', 0.20936301350593567), ('expenses', 0.2039915770292282), ('overseas', 0.2022646963596344), ('mobilizing', 0.19828303158283234), ('root', 0.1917053461074829), ('mdgs', 0.19162799417972565), ('reforms', 0.18785494565963745)]
#
# Training climate_change_2006 model (Income 1)
# Documents: 4
# Vocab size: 1247
# Top associations for 'climate_change_2006':
# [('fiscal', 0.29397204518318176), ('prevention', 0.24791380763053894), ('drawn', 0.23847191035747528), ('liberalization', 0.21861732006072998), ('assure', 0.21847572922706604), ('milestone', 0.20836849510669708), ('appointment', 0.20549599826335907), ('last', 0.20185662806034088), ('complex', 0.19732490181922913), ('newest', 0.19536015391349792)]
#
# Training climate_change_2007 model (Income 1)
# Documents: 39
# Vocab size: 5196
# Top associations for 'climate_change_2007':
# [('assembly', 0.9993125796318054), ('world', 0.9991714954376221), ('must', 0.9990755915641785), ('needs', 0.9990753531455994), ('country', 0.9990545511245728), ('international', 0.9990454912185669), ('united', 0.9990407228469849), ('also', 0.9990382790565491), ('countries', 0.9990236163139343), ('development', 0.9990216493606567)]
#
# Training climate_change_2008 model (Income 1)
# Documents: 31
# Vocab size: 3803
# Top associations for 'climate_change_2008':
# [('development', 0.9924501776695251), ('food', 0.9915101528167725), ('security', 0.9908866286277771), ('agriculture', 0.9905205368995667), ('africa', 0.9900695085525513), ('countries', 0.989332914352417), ('united_nation', 0.9892480373382568), ('people', 0.9887813329696655), ('general', 0.9887404441833496), ('situation', 0.9877109527587891)]
#
# Training climate_change_2009 model (Income 1)
# Documents: 36
# Vocab size: 5075
# Top associations for 'climate_change_2009':
# [('years', 0.999041736125946), ('areas', 0.9989794492721558), ('therefore', 0.9989530444145203), ('efforts', 0.9989411234855652), ('would', 0.9989357590675354), ('people', 0.998928427696228), ('united_nation', 0.9989245533943176), ('support', 0.9989137649536133), ('made', 0.9989131093025208), ('council', 0.9988834857940674)]
#
# Training climate_change_2010 model (Income 1)
# Documents: 25
# Vocab size: 4124
# Top associations for 'climate_change_2010':
# [('international', 0.9947574734687805), ('global', 0.9946016669273376), ('united_nation', 0.9944117665290833), ('union', 0.9941390752792358), ('security', 0.9941360950469971), ('states', 0.9941248893737793), ('order', 0.9941247701644897), ('development', 0.9940767884254456), ('support', 0.9940537214279175), ('peace', 0.9940139055252075)]
#
# Training climate_change_2011 model (Income 1)
# Documents: 23
# Vocab size: 3348
# Top associations for 'climate_change_2011':
# [('international', 0.8829013705253601), ('also', 0.8761390447616577), ('countries', 0.8760149478912354), ('africa', 0.8725195527076721), ('world', 0.8704008460044861), ('african', 0.865058422088623), ('peace', 0.8595325350761414), ('global', 0.8555118441581726), ('human', 0.8522020578384399), ('security', 0.8494096398353577)]
#
# Training climate_change_2012 model (Income 1)
# Documents: 14
# Vocab size: 2780
# Top associations for 'climate_change_2012':
# [('need', 0.38264793157577515), ('country', 0.37975767254829407), ('international', 0.3797515630722046), ('global', 0.37517914175987244), ('organized', 0.3683660328388214), ('development', 0.3637610673904419), ('people', 0.35436534881591797), ('united_nation', 0.33195552229881287), ('terrorist', 0.32992905378341675), ('destinations', 0.32943999767303467)]
#
# Training climate_change_2013 model (Income 1)
# Documents: 10
# Vocab size: 2399
# Top associations for 'climate_change_2013':
# [('republic', 0.3317483961582184), ('founding', 0.28067708015441895), ('women', 0.2753463685512543), ('centre', 0.26933765411376953), ('decade', 0.2496969848871231), ('expression', 0.24415504932403564), ('treated', 0.24390102922916412), ('societies', 0.2400895059108734), ('birthplace', 0.23444871604442596), ('millennium', 0.23340395092964172)]
#
# Training climate_change_2014 model (Income 1)
# Documents: 19
# Vocab size: 3187
# Top associations for 'climate_change_2014':
# [('peace', 0.4844929575920105), ('global', 0.48376762866973877), ('development', 0.4818485677242279), ('result', 0.48061951994895935), ('united_nation', 0.4759966731071472), ('must', 0.47525498270988464), ('construction', 0.47020936012268066), ('agenda', 0.467239648103714), ('mdgs', 0.46696653962135315), ('crisis', 0.4649059772491455)]
#
# Training climate_change_2015 model (Income 1)
# Documents: 20
# Vocab size: 3615
# Top associations for 'climate_change_2015':
# [('development', 0.804124116897583), ('also', 0.7850252985954285), ('united_nation', 0.7833542227745056), ('people', 0.7804998159408569), ('made', 0.7796372771263123), ('must', 0.7796218395233154), ('peace', 0.7790506482124329), ('action', 0.7788017392158508), ('including', 0.7785143256187439), ('african', 0.777717649936676)]
#
# Training climate_change_2016 model (Income 1)
# Documents: 27
# Vocab size: 4091
# Top associations for 'climate_change_2016':
# [('support', 0.9944618940353394), ('world', 0.9941248297691345), ('countries', 0.9941072463989258), ('united_nation', 0.9940041899681091), ('development', 0.9939186573028564), ('africa', 0.9936047196388245), ('global', 0.9935882687568665), ('security', 0.9935552477836609), ('community', 0.9934171438217163), ('international', 0.9932593107223511)]
#
# Training climate_change_2017 model (Income 1)
# Documents: 28
# Vocab size: 4263
# Top associations for 'climate_change_2017':
# [('people', 0.9955212473869324), ('peace', 0.9954160451889038), ('sustainable', 0.9954133629798889), ('political', 0.9954050779342651), ('country', 0.995324432849884), ('africa', 0.9952809810638428), ('african', 0.9952783584594727), ('development', 0.9951764345169067), ('government', 0.9951238036155701), ('economic', 0.9950987696647644)]
#
# Training climate_change_2018 model (Income 1)
# Documents: 20
# Vocab size: 4083
# Top associations for 'climate_change_2018':
# [('security', 0.9941397905349731), ('national', 0.9937655925750732), ('challenges', 0.9936445355415344), ('peace', 0.9933533668518066), ('international', 0.9933201670646667), ('development', 0.9932225346565247), ('people', 0.9930359721183777), ('republic', 0.9929338693618774), ('global', 0.9929320216178894), ('would', 0.9929130673408508)]
#
# Training climate_change_2019 model (Income 1)
# Documents: 24
# Vocab size: 4348
# Top associations for 'climate_change_2019':
# [('women', 0.9983065128326416), ('security', 0.9982672929763794), ('development', 0.9982543587684631), ('political', 0.9981369972229004), ('united_nation', 0.9981027245521545), ('government', 0.9979913234710693), ('peace', 0.9979596138000488), ('people', 0.9978092312812805), ('terrorism', 0.997782826423645), ('implementation', 0.9977738261222839)]
#
# Training climate_change_2020 model (Income 1)
# Documents: 18
# Vocab size: 2900
# Top associations for 'climate_change_2020':
# [('covid19', 0.7824985384941101), ('efforts', 0.7670329809188843), ('world', 0.7623293399810791), ('peace', 0.7404075264930725), ('africa', 0.7386593818664551), ('people', 0.7265135645866394), ('national', 0.724666178226471), ('agenda', 0.7222845554351807), ('rights', 0.6930708885192871), ('call', 0.6898663640022278)]
#
# Training climate_change_2021 model (Income 1)
# Documents: 21
# Vocab size: 4666
# Top associations for 'climate_change_2021':
# [('republic', 0.995312511920929), ('africa', 0.9952678084373474), ('development', 0.9952327013015747), ('countries', 0.9949920773506165), ('united_nation', 0.9949143528938293), ('country', 0.9947993159294128), ('world', 0.9945275187492371), ('support', 0.9943503141403198), ('council', 0.9943068027496338), ('people', 0.9942513108253479)]
#
# Training climate_change_2022 model (Income 1)
# Documents: 24
# Vocab size: 4501
# Top associations for 'climate_change_2022':
# [('development', 0.9960906505584717), ('international', 0.995345950126648), ('people', 0.9952291250228882), ('support', 0.9949523210525513), ('countries', 0.9949121475219727), ('must', 0.9948737025260925), ('order', 0.9945759773254395), ('world', 0.9944833517074585), ('united_nation', 0.9940381646156311), ('economic', 0.9939740896224976)]
#
# Training climate_change_2023 model (Income 1)
# Documents: 19
# Vocab size: 4028
# Top associations for 'climate_change_2023':
# [('countries', 0.9329065084457397), ('african', 0.9307401180267334), ('government', 0.9273907542228699), ('world', 0.9259675145149231), ('also', 0.924938976764679), ('state', 0.9240590929985046), ('international', 0.9240429401397705), ('states', 0.9239932298660278), ('solidarity', 0.9232572913169861), ('united_nation', 0.9221214652061462)]
#
# Training climate_change_2024 model (Income 1)
# Documents: 21
# Vocab size: 3960
# Top associations for 'climate_change_2024':
# [('security', 0.9272530674934387), ('development', 0.9224575161933899), ('countries', 0.922298789024353), ('conflicts', 0.9216592311859131), ('support', 0.9213045239448547), ('people', 0.9210942387580872), ('global', 0.9209449291229248), ('future', 0.920922040939331), ('must', 0.9188273549079895), ('peace', 0.9187543988227844)]
#
# ---------------------------------------- Income Level 2 ----------------------------------------
#
# Training climate_change_1991 model (Income 2)
# Documents: 6
# Vocab size: 1519
# Top associations for 'climate_change_1991':
# [('reminder', 0.3089452385902405), ('forum', 0.28017809987068176), ('encouraged', 0.2796515226364136), ('commitment', 0.2554416060447693), ('stockpile', 0.24521717429161072), ('achievement', 0.24080194532871246), ('states', 0.23078684508800507), ('causes', 0.23045630753040314), ('behalf', 0.22851388156414032), ('parts', 0.227816641330719)]
#
# Training climate_change_1992 model (Income 2)
# Documents: 7
# Vocab size: 1728
# Top associations for 'climate_change_1992':
# [('declaration', 0.27613767981529236), ('around', 0.27493155002593994), ('framework', 0.2457468956708908), ('cold', 0.22567568719387054), ('1990', 0.2255348116159439), ('chapter', 0.21221885085105896), ('significant', 0.21174246072769165), ('international', 0.20539817214012146), ('unique', 0.2027464061975479), ('reefs', 0.19864735007286072)]
#
# Training climate_change_1993 model (Income 2)
# Documents: 7
# Vocab size: 2056
# Top associations for 'climate_change_1993':
# [('denying', 0.2691112458705902), ('specks', 0.2444596290588379), ('fourth', 0.23519255220890045), ('facing', 0.23488818109035492), ('taken', 0.2345174103975296), ('catalogue', 0.22673918306827545), ('mantle', 0.22375205159187317), ('looming', 0.2213257998228073), ('postcoldwar', 0.21661223471164703), ('freedoms', 0.2128484696149826)]
#
# Training climate_change_1994 model (Income 2)
# Documents: 4
# Vocab size: 1673
# Top associations for 'climate_change_1994':
# [('possible', 0.28142037987709045), ('world', 0.2643492817878723), ('vocabulary', 0.25973233580589294), ('commemorate', 0.2581911087036133), ('intergovernmental', 0.2379949390888214), ('adjacent', 0.22552956640720367), ('concept', 0.2187623232603073), ('security', 0.21381013095378876), ('confident', 0.21013793349266052), ('historic', 0.20906966924667358)]
#
# Training climate_change_1995 model (Income 2)
# Documents: 7
# Vocab size: 2552
# Top associations for 'climate_change_1995':
# [('global', 0.4033552408218384), ('provides', 0.34994378685951233), ('action', 0.3126143217086792), ('forum', 0.31078246235847473), ('guinea', 0.30959001183509827), ('reunification', 0.30566418170928955), ('peoples', 0.3052958846092224), ('conducive', 0.30453264713287354), ('states', 0.30439645051956177), ('lose', 0.3010925352573395)]
#
# Training climate_change_1996 model (Income 2)
# Documents: 7
# Vocab size: 2386
# Top associations for 'climate_change_1996':
# [('development', 0.34970012307167053), ('council', 0.33301499485969543), ('honoured', 0.3196825683116913), ('unique', 0.3183119297027588), ('vital', 0.3164995610713959), ('could', 0.3118365406990051), ('expanding', 0.3085399866104126), ('deep', 0.3010016679763794), ('attention', 0.29902926087379456), ('nature', 0.29227545857429504)]
#
# Training climate_change_1997 model (Income 2)
# Documents: 11
# Vocab size: 2295
# Top associations for 'climate_change_1997':
# [('settings', 0.29743459820747375), ('live', 0.28560832142829895), ('turn', 0.2545114755630493), ('bottom', 0.25121739506721497), ('kwajalein', 0.25034597516059875), ('constraining', 0.24972917139530182), ('republic', 0.2440536767244339), ('cold', 0.24310189485549927), ('atmosphere', 0.2422308772802353), ('clear', 0.23885007202625275)]
#
# Training climate_change_1998 model (Income 2)
# Documents: 9
# Vocab size: 2474
# Top associations for 'climate_change_1998':
# [('like', 0.3456752300262451), ('appear', 0.34520313143730164), ('refer', 0.34017717838287354), ('kyoto_protocol', 0.3338565528392792), ('stronger', 0.3328709006309509), ('profound', 0.3283291161060333), ('government', 0.32014572620391846), ('community', 0.31922027468681335), ('delegation', 0.3187609612941742), ('stewardship', 0.3175314962863922)]
#
# Training climate_change_1999 model (Income 2)
# Documents: 5
# Vocab size: 1437
# Top associations for 'climate_change_1999':
# [('outcome', 0.26709598302841187), ('point', 0.25312796235084534), ('review', 0.24480663239955902), ('killer', 0.23452511429786682), ('failed', 0.2284659743309021), ('delegations', 0.22530369460582733), ('rules', 0.22097954154014587), ('modern', 0.2170339971780777), ('congratulate', 0.21131926774978638), ('domestic', 0.21103084087371826)]
#
# Training climate_change_2000 model (Income 2)
# Documents: 9
# Vocab size: 1600
# Top associations for 'climate_change_2000':
# [('positive', 0.3006320893764496), ('office', 0.27492082118988037), ('speeches', 0.24658071994781494), ('unaffected', 0.24309971928596497), ('independent', 0.2357938289642334), ('rights', 0.23544907569885254), ('nuclear', 0.2339814305305481), ('sometimes', 0.22863663733005524), ('congratulate', 0.22738786041736603), ('affected', 0.22182618081569672)]
#
# Training climate_change_2001 model (Income 2)
# Documents: 8
# Vocab size: 1880
# Top associations for 'climate_change_2001':
# [('holkeri', 0.31316375732421875), ('impossible', 0.3091374933719635), ('pressing', 0.30042824149131775), ('foreign', 0.2966429591178894), ('regardless', 0.27655428647994995), ('financial', 0.26628485321998596), ('addressed', 0.25742435455322266), ('terrorists', 0.25550323724746704), ('kyoto_protocol', 0.2554514706134796), ('mission', 0.254891037940979)]
#
# Training climate_change_2002 model (Income 2)
# Documents: 9
# Vocab size: 975
# Top associations for 'climate_change_2002':
# [('every', 0.2604447305202484), ('position', 0.24186792969703674), ('natural', 0.24122463166713715), ('halving', 0.23041197657585144), ('redoubling', 0.22651317715644836), ('ensure', 0.21409910917282104), ('relates', 0.21089006960391998), ('linked', 0.2053292691707611), ('levels', 0.19484983384609222), ('vulnerability', 0.19391843676567078)]
#
# Training climate_change_2003 model (Income 2)
# Documents: 4
# Vocab size: 1089
# Top associations for 'climate_change_2003':
# [('ongoing', 0.25456178188323975), ('successful', 0.22312599420547485), ('landmark', 0.2214922159910202), ('expanded', 0.2178286612033844), ('time', 0.20850546658039093), ('live', 0.20770759880542755), ('lengthening', 0.20113754272460938), ('mourn', 0.1976420283317566), ('policy', 0.19557766616344452), ('course', 0.19528578221797943)]
#
# Training climate_change_2004 model (Income 2)
# Documents: 6
# Vocab size: 1372
# Top associations for 'climate_change_2004':
# [('moratorium', 0.25630074739456177), ('allocation', 0.24527014791965485), ('including', 0.2416182905435562), ('steer', 0.24025027453899384), ('ones', 0.23711000382900238), ('feel', 0.23635543882846832), ('eradication', 0.22500279545783997), ('environmentally', 0.2247695028781891), ('strategic', 0.22134894132614136), ('longterm', 0.21909309923648834)]
#
# Training climate_change_2005 model (Income 2)
# Documents: 6
# Vocab size: 1534
# Top associations for 'climate_change_2005':
# [('general', 0.30495142936706543), ('commodity', 0.2561837136745453), ('pacific', 0.24561059474945068), ('share', 0.23831486701965332), ('charted', 0.213717982172966), ('guided', 0.2112107127904892), ('december', 0.20926572382450104), ('presidents', 0.2070876508951187), ('critical', 0.20691394805908203), ('firm', 0.20532971620559692)]
#
# Training climate_change_2006 model (Income 2)
# Documents: 6
# Vocab size: 1510
# Top associations for 'climate_change_2006':
# [('frameworks', 0.3052532374858856), ('holy', 0.24909183382987976), ('always', 0.24902789294719696), ('marine', 0.2308979481458664), ('geographical', 0.21826796233654022), ('survival', 0.2113533914089203), ('expanded', 0.21091750264167786), ('operational', 0.2001049518585205), ('balancing', 0.19768844544887543), ('majority', 0.1973063349723816)]
#
# Training climate_change_2007 model (Income 2)
# Documents: 41
# Vocab size: 5246
# Top associations for 'climate_change_2007':
# [('also', 0.9990971684455872), ('states', 0.9990954399108887), ('international', 0.9990429282188416), ('general', 0.9990087151527405), ('country', 0.9989312887191772), ('terrorism', 0.998893141746521), ('efforts', 0.998891294002533), ('years', 0.9988880753517151), ('global', 0.9988827705383301), ('assembly', 0.9988810420036316)]
#
# Training climate_change_2008 model (Income 2)
# Documents: 40
# Vocab size: 5664
# Top associations for 'climate_change_2008':
# [('must', 0.9991706013679504), ('time', 0.9991458058357239), ('also', 0.9990721344947815), ('states', 0.9990663528442383), ('food', 0.9990595579147339), ('today', 0.9990448355674744), ('country', 0.9990410208702087), ('support', 0.9990367889404297), ('international', 0.9990308284759521), ('council', 0.9990294575691223)]
#
# Training climate_change_2009 model (Income 2)
# Documents: 46
# Vocab size: 6084
# Top associations for 'climate_change_2009':
# [('also', 0.9990459680557251), ('national', 0.9990352988243103), ('maldives', 0.9989703893661499), ('coastal', 0.9989227056503296), ('principle', 0.9989209771156311), ('consider', 0.9989098310470581), ('progress', 0.9989094734191895), ('vulnerable', 0.9989036917686462), ('economies', 0.9988872408866882), ('difficult', 0.9988864660263062)]
#
# Training climate_change_2010 model (Income 2)
# Documents: 42
# Vocab size: 5488
# Top associations for 'climate_change_2010':
# [('also', 0.9991188645362854), ('international', 0.9990653395652771), ('year', 0.9990412592887878), ('global', 0.9990374445915222), ('economic', 0.9990056157112122), ('assembly', 0.998991847038269), ('country', 0.998978853225708), ('governments', 0.9989699125289917), ('cent', 0.9989628791809082), ('implementation', 0.9989585280418396)]
#
# Training climate_change_2011 model (Income 2)
# Documents: 34
# Vocab size: 4780
# Top associations for 'climate_change_2011':
# [('development', 0.9980791807174683), ('must', 0.998073160648346), ('united_nation', 0.9978348016738892), ('islands', 0.9978191256523132), ('economic', 0.9977731108665466), ('pacific', 0.9976288676261902), ('world', 0.9975606203079224), ('peace', 0.9975186586380005), ('international', 0.9975154399871826), ('also', 0.9974929094314575)]
#
# Training climate_change_2012 model (Income 2)
# Documents: 25
# Vocab size: 3977
# Top associations for 'climate_change_2012':
# [('peace', 0.9798862338066101), ('united_nation', 0.9788952469825745), ('government', 0.9782305955886841), ('community', 0.9781932830810547), ('people', 0.9781737327575684), ('also', 0.9779961705207825), ('general', 0.977273166179657), ('security', 0.9767236113548279), ('development', 0.9764924049377441), ('continue', 0.9763492345809937)]
#
# Training climate_change_2013 model (Income 2)
# Documents: 25
# Vocab size: 3968
# Top associations for 'climate_change_2013':
# [('states', 0.9896690249443054), ('development', 0.9893522262573242), ('security', 0.9877662062644958), ('international', 0.9877512454986572), ('economic', 0.9862933158874512), ('agenda', 0.9857666492462158), ('world', 0.9853940010070801), ('national', 0.9852917194366455), ('pakistan', 0.9852641224861145), ('islands', 0.9849829077720642)]
#
# Training climate_change_2014 model (Income 2)
# Documents: 34
# Vocab size: 5201
# Top associations for 'climate_change_2014':
# [('terrorism', 0.9991463422775269), ('community', 0.9990846514701843), ('united_nation', 0.9990615844726562), ('development', 0.9990530014038086), ('process', 0.9990324974060059), ('international', 0.9990173578262329), ('progress', 0.9989515542984009), ('security', 0.9989398717880249), ('part', 0.998919665813446), ('east', 0.9989187121391296)]
#
# Training climate_change_2015 model (Income 2)
# Documents: 39
# Vocab size: 5679
# Top associations for 'climate_change_2015':
# [('necessary', 0.9990988373756409), ('government', 0.9990909099578857), ('people', 0.9990662932395935), ('islands', 0.9989979863166809), ('council', 0.9989910125732422), ('system', 0.9989856481552124), ('rise', 0.9989845156669617), ('must', 0.9989829063415527), ('democratic', 0.998963475227356), ('regional', 0.9989448189735413)]
#
# Training climate_change_2016 model (Income 2)
# Documents: 37
# Vocab size: 6163
# Top associations for 'climate_change_2016':
# [('part', 0.9988973736763), ('past', 0.9988824129104614), ('including', 0.9988779425621033), ('construction', 0.9988763928413391), ('towards', 0.9988675713539124), ('economic', 0.9988443851470947), ('cent', 0.9988436698913574), ('regions', 0.9988402128219604), ('land', 0.9988391995429993), ('years', 0.9988389015197754)]
#
# Training climate_change_2017 model (Income 2)
# Documents: 40
# Vocab size: 5788
# Top associations for 'climate_change_2017':
# [('united_nation', 0.9992486238479614), ('security', 0.9992403388023376), ('country', 0.9992109537124634), ('countries', 0.9991627335548401), ('global', 0.9991549849510193), ('continue', 0.9991440176963806), ('would', 0.9991422295570374), ('terrorism', 0.9991309642791748), ('government', 0.9991201162338257), ('myanmar', 0.9991157054901123)]
#
# Training climate_change_2018 model (Income 2)
# Documents: 32
# Vocab size: 5536
# Top associations for 'climate_change_2018':
# [('cent', 0.9990308880805969), ('united_nation', 0.9990081787109375), ('peace', 0.9989875555038452), ('many', 0.9989814162254333), ('also', 0.9989781379699707), ('development', 0.9989549517631531), ('economic', 0.9989115595817566), ('national', 0.9989100098609924), ('terrorism', 0.9988954067230225), ('fight', 0.9988651275634766)]
#
# Training climate_change_2019 model (Income 2)
# Documents: 45
# Vocab size: 6866
# Top associations for 'climate_change_2019':
# [('western', 0.9989944696426392), ('violent', 0.9989708065986633), ('rule', 0.9989480376243591), ('longer', 0.9989472031593323), ('cultural', 0.9989396333694458), ('action', 0.9989299774169922), ('sdgs', 0.9989281892776489), ('could', 0.9989219903945923), ('democratic', 0.998920738697052), ('hatred', 0.9989038109779358)]
#
# Training climate_change_2020 model (Income 2)
# Documents: 33
# Vocab size: 5472
# Top associations for 'climate_change_2020':
# [('global', 0.9990222454071045), ('health', 0.9989503622055054), ('development', 0.9989439249038696), ('united_nation', 0.9989305734634399), ('country', 0.9989159107208252), ('international', 0.9989091753959656), ('peace', 0.9988945722579956), ('well', 0.9988293647766113), ('pandemic', 0.9987801909446716), ('world', 0.9987137913703918)]
#
# Training climate_change_2021 model (Income 2)
# Documents: 47
# Vocab size: 7130
# Top associations for 'climate_change_2021':
# [('conditions', 0.9986021518707275), ('thing', 0.9985944032669067), ('successive', 0.998576819896698), ('milestone', 0.9985740780830383), ('committees', 0.9985647797584534), ('stop', 0.9985471367835999), ('sympathy', 0.9985392093658447), ('force', 0.9985311627388), ('countrys', 0.9985243082046509), ('another', 0.9985173940658569)]
#
# Training climate_change_2022 model (Income 2)
# Documents: 45
# Vocab size: 6833
# Top associations for 'climate_change_2022':
# [('nuclear', 0.9988827109336853), ('international', 0.9988279342651367), ('great', 0.9988247752189636), ('peaceful', 0.9988149404525757), ('others', 0.998798668384552), ('part', 0.9987955093383789), ('levels', 0.9987908601760864), ('rise', 0.9987748861312866), ('africa', 0.9987713694572449), ('fate', 0.9987637996673584)]
#
# Training climate_change_2023 model (Income 2)
# Documents: 44
# Vocab size: 6412
# Top associations for 'climate_change_2023':
# [('rights', 0.998734176158905), ('million', 0.9987308979034424), ('parliament', 0.998720109462738), ('representing', 0.9987143278121948), ('settlements', 0.9987139105796814), ('military', 0.9987039566040039), ('areas', 0.9986940026283264), ('implementation', 0.998688280582428), ('even', 0.9986867904663086), ('legal', 0.9986865520477295)]
#
# Training climate_change_2024 model (Income 2)
# Documents: 40
# Vocab size: 6186
# Top associations for 'climate_change_2024':
# [('region', 0.9989067316055298), ('council', 0.9988669157028198), ('children', 0.9988577365875244), ('shared', 0.998814582824707), ('needs', 0.9987955689430237), ('terms', 0.9987950921058655), ('sectors', 0.9987831711769104), ('many', 0.998779833316803), ('order', 0.9987716674804688), ('continues', 0.9987689256668091)]
#
# ---------------------------------------- Income Level 3 ----------------------------------------
#
# Training climate_change_1990 model (Income 3)
# Documents: 2
# Vocab size: 102
# Top associations for 'climate_change_1990':
# [('expectations', 0.19871360063552856), ('international', 0.18278682231903076), ('confront', 0.1668207198381424), ('admission', 0.16225378215312958), ('envisaging', 0.15280678868293762), ('become', 0.1373790204524994), ('take', 0.1318134367465973), ('convention', 0.10865660011768341), ('many', 0.09360263496637344), ('high', 0.09131410717964172)]
#
# Training climate_change_1991 model (Income 3)
# Documents: 3
# Vocab size: 1597
# Top associations for 'climate_change_1991':
# [('pluralism', 0.26454561948776245), ('balance', 0.25180965662002563), ('disregard', 0.24061176180839539), ('liberated', 0.23702576756477356), ('paris', 0.23163525760173798), ('decadesold', 0.22730077803134918), ('poor', 0.2269793450832367), ('universality', 0.22633610665798187), ('world', 0.22166025638580322), ('minds', 0.21512258052825928)]
#
# Training climate_change_1992 model (Income 3)
# Documents: 5
# Vocab size: 812
# Top associations for 'climate_change_1992':
# [('good', 0.2605287432670593), ('fields', 0.2409561425447464), ('holds', 0.22748129069805145), ('present', 0.2248329520225525), ('constant', 0.22349385917186737), ('generals', 0.20893484354019165), ('change', 0.20492850244045258), ('overcome', 0.19916163384914398), ('fundamental', 0.19782015681266785), ('nevis', 0.1942402869462967)]
#
# Training climate_change_1993 model (Income 3)
# Documents: 4
# Vocab size: 896
# Top associations for 'climate_change_1993':
# [('make', 0.28427526354789734), ('disputes', 0.2482302337884903), ('moment', 0.24320001900196075), ('many', 0.23210777342319489), ('priority', 0.22657410800457), ('part', 0.22089913487434387), ('election', 0.21471241116523743), ('whether', 0.19526700675487518), ('independence', 0.1894407421350479), ('fundamentally', 0.18835115432739258)]
#
# Training climate_change_1994 model (Income 3)
# Documents: 1
# Vocab size: 1034
# Top associations for 'climate_change_1994':
# [('efforts', 0.27908018231391907), ('desired', 0.24766218662261963), ('final', 0.22884169220924377), ('response', 0.22855763137340546), ('possibilities', 0.21402548253536224), ('texts', 0.20840336382389069), ('played', 0.20247803628444672), ('actors', 0.19872266054153442), ('restructuring', 0.19765658676624298), ('arising', 0.19749104976654053)]
#
# Training climate_change_1995 model (Income 3)
# Documents: 3
# Vocab size: 1503
# Top associations for 'climate_change_1995':
# [('manmade', 0.27551618218421936), ('broken', 0.24662303924560547), ('evidence', 0.24124296009540558), ('given', 0.23312275111675262), ('winds', 0.22723136842250824), ('surf', 0.21881955862045288), ('1976', 0.2166375368833542), ('atlantic', 0.21047529578208923), ('threatened', 0.20904582738876343), ('excellency', 0.2085546851158142)]
#
# Training climate_change_1996 model (Income 3)
# Documents: 1
# Vocab size: 36
# Top associations for 'climate_change_1996':
# [('planet', 0.13956297934055328), ('close', 0.11715947836637497), ('common', 0.10802662372589111), ('must', 0.10450369119644165), ('efforts', 0.10250561684370041), ('chernobyl', 0.09560203552246094), ('uphold', 0.08845947682857513), ('importance', 0.07002916187047958), ('preserving', 0.06446202844381332), ('duty', 0.06260760128498077)]
#
# Training climate_change_1997 model (Income 3)
# Documents: 6
# Vocab size: 1009
# Top associations for 'climate_change_1997':
# [('poorer', 0.2798750400543213), ('drawn', 0.22426113486289978), ('different', 0.2116071730852127), ('join', 0.20709499716758728), ('unless', 0.20198728144168854), ('actively', 0.197581484913826), ('exporters', 0.1943049281835556), ('imperfect', 0.19165560603141785), ('treaty', 0.19066786766052246), ('relationship', 0.18636201322078705)]
#
# Training climate_change_1998 model (Income 3)
# Documents: 6
# Vocab size: 183
# Top associations for 'climate_change_1998':
# [('aware', 0.2205878049135208), ('longterm', 0.2058769017457962), ('answers', 0.16897700726985931), ('economic', 0.14632739126682281), ('sovereignty', 0.14543943107128143), ('combating', 0.14293625950813293), ('held', 0.139369398355484), ('state', 0.13883279263973236), ('global_warming', 0.13836976885795593), ('institutions', 0.1336759328842163)]
#
# Training climate_change_1999 model (Income 3)
# Documents: 3
# Vocab size: 562
# Top associations for 'climate_change_1999':
# [('fulfilling', 0.21989664435386658), ('came', 0.20561738312244415), ('problems', 0.2000444233417511), ('tables', 0.1991538554430008), ('1400', 0.19859713315963745), ('bleaching', 0.18820443749427795), ('metre', 0.18667562305927277), ('rain', 0.16830974817276), ('restrictions', 0.16615743935108185), ('died', 0.16406488418579102)]
#
# Training climate_change_2000 model (Income 3)
# Documents: 3
# Vocab size: 474
# Top associations for 'climate_change_2000':
# [('water', 0.25807759165763855), ('member', 0.24599269032478333), ('including', 0.23673206567764282), ('play', 0.22287125885486603), ('month', 0.21090562641620636), ('island', 0.20529983937740326), ('diagnostics', 0.20090356469154358), ('global', 0.19990825653076172), ('earth', 0.19053612649440765), ('responsibilities', 0.18953703343868256)]
#
# Training climate_change_2001 model (Income 3)
# Documents: 8
# Vocab size: 1279
# Top associations for 'climate_change_2001':
# [('thursday', 0.23332178592681885), ('bundestag', 0.22305430471897125), ('addressing', 0.22034086287021637), ('emergency', 0.2156970202922821), ('firmly', 0.20549148321151733), ('united', 0.20059941709041595), ('change', 0.1985531449317932), ('hard', 0.19768992066383362), ('destiny', 0.19366075098514557), ('laws', 0.1880941092967987)]
#
# Training climate_change_2002 model (Income 3)
# Documents: 3
# Vocab size: 1041
# Top associations for 'climate_change_2002':
# [('priorities', 0.2558099925518036), ('recognize', 0.2551916539669037), ('campaign', 0.24492603540420532), ('smaller', 0.22830171883106232), ('satisfaction', 0.22802619636058807), ('made', 0.2255382239818573), ('earth', 0.2133394330739975), ('difficult', 0.210488960146904), ('background', 0.20859120786190033), ('laws', 0.20690764486789703)]
#
# Training climate_change_2003 model (Income 3)
# Documents: 8
# Vocab size: 1676
# Top associations for 'climate_change_2003':
# [('determinants', 0.2523994743824005), ('much', 0.2500830590724945), ('paid', 0.23535744845867157), ('gives', 0.23212797939777374), ('long', 0.23083211481571198), ('guarantees', 0.22974012792110443), ('another', 0.22802434861660004), ('terms', 0.21423739194869995), ('periods', 0.21076029539108276), ('vicissitudes', 0.2070605754852295)]
#
# Training climate_change_2004 model (Income 3)
# Documents: 7
# Vocab size: 1337
# Top associations for 'climate_change_2004':
# [('sovereign', 0.24291975796222687), ('rest', 0.24071134626865387), ('peace', 0.23029093444347382), ('attenuate', 0.22603967785835266), ('however', 0.216499462723732), ('epidemics', 0.21546761691570282), ('forced', 0.2141161561012268), ('states', 0.2127561867237091), ('track', 0.20823609828948975), ('security', 0.20340140163898468)]
#
# Training climate_change_2005 model (Income 3)
# Documents: 9
# Vocab size: 1373
# Top associations for 'climate_change_2005':
# [('additional', 0.299858421087265), ('relief', 0.26118534803390503), ('must', 0.2562018036842346), ('macroeconomic', 0.2473560869693756), ('effective', 0.24334031343460083), ('convey', 0.2356218546628952), ('various', 0.22846032679080963), ('read', 0.21912671625614166), ('implement', 0.21722620725631714), ('countries', 0.21550390124320984)]
#
# Training climate_change_2006 model (Income 3)
# Documents: 8
# Vocab size: 1552
# Top associations for 'climate_change_2006':
# [('stock', 0.3017773926258087), ('guidance', 0.27301517128944397), ('trade', 0.25107765197753906), ('political', 0.24854901432991028), ('causes', 0.23478427529335022), ('fatigue', 0.23207102715969086), ('independent', 0.22969649732112885), ('impoverishing', 0.2250194251537323), ('appreciate', 0.21874657273292542), ('dangerous', 0.21791425347328186)]
#
# Training climate_change_2007 model (Income 3)
# Documents: 35
# Vocab size: 5474
# Top associations for 'climate_change_2007':
# [('development', 0.9991840720176697), ('africa', 0.9991505742073059), ('country', 0.9990625977516174), ('united_nation', 0.999058187007904), ('world', 0.9990118741989136), ('efforts', 0.9989983439445496), ('security', 0.9989925026893616), ('states', 0.9989790916442871), ('countries', 0.9989454746246338), ('economy', 0.9989346265792847)]
#
# Training climate_change_2008 model (Income 3)
# Documents: 35
# Vocab size: 5008
# Top associations for 'climate_change_2008':
# [('small', 0.9983034133911133), ('human', 0.9982954859733582), ('political', 0.9982353448867798), ('food', 0.998230516910553), ('developing', 0.9981628656387329), ('countries', 0.9981589913368225), ('security', 0.9981346130371094), ('development', 0.9981298446655273), ('international', 0.9980993866920471), ('economic', 0.9980898499488831)]
#
# Training climate_change_2009 model (Income 3)
# Documents: 39
# Vocab size: 6674
# Top associations for 'climate_change_2009':
# [('states', 0.9991227984428406), ('cent', 0.9990593194961548), ('threat', 0.9990440607070923), ('trade', 0.9990232586860657), ('regional', 0.9989986419677734), ('taking', 0.9989949464797974), ('place', 0.9989921450614929), ('available', 0.9989708065986633), ('well', 0.99895840883255), ('conflicts', 0.9989383816719055)]
#
# Training climate_change_2010 model (Income 3)
# Documents: 42
# Vocab size: 6243
# Top associations for 'climate_change_2010':
# [('issues', 0.9989776611328125), ('peoples', 0.9989410638809204), ('come', 0.9988783001899719), ('continue', 0.9988694190979004), ('fact', 0.9988598227500916), ('future', 0.9988530278205872), ('improved', 0.9988467693328857), ('time', 0.9988382458686829), ('five', 0.9988346695899963), ('social', 0.9988275170326233)]
#
# Training climate_change_2011 model (Income 3)
# Documents: 38
# Vocab size: 5240
# Top associations for 'climate_change_2011':
# [('must', 0.9992323517799377), ('international', 0.9991486668586731), ('financial', 0.9991470575332642), ('countries', 0.9990622401237488), ('united_nation', 0.999031126499176), ('power', 0.9990246891975403), ('caused', 0.9990177750587463), ('community', 0.9990074038505554), ('efforts', 0.998965322971344), ('trade', 0.9989621043205261)]
#
# Training climate_change_2012 model (Income 3)
# Documents: 34
# Vocab size: 5178
# Top associations for 'climate_change_2012':
# [('international', 0.9985936880111694), ('united_nation', 0.998578667640686), ('world', 0.9984719157218933), ('small', 0.9984082579612732), ('states', 0.9983111023902893), ('people', 0.9982994198799133), ('sustainable', 0.9982837438583374), ('global', 0.9982589483261108), ('community', 0.998208224773407), ('countries', 0.998148500919342)]
#
# Training climate_change_2013 model (Income 3)
# Documents: 34
# Vocab size: 4751
# Top associations for 'climate_change_2013':
# [('development', 0.998369574546814), ('world', 0.9983360767364502), ('must', 0.9983162879943848), ('international', 0.9983031153678894), ('countries', 0.9982642531394958), ('social', 0.9982131123542786), ('agenda', 0.9982043504714966), ('states', 0.99813312292099), ('poverty', 0.998127281665802), ('global', 0.9980834126472473)]
#
# Training climate_change_2014 model (Income 3)
# Documents: 34
# Vocab size: 5584
# Top associations for 'climate_change_2014':
# [('state', 0.999181866645813), ('people', 0.9991806745529175), ('states', 0.9991793036460876), ('development', 0.9991753101348877), ('economic', 0.9991406202316284), ('international', 0.9991114735603333), ('global', 0.999109148979187), ('levels', 0.9990878105163574), ('community', 0.9990736246109009), ('also', 0.9990573525428772)]
#
# Training climate_change_2015 model (Income 3)
# Documents: 42
# Vocab size: 6557
# Top associations for 'climate_change_2015':
# [('island', 0.9989913105964661), ('government', 0.9989565014839172), ('social', 0.9989379644393921), ('work', 0.9989171624183655), ('nothing', 0.9989073872566223), ('life', 0.9988973140716553), ('pledge', 0.9988924264907837), ('global', 0.9988856315612793), ('responsibility', 0.9988794326782227), ('nuclear', 0.9988709092140198)]
#
# Training climate_change_2016 model (Income 3)
# Documents: 43
# Vocab size: 6326
# Top associations for 'climate_change_2016':
# [('regional', 0.9989707469940186), ('cuba', 0.9989237189292908), ('region', 0.9989191889762878), ('continue', 0.9989163279533386), ('must', 0.9988996982574463), ('cooperation', 0.9988985061645508), ('international', 0.998870849609375), ('need', 0.9988650679588318), ('rights', 0.9988623261451721), ('economies', 0.9988604784011841)]
#
# Training climate_change_2017 model (Income 3)
# Documents: 40
# Vocab size: 6625
# Top associations for 'climate_change_2017':
# [('policy', 0.9989826679229736), ('world', 0.9989640712738037), ('sisters', 0.9989445805549622), ('system', 0.998919665813446), ('principles', 0.9989169836044312), ('commercial', 0.9989116787910461), ('meeting', 0.9989091157913208), ('effects', 0.9989057779312134), ('victims', 0.9988892674446106), ('region', 0.9988749027252197)]
#
# Training climate_change_2018 model (Income 3)
# Documents: 40
# Vocab size: 5622
# Top associations for 'climate_change_2018':
# [('international', 0.9992596507072449), ('government', 0.9992197155952454), ('year', 0.9991515278816223), ('people', 0.9991403818130493), ('united_nation', 0.9991395473480225), ('region', 0.9991371035575867), ('must', 0.9991156458854675), ('work', 0.9990653991699219), ('agenda', 0.9990552663803101), ('first', 0.9990522265434265)]
#
# Training climate_change_2019 model (Income 3)
# Documents: 45
# Vocab size: 6866
# Top associations for 'climate_change_2019':
# [('continue', 0.9992272853851318), ('islands', 0.999224066734314), ('state', 0.9992236495018005), ('system', 0.999200165271759), ('people', 0.9991898536682129), ('years', 0.9991669058799744), ('come', 0.9991572499275208), ('states', 0.999153196811676), ('high', 0.999149739742279), ('various', 0.9991452097892761)]
#
# Training climate_change_2020 model (Income 3)
# Documents: 40
# Vocab size: 4966
# Top associations for 'climate_change_2020':
# [('pandemic', 0.9966772794723511), ('people', 0.9963926672935486), ('human', 0.9963678121566772), ('economic', 0.9962817430496216), ('united_nation', 0.9962694048881531), ('peace', 0.9962550401687622), ('support', 0.9962421655654907), ('global', 0.9960711598396301), ('covid19', 0.9960284233093262), ('development', 0.9960123896598816)]
#
# Training climate_change_2021 model (Income 3)
# Documents: 43
# Vocab size: 6695
# Top associations for 'climate_change_2021':
# [('better', 0.9990066289901733), ('community', 0.998954176902771), ('infrastructure', 0.9989421963691711), ('system', 0.9989385604858398), ('region', 0.9989145994186401), ('crimes', 0.998911440372467), ('legitimate', 0.9989014863967896), ('lives', 0.998892605304718), ('made', 0.9988797903060913), ('economic', 0.9988710880279541)]
#
# Training climate_change_2022 model (Income 3)
# Documents: 41
# Vocab size: 6478
# Top associations for 'climate_change_2022':
# [('today', 0.9989715218544006), ('taiwan', 0.9989703893661499), ('growth', 0.9989697337150574), ('life', 0.9989546537399292), ('especially', 0.9989535212516785), ('legal', 0.9989423155784607), ('people', 0.9989314079284668), ('change', 0.9989312291145325), ('states', 0.998929500579834), ('common', 0.9989250898361206)]
#
# Training climate_change_2023 model (Income 3)
# Documents: 43
# Vocab size: 6744
# Top associations for 'climate_change_2023':
# [('country', 0.9990109801292419), ('times', 0.9989845752716064), ('process', 0.9989517331123352), ('charter', 0.9989496469497681), ('among', 0.9989445209503174), ('next', 0.9989327192306519), ('sovereign', 0.9989060759544373), ('across', 0.9989019632339478), ('health', 0.9989001750946045), ('haiti', 0.9988958239555359)]
#
# Training climate_change_2024 model (Income 3)
# Documents: 38
# Vocab size: 6113
# Top associations for 'climate_change_2024':
# [('security', 0.9986788630485535), ('also', 0.998624324798584), ('world', 0.9985682964324951), ('united_nation', 0.9984834790229797), ('human', 0.9984772801399231), ('international', 0.9984764456748962), ('country', 0.9984697699546814), ('national', 0.9984361529350281), ('agenda', 0.9984192252159119), ('states', 0.9984145164489746)]
#
# ---------------------------------------- Income Level 4 ----------------------------------------
#
# Training climate_change_1990 model (Income 4)
# Documents: 4
# Vocab size: 1298
# Top associations for 'climate_change_1990':
# [('valuable', 0.2694438397884369), ('yesterday', 0.2422468364238739), ('demonstrating', 0.2415170520544052), ('momentum', 0.2408820539712906), ('abilities', 0.22203129529953003), ('north', 0.21647551655769348), ('present', 0.2066994160413742), ('charter', 0.20317478477954865), ('knowledge', 0.20313908159732819), ('steps', 0.19931763410568237)]
#
# Training climate_change_1991 model (Income 4)
# Documents: 9
# Vocab size: 1443
# Top associations for 'climate_change_1991':
# [('immeasurably', 0.27516502141952515), ('interdependent', 0.2615818679332733), ('meetings', 0.25164252519607544), ('signal', 0.23058034479618073), ('dispatch', 0.20802071690559387), ('social', 0.20783710479736328), ('numerous', 0.2048521339893341), ('element', 0.19885209202766418), ('continues', 0.19688208401203156), ('founded', 0.19678115844726562)]
#
# Training climate_change_1992 model (Income 4)
# Documents: 4
# Vocab size: 150
# Top associations for 'climate_change_1992':
# [('livelihoods', 0.19603590667247772), ('essential', 0.1665661334991455), ('minister', 0.1539495438337326), ('signatories', 0.1529860943555832), ('nationbuilders', 0.14453789591789246), ('effort', 0.14230699837207794), ('good', 0.14043189585208893), ('pace', 0.13663440942764282), ('expectations', 0.12459975481033325), ('common', 0.12407936900854111)]
#
# Training climate_change_1993 model (Income 4)
# Documents: 2
# Vocab size: 68
# Top associations for 'climate_change_1993':
# [('committed', 0.14536921679973602), ('secretariat', 0.13955113291740417), ('availability', 0.12733741104602814), ('affairs', 0.11426940560340881), ('international', 0.10127198696136475), ('creation', 0.09943624585866928), ('funding', 0.0967169851064682), ('allowed', 0.09006425738334656), ('safeguard', 0.08114007860422134), ('features', 0.0786670371890068)]
#
# Training climate_change_1995 model (Income 4)
# Documents: 3
# Vocab size: 628
# Top associations for 'climate_change_1995':
# [('together', 0.22986984252929688), ('november', 0.22477327287197113), ('beijing', 0.22269116342067719), ('population', 0.2133045196533203), ('infrastructure', 0.20182804763317108), ('israelis', 0.195193350315094), ('conference', 0.1917950063943863), ('instead', 0.18124423921108246), ('icelandic', 0.17535792291164398), ('scale', 0.17337483167648315)]
#
# Training climate_change_1996 model (Income 4)
# Documents: 7
# Vocab size: 198
# Top associations for 'climate_change_1996':
# [('practical', 0.22050760686397552), ('would', 0.20592407882213593), ('help', 0.1689450740814209), ('north', 0.14638301730155945), ('social', 0.14536921679973602), ('effort', 0.1428918093442917), ('conference', 0.13956846296787262), ('thank', 0.13885653018951416), ('emergence', 0.1384427696466446), ('biodiversity', 0.136752650141716)]
#
# Training climate_change_1997 model (Income 4)
# Documents: 8
# Vocab size: 639
# Top associations for 'climate_change_1997':
# [('protect', 0.29843008518218994), ('tons', 0.23177829384803772), ('country', 0.21881103515625), ('life', 0.21880246698856354), ('ability', 0.21765385568141937), ('bigger', 0.21053902804851532), ('imperative', 0.19364263117313385), ('name', 0.18705707788467407), ('national', 0.1831471025943756), ('subcontract', 0.18120023608207703)]
#
# Training climate_change_1998 model (Income 4)
# Documents: 7
# Vocab size: 805
# Top associations for 'climate_change_1998':
# [('decreasing', 0.27625465393066406), ('asia', 0.24607330560684204), ('emissions', 0.2395956665277481), ('struggle', 0.22987864911556244), ('responses', 0.2283804714679718), ('globalization', 0.2282506227493286), ('cooperate', 0.2267817258834839), ('translate', 0.22156739234924316), ('barbados', 0.22068580985069275), ('recent', 0.20352044701576233)]
#
# Training climate_change_1999 model (Income 4)
# Documents: 7
# Vocab size: 204
# Top associations for 'climate_change_1999':
# [('agenda', 0.22049567103385925), ('greenhouse', 0.20594044029712677), ('kyoto', 0.16893550753593445), ('peoples', 0.14635686576366425), ('markets', 0.14531974494457245), ('faces', 0.14298869669437408), ('great', 0.13952209055423737), ('aires', 0.1388818770647049), ('humaninduced', 0.13840016722679138), ('vitally', 0.13678015768527985)]
#
# Training climate_change_2000 model (Income 4)
# Documents: 5
# Vocab size: 630
# Top associations for 'climate_change_2000':
# [('impoverished', 0.260024756193161), ('mid2002', 0.24309620261192322), ('centre', 0.22371986508369446), ('ratify', 0.22331252694129944), ('seattle', 0.20499302446842194), ('theatres', 0.2033357173204422), ('alert', 0.19738711416721344), ('swift', 0.19511553645133972), ('shared', 0.19486409425735474), ('tackling', 0.17389844357967377)]
#
# Training climate_change_2001 model (Income 4)
# Documents: 5
# Vocab size: 164
# Top associations for 'climate_change_2001':
# [('reassessment', 0.22583091259002686), ('world', 0.18278683722019196), ('postponed', 0.15415571630001068), ('next', 0.1525111198425293), ('overall', 0.14895407855510712), ('already', 0.14502346515655518), ('provide', 0.13736429810523987), ('member', 0.13631077110767365), ('projected', 0.13458020985126495), ('appropriate', 0.133772075176239)]
#
# Training climate_change_2002 model (Income 4)
# Documents: 2
# Vocab size: 71
# Top associations for 'climate_change_2002':
# [('including', 0.18279105424880981), ('call', 0.1363266259431839), ('water', 0.13457264006137848), ('small', 0.13382205367088318), ('bahamas', 0.1302417367696762), ('taken', 0.12013321369886398), ('also', 0.1112254410982132), ('development', 0.11117105185985565), ('high', 0.10891636461019516), ('implementation', 0.10337581485509872)]
#
# Training climate_change_2003 model (Income 4)
# Documents: 2
# Vocab size: 57
# Top associations for 'climate_change_2003':
# [('states', 0.17005769908428192), ('affect', 0.1604202389717102), ('specifically', 0.12622545659542084), ('detailed', 0.11601787805557251), ('united', 0.09617381542921066), ('eighth', 0.09025479853153229), ('commitment', 0.08587704598903656), ('must', 0.0840606689453125), ('gathered', 0.07570962607860565), ('negotiations', 0.054575320333242416)]
#
# Training climate_change_2004 model (Income 4)
# Documents: 9
# Vocab size: 1519
# Top associations for 'climate_change_2004':
# [('members', 0.28961363434791565), ('construction', 0.2642052173614502), ('united', 0.24328644573688507), ('determine', 0.2397202104330063), ('aside', 0.2358626127243042), ('secretary', 0.2334045022726059), ('recommendations', 0.22628886997699738), ('hand', 0.22312697768211365), ('grand', 0.21946941316127777), ('environment', 0.21550941467285156)]
#
# Training climate_change_2005 model (Income 4)
# Documents: 7
# Vocab size: 1892
# Top associations for 'climate_change_2005':
# [('foregoing', 0.31441691517829895), ('tribute', 0.24145357310771942), ('constructively', 0.23825900256633759), ('peace', 0.2378389835357666), ('responsibility', 0.23539520800113678), ('hall', 0.23471134901046753), ('conservation', 0.22819370031356812), ('needy', 0.22623182833194733), ('judiciaries', 0.225402370095253), ('forum', 0.22178395092487335)]
#
# Training climate_change_2006 model (Income 4)
# Documents: 11
# Vocab size: 1707
# Top associations for 'climate_change_2006':
# [('ahead', 0.3206591010093689), ('work', 0.26866307854652405), ('shanghai', 0.26261910796165466), ('programme', 0.23641230165958405), ('demonstrates', 0.23508787155151367), ('sustained', 0.23062823712825775), ('fellow', 0.22793757915496826), ('consistent', 0.22011826932430267), ('continue', 0.21764209866523743), ('necessary', 0.21719811856746674)]
#
# Training climate_change_2007 model (Income 4)
# Documents: 43
# Vocab size: 5455
# Top associations for 'climate_change_2007':
# [('hope', 0.9990018606185913), ('terrorism', 0.9989686012268066), ('need', 0.9989440441131592), ('cooperation', 0.9988673329353333), ('nature', 0.9988519549369812), ('efforts', 0.9988471865653992), ('therefore', 0.9988356232643127), ('lebanon', 0.9988312721252441), ('countries', 0.9988254308700562), ('progress', 0.9988222122192383)]
#
# Training climate_change_2008 model (Income 4)
# Documents: 40
# Vocab size: 5046
# Top associations for 'climate_change_2008':
# [('international', 0.9992057085037231), ('united_nation', 0.9991424083709717), ('must', 0.9991361498832703), ('states', 0.9990828633308411), ('human', 0.9990800619125366), ('security', 0.9990793466567993), ('member', 0.999055027961731), ('first', 0.9990506768226624), ('work', 0.9990447163581848), ('economic', 0.9990234971046448)]
#
# Training climate_change_2009 model (Income 4)
# Documents: 45
# Vocab size: 5977
# Top associations for 'climate_change_2009':
# [('strategic', 0.9987292885780334), ('economies', 0.9987242817878723), ('context', 0.9987117648124695), ('bank', 0.9987043142318726), ('every', 0.9986815452575684), ('sector', 0.9986768960952759), ('declaration', 0.998675525188446), ('decide', 0.9986645579338074), ('required', 0.998656690120697), ('billion', 0.998654305934906)]
#
# Training climate_change_2010 model (Income 4)
# Documents: 37
# Vocab size: 4741
# Top associations for 'climate_change_2010':
# [('international', 0.9991884231567383), ('united_nation', 0.9991238117218018), ('european', 0.999114990234375), ('security', 0.9990605115890503), ('action', 0.9990519285202026), ('turkish', 0.9990509748458862), ('people', 0.9990352392196655), ('countries', 0.9990235567092896), ('national', 0.9990189075469971), ('council', 0.9990161657333374)]
#
# Training climate_change_2011 model (Income 4)
# Documents: 32
# Vocab size: 4003
# Top associations for 'climate_change_2011':
# [('united_nation', 0.983849287033081), ('need', 0.9834012985229492), ('development', 0.9832635521888733), ('also', 0.9830976128578186), ('peace', 0.9829105734825134), ('security', 0.9826496243476868), ('community', 0.982386589050293), ('people', 0.9821131229400635), ('support', 0.9820911288261414), ('years', 0.9813696146011353)]
#
# Training climate_change_2012 model (Income 4)
# Documents: 25
# Vocab size: 3595
# Top associations for 'climate_change_2012':
# [('must', 0.8536001443862915), ('also', 0.8410571217536926), ('international', 0.8393392562866211), ('challenges', 0.8273664712905884), ('council', 0.8223887085914612), ('economic', 0.8172914981842041), ('security', 0.8125084638595581), ('people', 0.8124033212661743), ('development', 0.8114442229270935), ('arms', 0.8109564781188965)]
#
# Training climate_change_2013 model (Income 4)
# Documents: 26
# Vocab size: 4569
# Top associations for 'climate_change_2013':
# [('people', 0.9972175359725952), ('development', 0.9971501231193542), ('world', 0.9970628023147583), ('international', 0.9970312118530273), ('united_nation', 0.9969895482063293), ('countries', 0.9968889951705933), ('must', 0.9968758225440979), ('years', 0.99686598777771), ('need', 0.9968201518058777), ('support', 0.9968188405036926)]
#
# Training climate_change_2014 model (Income 4)
# Documents: 43
# Vocab size: 5395
# Top associations for 'climate_change_2014':
# [('global', 0.9990441799163818), ('united_nation', 0.9990189671516418), ('international', 0.9990025162696838), ('challenges', 0.9989797472953796), ('world', 0.9989673495292664), ('efforts', 0.998955488204956), ('terrorist', 0.9989469051361084), ('education', 0.9989453554153442), ('must', 0.9989423155784607), ('agenda', 0.9989416003227234)]
#
# Training climate_change_2015 model (Income 4)
# Documents: 42
# Vocab size: 5452
# Top associations for 'climate_change_2015':
# [('small', 0.999151885509491), ('united_nation', 0.9991329312324524), ('agenda', 0.9991324543952942), ('policies', 0.9991179704666138), ('implementation', 0.9991044402122498), ('countries', 0.9990922212600708), ('nations', 0.9990824460983276), ('well', 0.9990772008895874), ('future', 0.9990760087966919), ('always', 0.9990604519844055)]
#
# Training climate_change_2016 model (Income 4)
# Documents: 43
# Vocab size: 5572
# Top associations for 'climate_change_2016':
# [('would', 0.9992033839225769), ('efforts', 0.999182939529419), ('economic', 0.9991002678871155), ('support', 0.9990999102592468), ('states', 0.9990913271903992), ('nuclear', 0.9990793466567993), ('security', 0.9990648627281189), ('peace', 0.999058723449707), ('rights', 0.999056875705719), ('united_nation', 0.9990546703338623)]
#
# Training climate_change_2017 model (Income 4)
# Documents: 47
# Vocab size: 5993
# Top associations for 'climate_change_2017':
# [('effects', 0.999015212059021), ('natural', 0.99894779920578), ('respect', 0.9988541007041931), ('disasters', 0.9988529682159424), ('time', 0.9988345503807068), ('even', 0.9988251328468323), ('high', 0.9988248944282532), ('middle', 0.9988097548484802), ('year', 0.9987988471984863), ('relevant', 0.998793363571167)]
#
# Training climate_change_2018 model (Income 4)
# Documents: 47
# Vocab size: 6620
# Top associations for 'climate_change_2018':
# [('become', 0.9987313151359558), ('hurricane', 0.9987239241600037), ('africa', 0.9986749291419983), ('rome', 0.9986732602119446), ('palau', 0.998667299747467), ('precisely', 0.9986506700515747), ('peacekeeping', 0.9986475706100464), ('cannot', 0.9986473321914673), ('rich', 0.9986445903778076), ('savage', 0.9986436367034912)]
#
# Training climate_change_2019 model (Income 4)
# Documents: 52
# Vocab size: 7526
# Top associations for 'climate_change_2019':
# [('grid', 0.9987105131149292), ('online', 0.9986779093742371), ('organizations', 0.9986275434494019), ('costly', 0.9986218214035034), ('times', 0.9985788464546204), ('tatou', 0.9985763430595398), ('obligations', 0.9985715746879578), ('crises', 0.9985702037811279), ('aspire', 0.998569905757904), ('three', 0.9985642433166504)]
#
# Training climate_change_2020 model (Income 4)
# Documents: 44
# Vocab size: 6108
# Top associations for 'climate_change_2020':
# [('many', 0.9990595579147339), ('work', 0.9990529417991638), ('people', 0.9990103840827942), ('time', 0.9989948868751526), ('also', 0.9989756941795349), ('peace', 0.998971700668335), ('health', 0.9989627003669739), ('world', 0.9989622235298157), ('developing', 0.9989497065544128), ('economic', 0.9989494681358337)]
#
# Training climate_change_2021 model (Income 4)
# Documents: 54
# Vocab size: 7306
# Top associations for 'climate_change_2021':
# [('constitutional', 0.9987269043922424), ('word', 0.9986937046051025), ('recall', 0.998688280582428), ('exploitation', 0.9986875653266907), ('spoke', 0.9986708760261536), ('basis', 0.9986701607704163), ('flows', 0.9986670613288879), ('hard', 0.9986657500267029), ('online', 0.9986547231674194), ('seeing', 0.9986464381217957)]
#
# Training climate_change_2022 model (Income 4)
# Documents: 56
# Vocab size: 7001
# Top associations for 'climate_change_2022':
# [('together', 0.998583972454071), ('2050', 0.9985747337341309), ('technology', 0.9985504746437073), ('shall', 0.9985467195510864), ('gender', 0.9985448718070984), ('medicines', 0.9985446929931641), ('person', 0.9985331892967224), ('normal', 0.9985325336456299), ('results', 0.9985252022743225), ('respect', 0.998523473739624)]
#
# Training climate_change_2023 model (Income 4)
# Documents: 60
# Vocab size: 7046
# Top associations for 'climate_change_2023':
# [('construction', 0.9987360835075378), ('mali', 0.9987157583236694), ('border', 0.9987111687660217), ('exchange', 0.9986881017684937), ('opportunities', 0.9986847639083862), ('bahamas', 0.9986752271652222), ('home', 0.9986585378646851), ('contain', 0.9986503720283508), ('catastrophic', 0.9986458420753479), ('paid', 0.9986425638198853)]
#
# Training climate_change_2024 model (Income 4)
# Documents: 43
# Vocab size: 5900
# Top associations for 'climate_change_2024':
# [('system', 0.9991227388381958), ('cannot', 0.9991136789321899), ('international', 0.9991020560264587), ('must', 0.9990594983100891), ('security', 0.9990378618240356), ('like', 0.9990235567092896), ('technologies', 0.9990175366401672), ('ocean', 0.9990136027336121), ('small', 0.9989922046661377), ('gaza', 0.9989892840385437)]

# %%
""" top_similar_by_year = {}

for income_level, models_by_year in all_models.items():
    for year, model in models_by_year.items():
        token = f"climate_change_{year}"
        
        if token in model.wv:
            similar_words = model.wv.most_similar(token, topn=5)
            top_similar_by_year[(income_level, year)] = [word for word, _ in similar_words]
        else:
            print('something wrong')
            top_similar_by_year[(income_level, year)] = [None] * 5


top_words_df = pd.DataFrame.from_dict(top_similar_by_year, orient='index')
top_words_df.index = pd.MultiIndex.from_tuples(top_words_df.index, names=['Income_Level', 'Year'])
top_words_df.columns = [f"Rank_{i+1}" for i in range(top_words_df.shape[1])]

top_words_df = top_words_df.sort_index()
top_words_df """
# Out:
# ' top_similar_by_year = {}\n\nfor income_level, models_by_year in all_models.items():\n    for year, model in models_by_year.items():\n        token = f"climate_change_{year}"\n\n        if token in model.wv:\n            similar_words = model.wv.most_similar(token, topn=5)\n            top_similar_by_year[(income_level, year)] = [word for word, _ in similar_words]\n        else:\n            print(\'something wrong\')\n            top_similar_by_year[(income_level, year)] = [None] * 5\n\n\ntop_words_df = pd.DataFrame.from_dict(top_similar_by_year, orient=\'index\')\ntop_words_df.index = pd.MultiIndex.from_tuples(top_words_df.index, names=[\'Income_Level\', \'Year\'])\ntop_words_df.columns = [f"Rank_{i+1}" for i in range(top_words_df.shape[1])]\n\ntop_words_df = top_words_df.sort_index()\ntop_words_df '

# %%
for income_level, models_by_year in all_models.items():
    plot_data = []
    print(income_level)
    for year, model in models_by_year.items():
        target_token = f"climate_change_{year}"
        
        if target_token not in model.wv:
            continue
        
        # Add climate_change_YEAR
        plot_data.append({
            'token': target_token,
            'vector': model.wv[target_token],
            'year': year,
            'source': 'climate_change',
            'income_level': income_level
        })
        
        # Add top N similar words
        similar = model.wv.most_similar(target_token, topn=2)
        for word, _ in similar:
            if word in model.wv:
                plot_data.append({
                    'token': word,
                    'vector': model.wv[word],
                    'year': year,
                    'source': 'neighbor',
                    'income_level': income_level
                })

    df_plot = pd.DataFrame(plot_data)


    # Stack vectors into 2D array for t-SNE
    X = np.vstack(df_plot['vector'].values)
    if income_level == 1:
        print(X)
        break
    # Run t-SNE
    tsne = TSNE(n_components=2, perplexity=10, metric='cosine', random_state=42)
    X_2d = tsne.fit_transform(X)

    # Store the result back in the DataFrame
    df_plot['TSNE_1'] = X_2d[:, 0]
    df_plot['TSNE_2'] = X_2d[:, 1]

    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=df_plot,
        x='TSNE_1',
        y='TSNE_2',
        hue='year',
        style='source',
        palette='coolwarm',
        alpha=1
    )

    # Prepare all labels as objects
    texts = []

    # Climate change labels
    for _, row in df_plot[df_plot['source'] == 'climate_change'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=9, weight='bold')
        )

    # Neighbor labels (optional, maybe use fewer or smaller fontsize)
    for _, row in df_plot[df_plot['source'] == 'neighbor'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=7, alpha=0.7)
        )

    # Adjust to avoid overlaps
    adjust_text(texts, 
                arrowprops=dict(arrowstyle="-", color='gray', lw=0.5), 
                expand_points=(1.2, 1.2), 
                expand_text=(1.2, 1.2),
                force_text=0.25,
                force_points=0.25)

    plt.title("t-SNE: Semantic Drift of 'climate_change_YEAR' and Neighbors")
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# 1
# [[-0.00136593  0.00647773 -0.00224725 ... -0.0050125  -0.0014534
#    0.0007393 ]
#  [-0.00220325 -0.00063289 -0.00100938 ...  0.00131282 -0.0052995
#   -0.00400392]
#  [-0.00037818 -0.00384958 -0.00603126 ... -0.00421248  0.00238275
#    0.00558013]
#  ...
#  [-0.00080161 -0.02402446  0.01274541 ...  0.00381219  0.00534331
#   -0.00371693]
#  [ 0.00967819 -0.06558651  0.02915613 ...  0.02343211 -0.00494046
#   -0.00703667]
#  [ 0.00026828 -0.07556742  0.0323419  ...  0.02605598  0.00132898
#   -0.00618771]]

# %%
np.size(X[0])
# Out:
# 150

# %%
from scipy.linalg import orthogonal_procrustes

# After training all models, align within each income level
all_aligned_models = {}

for income_level, models_by_year in all_models.items():
    if not models_by_year:
        continue
        
    # Get sorted years and use first year as reference
    years = sorted(models_by_year.keys())
    ref_year = years[0]
    ref_model = models_by_year[ref_year]
    
    aligned_models = {ref_year: ref_model}  # Reference model stays unchanged
    
    # Find stable anchor words (common non-climate words)
    anchor_words = set()
    for year, model in models_by_year.items():
        # Exclude climate_change tokens and rare words
        anchor_words |= {word for word in model.wv.key_to_index 
                        if not word.startswith('climate_change_') 
                        and model.wv.get_vecattr(word, 'count') > 5}
    
    for year in years[1:]:
        curr_model = models_by_year[year]
        
        # Get shared anchor words present in both models
        common_anchors = list(anchor_words & set(ref_model.wv.key_to_index) & set(curr_model.wv.key_to_index))
        
        if len(common_anchors) < 50:
            print(f"Warning: Only {len(common_anchors)} anchors for income level {income_level} in year {year}")
            continue
            
        # Create anchor vector matrices
        X_ref = np.array([ref_model.wv[word] for word in common_anchors])
        X_curr = np.array([curr_model.wv[word] for word in common_anchors])
        
        # Find optimal orthogonal transformation
        Q, _ = orthogonal_procrustes(X_curr, X_ref)
        
        # Apply transformation to all vectors in current model
        aligned_vectors = curr_model.wv.vectors @ Q
        
        # Create new aligned model
        aligned_model = Word2Vec(vector_size=curr_model.vector_size)
        aligned_model.wv.add_vectors(
            keys=curr_model.wv.index_to_key,
            weights=aligned_vectors
        )
        aligned_models[year] = aligned_model
    
    all_aligned_models[income_level] = aligned_models
# Out:
# Warning: Only 30 anchors for income level 1 in year 1993
# Warning: Only 29 anchors for income level 1 in year 1996
# Warning: Only 49 anchors for income level 1 in year 1997
# Warning: Only 39 anchors for income level 3 in year 1992
# Warning: Only 33 anchors for income level 3 in year 1993
# Warning: Only 49 anchors for income level 3 in year 1995
# Warning: Only 6 anchors for income level 3 in year 1996
# Warning: Only 48 anchors for income level 3 in year 1997
# Warning: Only 20 anchors for income level 3 in year 1998
# Warning: Only 39 anchors for income level 3 in year 1999
# Warning: Only 39 anchors for income level 3 in year 2000
# Warning: Only 48 anchors for income level 3 in year 2001
# Warning: Only 41 anchors for income level 4 in year 1993
# Warning: Only 40 anchors for income level 4 in year 2002
# Warning: Only 34 anchors for income level 4 in year 2003

# %%
# Use aligned models for plotting
for income_level, aligned_models in all_aligned_models.items():
    plot_data = []
    print(income_level)
    for year, model in aligned_models.items():
        target_token = f"climate_change_{year}"
        
        if target_token not in model.wv:
            continue
        
        plot_data.append({
            'token': target_token,
            'vector': model.wv[target_token],
            'year': year,
            'source': 'climate_change',
            'income_level': income_level
        })
        
        # Get similar words from ALIGNED model
        similar = model.wv.most_similar(target_token, topn=3)
        for word, _ in similar:
            plot_data.append({
                'token': word,
                'vector': model.wv[word],
                'year': year,
                'source': 'neighbor',
                'income_level': income_level
            })

    df_plot = pd.DataFrame(plot_data)

    # Stack vectors into 2D array for t-SNE
    X_orthogonal = np.vstack(df_plot['vector'].values)

    # Run t-SNE
    tsne = TSNE(n_components=2, perplexity=2, metric='cosine', random_state=42)
    X_2d = tsne.fit_transform(X_orthogonal)

    # Store the result back in the DataFrame
    df_plot['TSNE_1'] = X_2d[:, 0]
    df_plot['TSNE_2'] = X_2d[:, 1]

    plt.figure(figsize=(12, 8))
    sns.scatterplot(
        data=df_plot,
        x='TSNE_1',
        y='TSNE_2',
        hue='year',
        style='source',
        palette='coolwarm',
        alpha=1
    )

    # Prepare all labels as objects
    texts = []

    # Climate change labels
    for _, row in df_plot[df_plot['source'] == 'climate_change'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=9, weight='bold')
        )

    # Neighbor labels (optional, maybe use fewer or smaller fontsize)
    for _, row in df_plot[df_plot['source'] == 'neighbor'].iterrows():
        texts.append(
            plt.text(row['TSNE_1'], row['TSNE_2'], row['token'], fontsize=7, alpha=0.7)
        )

    # Adjust to avoid overlaps
    adjust_text(texts, 
                arrowprops=dict(arrowstyle="-", color='gray', lw=0.5), 
                expand_points=(1.2, 1.2), 
                expand_text=(1.2, 1.2),
                force_text=0.25,
                force_points=0.25)

    plt.title("t-SNE: Semantic Drift of 'climate_change_YEAR' and Neighbors")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Then proceed with t-SNE as before...
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1, 5):
    # Compare all years to the reference year
    years = sorted(all_aligned_models[i].keys())
    reference_year = years[0]

    print(f"\nSemantic Drift (Income Level {i}): Reference = {reference_year}")
    for year in years[1:]:
        vec_curr = all_aligned_models[i][year].wv[f"climate_change_{year}"].reshape(1, -1)
        cos_sim = cosine_similarity(
            all_aligned_models[i][reference_year].wv[f"climate_change_{reference_year}"].reshape(1, -1),
            vec_curr
        )[0][0]
        print(f"{reference_year} vs. {year}: {cos_sim:.3f}")

    # Collect results
    years = years[1:]  # Exclude reference year
    similarities = [
        cosine_similarity(
            all_aligned_models[i][reference_year].wv[f"climate_change_{reference_year}"].reshape(1, -1),
            all_aligned_models[i][y].wv[f"climate_change_{y}"].reshape(1, -1)
        )[0][0] for y in years
    ]

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(years, similarities, marker='o', linestyle='--', color='tab:red')
    plt.axhline(y=-1.0, color='gray', linestyle=':', alpha=0.5, label="No Drift")
    plt.title(f"Semantic Drift of 'climate_change' (Income Level {i})\nReference: {reference_year}")
    plt.xlabel("Year")
    plt.ylabel("Cosine Similarity to Reference")
    plt.ylim(0.5, 1.05)
    plt.grid(True)
    plt.show()
# Out:
# Semantic Drift (Income Level 1): Reference = 1990
# 1990 vs. 1991: 0.077
# 1990 vs. 1992: -0.046
# 1990 vs. 1994: -0.003
# 1990 vs. 1995: 0.086
# 1990 vs. 1998: -0.006
# 1990 vs. 1999: -0.075
# 1990 vs. 2000: 0.037
# 1990 vs. 2001: -0.063
# 1990 vs. 2002: -0.183
# 1990 vs. 2003: -0.035
# 1990 vs. 2004: 0.085
# 1990 vs. 2005: 0.015
# 1990 vs. 2006: -0.142
# 1990 vs. 2007: -0.047
# 1990 vs. 2008: -0.042
# 1990 vs. 2009: -0.048
# 1990 vs. 2010: -0.059
# 1990 vs. 2011: -0.062
# 1990 vs. 2012: -0.120
# 1990 vs. 2013: 0.008
# 1990 vs. 2014: 0.002
# 1990 vs. 2015: -0.089
# 1990 vs. 2016: -0.082
# 1990 vs. 2017: -0.097
# 1990 vs. 2018: -0.072
# 1990 vs. 2019: -0.069
# 1990 vs. 2020: -0.109
# 1990 vs. 2021: -0.072
# 1990 vs. 2022: -0.046
# 1990 vs. 2023: -0.020
# 1990 vs. 2024: -0.075
# Semantic Drift (Income Level 2): Reference = 1991
# 1991 vs. 1992: -0.070
# 1991 vs. 1993: -0.036
# 1991 vs. 1994: 0.085
# 1991 vs. 1995: 0.025
# 1991 vs. 1996: -0.059
# 1991 vs. 1997: 0.107
# 1991 vs. 1998: 0.104
# 1991 vs. 1999: -0.091
# 1991 vs. 2000: -0.034
# 1991 vs. 2001: 0.047
# 1991 vs. 2002: 0.173
# 1991 vs. 2003: 0.083
# 1991 vs. 2004: -0.024
# 1991 vs. 2005: -0.006
# 1991 vs. 2006: -0.025
# 1991 vs. 2007: 0.256
# 1991 vs. 2008: 0.270
# 1991 vs. 2009: 0.269
# 1991 vs. 2010: 0.245
# 1991 vs. 2011: 0.279
# 1991 vs. 2012: 0.257
# 1991 vs. 2013: 0.269
# 1991 vs. 2014: 0.269
# 1991 vs. 2015: 0.237
# 1991 vs. 2016: 0.265
# 1991 vs. 2017: 0.255
# 1991 vs. 2018: 0.248
# 1991 vs. 2019: 0.224
# 1991 vs. 2020: 0.267
# 1991 vs. 2021: 0.239
# 1991 vs. 2022: 0.243
# 1991 vs. 2023: 0.249
# 1991 vs. 2024: 0.264
# Semantic Drift (Income Level 3): Reference = 1990
# 1990 vs. 1991: -0.050
# 1990 vs. 1994: 0.036
# 1990 vs. 2002: -0.024
# 1990 vs. 2003: -0.102
# 1990 vs. 2004: -0.052
# 1990 vs. 2005: 0.029
# 1990 vs. 2006: 0.175
# 1990 vs. 2007: 0.027
# 1990 vs. 2008: 0.036
# 1990 vs. 2009: 0.000
# 1990 vs. 2010: -0.033
# 1990 vs. 2011: 0.018
# 1990 vs. 2012: 0.043
# 1990 vs. 2013: 0.029
# 1990 vs. 2014: 0.010
# 1990 vs. 2015: -0.027
# 1990 vs. 2016: -0.009
# 1990 vs. 2017: -0.044
# 1990 vs. 2018: -0.005
# 1990 vs. 2019: 0.007
# 1990 vs. 2020: 0.036
# 1990 vs. 2021: -0.021
# 1990 vs. 2022: -0.026
# 1990 vs. 2023: 0.015
# 1990 vs. 2024: 0.012
# Semantic Drift (Income Level 4): Reference = 1990
# 1990 vs. 1991: 0.161
# 1990 vs. 1992: 0.090
# 1990 vs. 1995: 0.088
# 1990 vs. 1996: 0.039
# 1990 vs. 1997: 0.106
# 1990 vs. 1998: -0.128
# 1990 vs. 1999: 0.169
# 1990 vs. 2000: 0.021
# 1990 vs. 2001: 0.018
# 1990 vs. 2004: 0.058
# 1990 vs. 2005: -0.031
# 1990 vs. 2006: -0.218
# 1990 vs. 2007: 0.087
# 1990 vs. 2008: 0.090
# 1990 vs. 2009: 0.073
# 1990 vs. 2010: 0.083
# 1990 vs. 2011: 0.094
# 1990 vs. 2012: 0.110
# 1990 vs. 2013: 0.082
# 1990 vs. 2014: 0.084
# 1990 vs. 2015: 0.075
# 1990 vs. 2016: 0.083
# 1990 vs. 2017: 0.079
# 1990 vs. 2018: 0.084
# 1990 vs. 2019: 0.065
# 1990 vs. 2020: 0.079
# 1990 vs. 2021: 0.077
# 1990 vs. 2022: 0.065
# 1990 vs. 2023: 0.083
# 1990 vs. 2024: 0.081

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# Example for one income level (adjust loop for all levels)
income_level = 1
years = sorted(all_aligned_models[income_level].keys())
n_years = len(years)

# Initialize similarity matrix
similarity_matrix = np.zeros((n_years, n_years))

# Fill matrix with cosine similarities
for i, year1 in enumerate(years):
    vec1 = all_aligned_models[income_level][year1].wv[f"climate_change_{year1}"].reshape(1, -1)
    for j, year2 in enumerate(years):
        vec2 = all_aligned_models[income_level][year2].wv[f"climate_change_{year2}"].reshape(1, -1)
        similarity_matrix[i, j] = np.round(cosine_similarity(vec1, vec2)[0][0], 1)

plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(
    similarity_matrix,
    annot=True,
    fmt=".1f",  # Show 1 decimal place (CORRECTED: moved out of annot_kws)
    annot_kws={"size": 10},  # Adjust text size only
    cmap="coolwarm",
    vmin=0.5,
    vmax=1.0,
    xticklabels=years,
    yticklabels=years,
    linewidths=0.5,
    cbar_kws={"label": "Cosine Similarity"}
)

plt.title(f"Semantic Similarity of 'climate_change_YYYY'\n(Income Level {income_level})", pad=20)
plt.xlabel("Year")
plt.ylabel("Year")
plt.tight_layout()
plt.show()

# %%
similarity_matrix[-1]
# Out:
# array([-0.08      , -0.02      , -0.03      ,  0.1       ,  0.03      ,
#         0.07      ,  0.1       , -0.01      , -0.04      ,  0.14      ,
#         0.12      ,  0.03      ,  0.07      , -0.06      ,  0.85000002,
#         0.82999998,  0.83999997,  0.83999997,  0.77999997,  0.38999999,
#         0.11      ,  0.37      ,  0.63      ,  0.82999998,  0.81999999,
#         0.82999998,  0.83999997,  0.69      ,  0.82999998,  0.83999997,
#         0.75999999,  1.        ])
