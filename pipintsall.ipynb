# %%
! pip install pandas 
! pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 3.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.0 MB 4.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.0 MB 4.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.0 MB 5.3 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/11.0 MB 5.5 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 5.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
# ...

# %%
! pip install transformers
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/10.8 MB 3.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/10.8 MB 4.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/10.8 MB 4.4 MB/s eta 0:00:02
#    -------------- ------------------------- 3.9/10.8 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/10.8 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.8 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/10.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/10.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
# ...
